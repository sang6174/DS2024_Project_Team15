# %% [markdown]
# ### CRAWL DATA "Tivi" FROM LAZADA

# %% [markdown]
# ### 1. Setting selenium and initialize Chrome

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %%
#URL Lazada: tivi
main_link = 'https://www.lazada.vn/catalog/?q=tivi'
path = 'chromedriver.exe'

# Customize Chrome browser settings
chrome_options = Options()                                     
chrome_options.add_argument('--no-sandbox')                     #Them tuy chon de chay Chrome ko co sandbox, thuong duoc su dung de tranh cac van de ve quyen truy cap he thong
chrome_options.add_argument('--disable-notifications')          #Tat thong bao tu trinh duyet
chrome_options.add_argument('--disable-infobars')               #Tat thanh thong tin cua trinh duyet

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

#Open the Lazada web
driver.get(main_link)

# %% [markdown]
# ### 2. Crawl data on 1 page

# %% [markdown]
# ##### Outside page

# %%
#Crawl the information displayed on the outside of the page

def get_Data_On_Page():
    #The information is definitely there
    Type = [elem.get_attribute("value") for elem in driver.find_elements(By.CSS_SELECTOR, ".search-box__input--O34g")]
    Title = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".RfADt [href]")]
    Link = [elem.get_attribute('href') for elem in driver.find_elements(By.CSS_SELECTOR, ".RfADt [href]")]
    Price_sale = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".ooOxS")]

    #The information may or may not be available
    #If not, assign None
    Sale_off, Total_sold, Preview = [], [], []
    for i in range(1, len(Title)+1):
        Title = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".RfADt [href]")]

        Sale_off, Total_sold, Preview = [], [], []
        for i in range(1, len(Title)+1):
            try:
                temp_sale = driver.find_element("xpath", "/html/body/div[3]/div/div[2]/div[1]/div/div[1]/div[2]/div[{}]/div/div/div[2]/div[4]/span".format(i))
                Sale_off.append(temp_sale.text)
            except NoSuchElementException:
                Sale_off.append(None)

            try:
                temp_sold = driver.find_element("xpath", "/html/body/div[3]/div/div[2]/div[1]/div/div[1]/div[2]/div[{}]/div/div/div[2]/div[5]/span[1]/span[1]".format(i))
                Total_sold.append(temp_sold.text)
            except NoSuchElementException:
                Total_sold.append(None)

            try:
                temp_preview = driver.find_element("xpath", "/html/body/div[3]/div/div[2]/div[1]/div/div[1]/div[2]/div[{}]/div/div/div[2]/div[5]/div/span".format(i))
                Preview.append(temp_preview.text)
            except NoSuchElementException:
                Preview.append(None)

    Location = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".oa6ri")]
    if len(Type) == 1:
        Type = Type * len(Title)

    data = {
        "Type": Type,
        "Title": Title,
        "Link": Link,
        "Price_sale": Price_sale,
        "Sale_off": Sale_off,
        "Total_sold": Total_sold,
        "Preview": Preview,
        "Location": Location
    }

    # Convert the dictionary to a DataFrame
    df = pd.DataFrame(data)
    return df

# %%
#Call the function and get the DF
tivi = get_Data_On_Page()
tivi.index = np.arange(1, len(tivi)+1)

# %%
tivi.head()
# Out:
#    Type                                              Title  \
# 1  tivi  [NEW MODEL 2024] QLED TIVI 4K SAMSUNG 85 INCH ...
# 2  tivi  GIAO HÀ NỘI - Smart Tivi Casper 4K 50 inch 50U...
# 3  tivi  Thanh lý TIVI TOSHIBA 24inch đầy đủ cổng kết n...
# 4  tivi            Smart Tivi Coocaa Full HD 43 Inch 43S3U
# 5  tivi               Smart Tivi Samsung 32 inch UA32T4202
#
#                                                 Link    Price_sale Sale_off  \
# 1  https://www.lazada.vn/products/new-model-2024-...  64.690.000 ₫   6% Off
# 2  https://www.lazada.vn/products/giao-ha-noi-sma...   5.389.000 ₫  46% Off
# 3  https://www.lazada.vn/products/thanh-ly-tivi-t...     920.486 ₫   3% Off
# 4  https://www.lazada.vn/products/smart-tivi-cooc...   3.989.000 ₫  50% Off
# 5  https://www.lazada.vn/products/smart-tivi-sams...   4.689.000 ₫  41% Off
#
#    Total_sold Preview     Location
# 1        None    None  Hồ Chí Minh
# 2  130 Đã bán     (6)       Hà Nội
# 3   77 Đã bán    (26)       Hà Nội
# 4        None    None       Hà Nội
# 5   16 Đã bán    None       Hà Nội

# %% [markdown]
# ##### Each Product

# %%
#Get the link and access each product to get more features
def get_Data_Detail_1Product(link):
    driver.get(link)                            #Get link
    sleep(random.uniform(2, 5))                 #Random sleep to mimic human behavior and avoid getting blocked
    
    Price_original = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".notranslate.pdp-price.pdp-price_type_deleted.pdp-price_color_lightgray.pdp-price_size_xs")]
    Ship_price = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".delivery-option-item.delivery-option-item_type_standard .delivery-option-item__body .delivery-option-item__shipping-fee.no-subtitle")]
    Return = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".delivery-option-item.delivery-option-item_type_returnPolicy30 .delivery-option-item__body .delivery-option-item__info .delivery-option-item__title")]

    # Sale_rating & Ship_on_time & Chat_respone
    percentage = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".seller-info-value ")]
    Sale_rating = percentage[0] if len(percentage) > 0 else None
    Ship_on_time = percentage[1] if len(percentage) > 1 else None
    Chat_response = percentage[2] if len(percentage) > 2 else None


    # Cuộn trang từ từ để tải phần đánh giá sao
    while True:
        driver.execute_script("window.scrollBy(0, 400);")
        sleep(1)  # Đợi một chút để nội dung tải
        try:
            stars = driver.find_elements(By.CSS_SELECTOR, ".detail .percent")
            if len(stars) >= 5:
                break
        except NoSuchElementException:
            continue
    
    One_star, Two_star, Three_star, Four_star, Five_star = [], [], [], [], []
    stars = [elem.text for elem in stars]

    One_star.append(stars[4] if len(stars) > 4 else 'N/A')
    Two_star.append(stars[3] if len(stars) > 3 else 'N/A')
    Three_star.append(stars[2] if len(stars) > 2 else 'N/A')
    Four_star.append(stars[1] if len(stars) > 1 else 'N/A')
    Five_star.append(stars[0] if len(stars) > 0 else 'N/A')


    #Create a dictionary with the lists
    detail = {
        "Price_original": Price_original[0] if Price_original else None,
        "Ship_price": Ship_price[0] if Ship_price else None,
        "Return": Return[0] if Return else None,
        "Sale_rating": Sale_rating,
        "Ship_on_time": Ship_on_time,
        "Chat_response": Chat_response,
        "One_star": One_star,
        "Two_star": Two_star,
        "Three_star": Three_star,
        "Four_star": Four_star,
        "Five_star": Five_star
    }
    
    return detail

# %%
#Initialize dictionary to store details for all products
detail_products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(tivi.Link, desc="Crawling product details"):
    details = get_Data_Detail_1Product(link)
    for key in detail_products.keys():
        detail_products[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 40/40 [19:58<00:00, 29.96s/it]

# %%
#Add columns to dienthoai
for key, value in detail_products.items():
    tivi[key] = value

# %%
#Convert to csv
page_01 = tivi.to_csv("page_01.csv", index=False)
tivi
# Out:
#     Type                                              Title  \
# 1   tivi  [NEW MODEL 2024] QLED TIVI 4K SAMSUNG 85 INCH ...
# 2   tivi  GIAO HÀ NỘI - Smart Tivi Casper 4K 50 inch 50U...
# 3   tivi  Thanh lý TIVI TOSHIBA 24inch đầy đủ cổng kết n...
# 4   tivi            Smart Tivi Coocaa Full HD 43 Inch 43S3U
# 5   tivi               Smart Tivi Samsung 32 inch UA32T4202
# 6   tivi  Tivi 32 inch Sen Việt Androi Tv độ phân giải 1...
# 7   tivi  Thanh lý Smart Tivi LG 4K 43 inch có wifi,yout...
# 8   tivi  Smart Tivi Casper S Series Full HD 43 inch 43F...
# 9   tivi         Smart Tivi Sony 42 inch có wifi,youtobe...
# 10  tivi         Tivi Mới Cũ dùng cho khách sạn - văn phòng
# 11  tivi  [SALE 6.6] Smart Tivi Samsung 55 inch QLED 4K ...
# 12  tivi  phim phân cực 32in để dán tivi bị ố dộp mốc la...
# 13  tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 55 inch U...
# 14  tivi  THANH LED TIVI SAMSUNG 43T6000 43T6500 43R6000...
# 15  tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 50 inch U...
# 16  tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 65 inch U...
# 17  tivi  SMART TV 4K COOCAA 55 inch viền mỏng - Youtube...
# 18  tivi           Smart Tivi Samsung 4K 65 inch UA65AU7002
# 19  tivi  [6.6 HOTDEAL 19400K - Tặng Loa S522W cho 20 đơ...
# 20  tivi  TCON: T430HVN01.A, T420HVN6.1, T430HVN01.0, T4...
# 21  tivi        Smart Tivi QLED 4K 50 inch Samsung QA50Q65A
# 22  tivi        Smart Tivi Samsung 65 inch QLED 4K 65QN90CA
# 23  tivi               Google Tivi COOCAA 75 inch 4K V-75C9
# 24  tivi   Thanh Led Tivi SAMSUNG 32J4003, 32J4303, 32N4300
# 25  tivi           Smart Tivi Samsung 4K 43 inch UA43AU7002
# 26  tivi                   Android Tivi TCL 40 inch L40S66A
# 27  tivi                    Thanh led tivi samsung 48ju6400
# 28  tivi   Tivi led 24 inch Darling có tích hợp đầu thu KTS
# 29  tivi        Smart Tivi QLED Samsung 4K 65 inch QA65Q80R
# 30  tivi             Google Tivi QLED TCL 4K 43 inch 43Q636
# 31  tivi  Thanh lý Tivi Samsung 32inch chính hãng, hình ...
# 32  tivi  [ 6.6 HOTDEAL 5290K - Tặng Giá Treo TV DP243 c...
# 33  tivi  SMART TIVI DARLING 32 INCH 32HD964S ( Internet...
# 34  tivi         Tivi Smart Tv 32 inch Asanzo wifi internet
# 35  tivi                  Google Tivi TCL 4K 58 inch 58P635
# 36  tivi  Google Tivi TCL 4K 43 inch 43P745 - Hàng chính...
# 37  tivi  Bo WIFI Tivi SONY 43W800F, 43W800G, 49W800F, 4...
# 38  tivi  THANH LED TIVI SAMSUNG 55TU7000 55TU8000 55TU8...
# 39  tivi  Bộ LED TIVI SAMSUNG 40J5000 40J5200 40J5250 40...
# 40  tivi  TCON TIVI SONY 43W800F, 43W800G - HÀNG NGUYÊN ...
#
#                                                  Link    Price_sale Sale_off  \
# 1   https://www.lazada.vn/products/new-model-2024-...  64.690.000 ₫   6% Off
# 2   https://www.lazada.vn/products/giao-ha-noi-sma...   5.389.000 ₫  46% Off
# 3   https://www.lazada.vn/products/thanh-ly-tivi-t...     920.486 ₫   3% Off
# 4   https://www.lazada.vn/products/smart-tivi-cooc...   3.989.000 ₫  50% Off
# 5   https://www.lazada.vn/products/smart-tivi-sams...   4.689.000 ₫  41% Off
# 6   https://www.lazada.vn/products/tivi-32-inch-se...   2.490.000 ₫     None
# 7   https://www.lazada.vn/products/thanh-ly-smart-...   3.565.542 ₫   4% Off
# 8   https://www.lazada.vn/products/smart-tivi-casp...   4.689.000 ₫  48% Off
# 9   https://www.lazada.vn/products/smart-tivi-sony...   3.003.074 ₫   2% Off
# 10  https://www.lazada.vn/products/tivi-moi-cu-dun...     950.000 ₫     None
# 11  https://www.lazada.vn/products/sale-66-smart-t...  11.589.000 ₫  27% Off
# 12  https://www.lazada.vn/products/phim-phan-cuc-3...      99.000 ₫     None
# 13  https://www.lazada.vn/products/sale-66-smart-t...   8.589.000 ₫  33% Off
# 14  https://www.lazada.vn/products/thanh-led-tivi-...     230.000 ₫     None
# 15  https://www.lazada.vn/products/sale-66-smart-t...   8.189.000 ₫  28% Off
# 16  https://www.lazada.vn/products/sale-66-smart-t...  11.589.000 ₫  27% Off
# 17  https://www.lazada.vn/products/smart-tv-4k-coo...   5.740.000 ₫  48% Off
# 18  https://www.lazada.vn/products/smart-tivi-sams...   9.900.000 ₫  44% Off
# 19  https://www.lazada.vn/products/66-hotdeal-1940...  33.890.000 ₫  11% Off
# 20  https://www.lazada.vn/products/tcon-t430hvn01a...     250.000 ₫     None
# 21  https://www.lazada.vn/products/smart-tivi-qled...  12.600.000 ₫  14% Off
# 22  https://www.lazada.vn/products/smart-tivi-sams...  31.590.000 ₫  36% Off
# 23  https://www.lazada.vn/products/google-tivi-coo...  11.381.000 ₫  51% Off
# 24  https://www.lazada.vn/products/thanh-led-tivi-...     120.000 ₫     None
# 25  https://www.lazada.vn/products/smart-tivi-sams...   6.100.000 ₫  38% Off
# 26  https://www.lazada.vn/products/android-tivi-tc...   4.190.000 ₫  46% Off
# 27  https://www.lazada.vn/products/thanh-led-tivi-...     570.000 ₫     None
# 28  https://www.lazada.vn/products/tivi-led-24-inc...   2.250.000 ₫     None
# 29  https://www.lazada.vn/products/smart-tivi-qled...  14.200.000 ₫  38% Off
# 30  https://www.lazada.vn/products/google-tivi-qle...   6.490.000 ₫  44% Off
# 31  https://www.lazada.vn/products/thanh-ly-tivi-s...   1.675.000 ₫  11% Off
# 32  https://www.lazada.vn/products/66-hotdeal-5290...   6.490.000 ₫  38% Off
# 33  https://www.lazada.vn/products/smart-tivi-darl...   2.730.000 ₫     None
# 34  https://www.lazada.vn/products/tivi-smart-tv-3...   3.050.000 ₫     None
# 35  https://www.lazada.vn/products/google-tivi-tcl...   7.490.000 ₫  29% Off
# 36  https://www.lazada.vn/products/google-tivi-tcl...   7.990.000 ₫     None
# 37  https://www.lazada.vn/products/bo-wifi-tivi-so...     190.000 ₫     None
# 38  https://www.lazada.vn/products/thanh-led-tivi-...     230.000 ₫     None
# 39  https://www.lazada.vn/products/bo-led-tivi-sam...     165.000 ₫     None
# 40  https://www.lazada.vn/products/tcon-tivi-sony-...     320.000 ₫     None
#
#      Total_sold Preview     Location Price_original Ship_price  \
# 1          None    None  Hồ Chí Minh   68.790.000 ₫
# 2    130 Đã bán     (6)       Hà Nội    9.890.000 ₫
# 3     77 Đã bán    (26)       Hà Nội      950.000 ₫  115.100 ₫
# 4          None    None       Hà Nội    7.990.000 ₫
# 5     16 Đã bán    None       Hà Nội    7.900.000 ₫
# 6          None    None    Thái Bình           None  141.300 ₫
# 7     31 Đã bán    (15)       Hà Nội    3.700.000 ₫  206.800 ₫
# 8      9 Đã bán    None       Hà Nội    9.090.000 ₫
# 9     21 Đã bán    (17)       Hà Nội    3.070.000 ₫  198.200 ₫
# 10         None    None       Hà Nội           None  198.200 ₫
# 11    85 Đã bán    (24)  Hồ Chí Minh   15.900.000 ₫  146.000 ₫
# 12   908 Đã bán   (220)  Hồ Chí Minh           None   18.300 ₫
# 13  1.0K Đã bán   (234)  Hồ Chí Minh   12.900.000 ₫  159.200 ₫
# 14    72 Đã bán    (26)  Hồ Chí Minh           None   16.500 ₫
# 15   102 Đã bán    (24)  Hồ Chí Minh   11.400.000 ₫  131.600 ₫
# 16   317 Đã bán    (63)  Hồ Chí Minh   15.900.000 ₫  258.200 ₫
# 17  2.2K Đã bán   (919)  Hồ Chí Minh   10.990.000 ₫   46.000 ₫
# 18     5 Đã bán    None  Hồ Chí Minh   17.800.000 ₫  238.400 ₫
# 19    83 Đã bán    (27)   Bình Dương   38.290.000 ₫
# 20   165 Đã bán    (57)       Hà Nội           None   32.700 ₫
# 21     9 Đã bán     (4)  Hồ Chí Minh   14.690.000 ₫  146.000 ₫
# 22     8 Đã bán    None  Hồ Chí Minh   48.990.000 ₫
# 23         None    None  Hồ Chí Minh   22.990.000 ₫
# 24    12 Đã bán     (7)   Tiền Giang           None   28.700 ₫
# 25         None    None  Hồ Chí Minh    9.900.000 ₫   21.600 ₫
# 26         None    None  Hồ Chí Minh    7.690.000 ₫  131.600 ₫
# 27         None    None       Hà Nội           None   21.700 ₫
# 28    59 Đã bán    (20)    Đồng Tháp           None   65.500 ₫
# 29         None    None  Hồ Chí Minh   22.900.000 ₫  258.200 ₫
# 30         None    None  Hồ Chí Minh   11.490.000 ₫  131.600 ₫
# 31         None    None       Hà Nội    1.875.000 ₫  198.200 ₫
# 32   473 Đã bán   (141)     Bắc Ninh   10.490.000 ₫   Miễn phí
# 33         None    None  Hồ Chí Minh           None   38.000 ₫
# 34         None    None    Đồng Tháp           None   88.900 ₫
# 35         None    None  Hồ Chí Minh   10.490.000 ₫  131.600 ₫
# 36    20 Đã bán     (8)   Bình Dương           None
# 37    18 Đã bán     (2)   Tiền Giang           None   28.700 ₫
# 38     7 Đã bán     (1)  Hồ Chí Minh           None   16.500 ₫
# 39         None     (3)      Hà Tĩnh           None   43.900 ₫
# 40    17 Đã bán     (6)   Tiền Giang           None   32.200 ₫
#
#                        Return         Sale_rating        Ship_on_time  \
# 1                        None                100%  Không đủ thông tin
# 2                        None                100%  Không đủ thông tin
# 3                        None                 91%                 95%
# 4   30 Ngày Trả Hàng Miễn Phí    Nhà bán hàng mới  Không đủ thông tin
# 5                        None                100%  Không đủ thông tin
# 6                        None    Nhà bán hàng mới  Không đủ thông tin
# 7                        None                 91%                 95%
# 8                        None                100%  Không đủ thông tin
# 9                        None                 91%                 95%
# 10                       None                 86%                 97%
# 11  30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 12                       None                 94%                100%
# 13  30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 14                       None                 99%                100%
# 15  30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 16  30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 17  30 Ngày Trả Hàng Miễn Phí                 97%                 93%
# 18                       None                 85%                 50%
# 19  30 Ngày Trả Hàng Miễn Phí                 96%                100%
# 20                       None                 96%                100%
# 21                       None                 85%                 50%
# 22                       None                100%  Không đủ thông tin
# 23                       None                 97%  Không đủ thông tin
# 24                       None                 96%                100%
# 25                       None  Không đủ thông tin  Không đủ thông tin
# 26                       None  Không đủ thông tin  Không đủ thông tin
# 27                       None                 97%                 96%
# 28                       None                 97%                 94%
# 29                       None                 85%                 50%
# 30                       None  Không đủ thông tin  Không đủ thông tin
# 31                       None                 91%                 92%
# 32  30 Ngày Trả Hàng Miễn Phí                 96%                100%
# 33                       None  Không đủ thông tin  Không đủ thông tin
# 34                       None                 97%                 85%
# 35                       None  Không đủ thông tin  Không đủ thông tin
# 36  30 Ngày Trả Hàng Miễn Phí                 96%                100%
# 37                       None                 96%                100%
# 38                       None                 99%                100%
# 39                       None                 96%                100%
# 40                       None                 96%                100%
#
#          Chat_response One_star Two_star Three_star Four_star Five_star
# 1                 100%      [0]      [0]        [0]       [0]       [0]
# 2                 100%      [0]      [0]        [0]       [0]       [6]
# 3                  92%      [0]      [0]        [0]       [2]      [24]
# 4                 100%      [0]      [0]        [0]       [0]       [0]
# 5                 100%      [0]      [0]        [0]       [0]       [1]
# 6                 100%      [0]      [0]        [0]       [0]       [0]
# 7                  92%      [1]      [0]        [1]       [0]      [14]
# 8                 100%      [0]      [0]        [0]       [0]       [0]
# 9                  92%      [1]      [0]        [1]       [1]      [14]
# 10                 66%      [0]      [0]        [0]       [0]       [0]
# 11                100%      [0]      [0]        [1]       [0]      [23]
# 12  Không đủ thông tin      [3]      [3]        [2]       [8]     [205]
# 13                100%      [1]      [0]        [0]       [1]     [232]
# 14                 36%      [0]      [0]        [0]       [0]      [26]
# 15                100%      [0]      [0]        [0]       [1]      [24]
# 16                100%      [1]      [0]        [0]       [2]      [60]
# 17                100%      [5]      [0]        [1]      [17]     [896]
# 18                100%      [0]      [0]        [0]       [0]       [0]
# 19                 99%      [0]      [0]        [0]       [0]      [27]
# 20                100%      [0]      [2]        [1]       [2]      [52]
# 21                100%      [0]      [0]        [0]       [0]       [5]
# 22                100%      [0]      [0]        [0]       [0]       [0]
# 23                 86%      [0]      [0]        [0]       [0]       [0]
# 24                100%      [0]      [0]        [0]       [0]       [7]
# 25  Không đủ thông tin      [0]      [0]        [0]       [0]       [0]
# 26                100%      [0]      [0]        [0]       [0]       [0]
# 27                 55%      [0]      [0]        [0]       [0]       [0]
# 28                100%      [0]      [0]        [0]       [4]      [16]
# 29                100%      [0]      [0]        [0]       [0]       [0]
# 30                100%      [0]      [0]        [0]       [0]       [0]
# 31                100%      [0]      [0]        [0]       [0]       [0]
# 32                 99%      [2]      [1]        [1]       [1]     [136]
# 33  Không đủ thông tin      [0]      [0]        [0]       [0]       [0]
# 34  Không đủ thông tin      [0]      [0]        [0]       [0]       [0]
# 35                100%      [0]      [0]        [0]       [0]       [0]
# 36                 99%      [0]      [0]        [0]       [0]       [9]
# 37                100%      [0]      [0]        [0]       [0]       [3]
# 38                 36%      [0]      [0]        [0]       [0]       [1]
# 39                100%      [0]      [0]        [0]       [0]       [3]
# 40                100%      [0]      [0]        [0]       [0]       [6]
