# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/trang-phuc-nu/?_keyori=ss&catalog_redirect_tag=true&from=search_history&page=19&q=qu%E1%BA%A7n%20%C3%A1o&spm=a2o4n.home-vn.search.2.11183bdck8qLDT&sugg=qu%E1%BA%A7n%20%C3%A1o_0_1"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
df.head()
# Out:
#       Type                                              Title  \
# 0  quần áo  Đồ Bộ Nữ Đi Chơi Chất Thun Mát Size M - dưới 5...
# 1  quần áo  Đồ ngủ nữ pijama mặc nhà bộ ngủ hoạt hình cộc ...
# 2  quần áo  SÉT BỘ ÁO CỘC TAY CÔ BÉ ĐI XE MÁY KÈM QUẦN BOM...
# 3  quần áo  (ẢNH THẬT) Quần legging dài nâng mông cạp cao ...
# 4  quần áo      Bộ Pijama, Đồ Bộ Mặc Nhà Nữ Dáng Cộc xinh xắn
#
#                                                Links     Price  \
# 0  https://www.lazada.vn/products/do-bo-nu-di-cho...  35.891 ₫
# 1  https://www.lazada.vn/products/do-ngu-nu-pijam...  25.000 ₫
# 2  https://www.lazada.vn/products/set-bo-ao-coc-t...  36.000 ₫
# 3  https://www.lazada.vn/products/anh-that-quan-l...  26.020 ₫
# 4  https://www.lazada.vn/products/bo-pijama-do-bo...  15.971 ₫
#
#   Discount_percent         Sold Preview     Location
# 0          64% Off  3.0K Đã bán  (1024)  Hồ Chí Minh
# 1          50% Off   907 Đã bán   (246)  Hồ Chí Minh
# 2          60% Off   102 Đã bán    (21)     Nam Định
# 3          55% Off   547 Đã bán   (109)       Hà Nội
# 4          54% Off   229 Đã bán    (68)       Hà Nội

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [52:27<00:00, 26.23s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
# save to csv
df.to_csv("lazada_4.csv", index = True)
df.head()
# Out:
#       Type                                              Title  \
# 0  quần áo  Đồ Bộ Nữ Đi Chơi Chất Thun Mát Size M - dưới 5...
# 1  quần áo  Đồ ngủ nữ pijama mặc nhà bộ ngủ hoạt hình cộc ...
# 2  quần áo  SÉT BỘ ÁO CỘC TAY CÔ BÉ ĐI XE MÁY KÈM QUẦN BOM...
# 3  quần áo  (ẢNH THẬT) Quần legging dài nâng mông cạp cao ...
# 4  quần áo      Bộ Pijama, Đồ Bộ Mặc Nhà Nữ Dáng Cộc xinh xắn
#
#                                                Links     Price  \
# 0  https://www.lazada.vn/products/do-bo-nu-di-cho...  35.891 ₫
# 1  https://www.lazada.vn/products/do-ngu-nu-pijam...  25.000 ₫
# 2  https://www.lazada.vn/products/set-bo-ao-coc-t...  36.000 ₫
# 3  https://www.lazada.vn/products/anh-that-quan-l...  26.020 ₫
# 4  https://www.lazada.vn/products/bo-pijama-do-bo...  15.971 ₫
#
#   Discount_percent         Sold Preview     Location   Original Ship_price  \
# 0          64% Off  3.0K Đã bán  (1024)  Hồ Chí Minh  100.000 ₫   16.500 ₫
# 1          50% Off   907 Đã bán   (246)  Hồ Chí Minh   71.998 ₫   16.500 ₫
# 2          60% Off   102 Đã bán    (21)     Nam Định  189.000 ₫   37.700 ₫
# 3          55% Off   547 Đã bán   (109)       Hà Nội   78.000 ₫   32.700 ₫
# 4          54% Off   229 Đã bán    (68)       Hà Nội   59.000 ₫   32.700 ₫
#
#                              Return Positive_review Ship_on_time  \
# 0  3 ngày trả hàng cho Nhà bán hàng             97%         100%
# 1  3 ngày trả hàng cho Nhà bán hàng             91%         100%
# 2  3 ngày trả hàng cho Nhà bán hàng             94%         100%
# 3  3 ngày trả hàng cho Nhà bán hàng             83%          98%
# 4  3 ngày trả hàng cho Nhà bán hàng             95%         100%
#
#   Rate_response One_star Two_star Three_star Four_star Five_star
# 0          100%       20        7         27        36       934
# 1           50%        5        2          6         7       226
# 2           83%        1        0          1         1        18
# 3          100%       28       10          5         5        61
# 4          100%        0        1          0         3        65
