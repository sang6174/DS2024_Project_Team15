# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.request
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
from tqdm import tqdm

# %%
from Main_function import get_Data_On_Page, get_Data_OneProduct_Link 

path = 'chromedriver.exe'

# # Customize chrome displayLa
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')
## chrome_options.add_argument('--headless')  # Optional: run Chrome in headless mode

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
#Empty list, to store data from all pages
AllData = []

for page in tqdm(range(2, 6), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?page={page}&q=Trang%20s%E1%BB%A9c&spm=a2o4n.home-vn.search.d_go'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    df_Jewelry = get_Data_On_Page(driver)
    AllData.append(df_Jewelry)
# Out:
# Crawling pages: 100%|██████████| 4/4 [02:20<00:00, 35.06s/it]

# %%
#Combine into a DataFrame
Data_Jewelry_Page02_To_Page05 = pd.concat(AllData, ignore_index=True)
Data_Jewelry_Page02_To_Page05.index = np.arange(1, len(Data_Jewelry_Page02_To_Page05)+1)
Data_Jewelry_Page02_To_Page05
# Out:
#           Type                                              Title  \
# 1    Trang sức  17km pha lê May Mắn Vòng đeo tay đính hạt cho ...
# 2    Trang sức  17km thanh lịch nơ hình trái tim bướm mặt dây ...
# 3    Trang sức  17KM Pink Crystal Bell Orchid Bracelet for Wom...
# 4    Trang sức  17km Tulip Wing nơ hình trái tim Mặt dây chuyề...
# 5    Trang sức  MIAOYA Thời trang Hàn Quốc bốn mặt dây chuyền ...
# ..         ...                                                ...
# 156  Trang sức  Người Đàn Ông Nhẫn Punk titan bạc Thép Zircon ...
# 157  Trang sức  DREJEW Phiên Bản Hàn Quốc Vòng Cổ Mới Hoa Ngọt...
# 158  Trang sức  Dây chuyền đơn/ nhiều lớp kiểu dáng tùy chọn p...
# 159  Trang sức  Tốt Quá 30 cái/bộ Sang Trọng Nhẫn vàng Set Cho...
# 160  Trang sức  Thời trang mới thép Titan Vòng cổ đa năng cổ đ...
#
#                                                   Link Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/17km-pha-le-may...    6.848 ₫  46% Off
# 2    https://www.lazada.vn/products/17km-thanh-lich...    6.587 ₫  56% Off
# 3    https://www.lazada.vn/products/17km-pink-cryst...    9.320 ₫  59% Off
# 4    https://www.lazada.vn/products/17km-tulip-wing...    5.674 ₫  50% Off
# 5    https://www.lazada.vn/products/miaoya-thoi-tra...    9.157 ₫  49% Off
# ..                                                 ...        ...      ...
# 156  https://www.lazada.vn/products/nguoi-dan-ong-n...   14.000 ₫  40% Off
# 157  https://www.lazada.vn/products/drejew-phien-ba...   16.900 ₫  50% Off
# 158  https://www.lazada.vn/products/day-chuyen-don-...   28.000 ₫
# 159  https://www.lazada.vn/products/tot-qua-30-caib...   29.432 ₫  54% Off
# 160  https://www.lazada.vn/products/thoi-trang-moi-...   33.000 ₫  35% Off
#
#       Total_sold Preview     Location
# 1    1.9K Đã bán   (594)  Hồ Chí Minh
# 2    3.5K Đã bán   (950)  Hồ Chí Minh
# 3     133 Đã bán    (31)  Hồ Chí Minh
# 4    6.7K Đã bán  (1649)  Hồ Chí Minh
# 5     246 Đã bán    (50)   Nước ngoài
# ..           ...     ...          ...
# 156   152 Đã bán    (53)  Hồ Chí Minh
# 157   649 Đã bán   (107)   Nước ngoài
# 158  2.4K Đã bán   (342)   Nước ngoài
# 159    43 Đã bán    (16)   Nước ngoài
# 160     8 Đã bán     (4)   Nước ngoài
#
# [160 rows x 8 columns]

# %%
#Initialize dictionary to store details for all products
Products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(Data_Jewelry_Page02_To_Page05.Link, desc="Crawling link product"):
    LinkProduct = get_Data_OneProduct_Link( driver,link)
    for key in Products.keys():
        Products[key].append(LinkProduct[key])
# Out:
# Crawling link product: 100%|██████████| 160/160 [2:00:31<00:00, 45.19s/it]

# %%
#Add columns to combined_data
for key, value in Products.items():
    Data_Jewelry_Page02_To_Page05[key] = value

# %%
# Convert to csv
Data_Jewelry_Page02_To_Page05.to_csv("Data_Jewelry_Page02_To_Page05.csv", index=False)
Data_Jewelry_Page02_To_Page05
# Out:
#           Type                                              Title  \
# 1    Trang sức  17km pha lê May Mắn Vòng đeo tay đính hạt cho ...
# 2    Trang sức  17km thanh lịch nơ hình trái tim bướm mặt dây ...
# 3    Trang sức  17KM Pink Crystal Bell Orchid Bracelet for Wom...
# 4    Trang sức  17km Tulip Wing nơ hình trái tim Mặt dây chuyề...
# 5    Trang sức  MIAOYA Thời trang Hàn Quốc bốn mặt dây chuyền ...
# ..         ...                                                ...
# 156  Trang sức  Người Đàn Ông Nhẫn Punk titan bạc Thép Zircon ...
# 157  Trang sức  DREJEW Phiên Bản Hàn Quốc Vòng Cổ Mới Hoa Ngọt...
# 158  Trang sức  Dây chuyền đơn/ nhiều lớp kiểu dáng tùy chọn p...
# 159  Trang sức  Tốt Quá 30 cái/bộ Sang Trọng Nhẫn vàng Set Cho...
# 160  Trang sức  Thời trang mới thép Titan Vòng cổ đa năng cổ đ...
#
#                                                   Link Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/17km-pha-le-may...    6.848 ₫  46% Off
# 2    https://www.lazada.vn/products/17km-thanh-lich...    6.587 ₫  56% Off
# 3    https://www.lazada.vn/products/17km-pink-cryst...    9.320 ₫  59% Off
# 4    https://www.lazada.vn/products/17km-tulip-wing...    5.674 ₫  50% Off
# 5    https://www.lazada.vn/products/miaoya-thoi-tra...    9.157 ₫  49% Off
# ..                                                 ...        ...      ...
# 156  https://www.lazada.vn/products/nguoi-dan-ong-n...   14.000 ₫  40% Off
# 157  https://www.lazada.vn/products/drejew-phien-ba...   16.900 ₫  50% Off
# 158  https://www.lazada.vn/products/day-chuyen-don-...   28.000 ₫
# 159  https://www.lazada.vn/products/tot-qua-30-caib...   29.432 ₫  54% Off
# 160  https://www.lazada.vn/products/thoi-trang-moi-...   33.000 ₫  35% Off
#
#       Total_sold Preview     Location Price_original Ship_price  \
# 1    1.9K Đã bán   (594)  Hồ Chí Minh           None       None
# 2    3.5K Đã bán   (950)  Hồ Chí Minh       18.000 ₫   17.000 ₫
# 3     133 Đã bán    (31)  Hồ Chí Minh       27.975 ₫   17.000 ₫
# 4    6.7K Đã bán  (1649)  Hồ Chí Minh       12.900 ₫   17.000 ₫
# 5     246 Đã bán    (50)   Nước ngoài       17.999 ₫   17.000 ₫
# ..           ...     ...          ...            ...        ...
# 156   152 Đã bán    (53)  Hồ Chí Minh       23.333 ₫   17.000 ₫
# 157   649 Đã bán   (107)   Nước ngoài       54.698 ₫   17.000 ₫
# 158  2.4K Đã bán   (342)   Nước ngoài       40.000 ₫   17.000 ₫
# 159    43 Đã bán    (16)   Nước ngoài       64.000 ₫   17.000 ₫
# 160     8 Đã bán     (4)   Nước ngoài       50.700 ₫   17.000 ₫
#
#                         Return       Sale_rating Ship_on_time  \
# 1                         None              None         None
# 2    30 Ngày Trả Hàng Miễn Phí               96%          95%
# 3    30 Ngày Trả Hàng Miễn Phí               96%          95%
# 4    30 Ngày Trả Hàng Miễn Phí               96%          95%
# 5                         None               96%         100%
# ..                         ...               ...          ...
# 156                       None               92%         100%
# 157  30 Ngày Trả Hàng Miễn Phí               98%          91%
# 158                       None               94%         100%
# 159  30 Ngày Trả Hàng Miễn Phí               96%          89%
# 160                       None  Nhà bán hàng mới         100%
#
#           Chat_response One_star Two_star Three_star Four_star Five_star
# 1                  None     [13]      [8]       [15]      [14]     [544]
# 2                   96%      [6]      [9]       [11]      [12]     [913]
# 3                   96%      [1]      [0]        [0]       [1]      [29]
# 4                   96%     [39]     [14]       [26]      [36]    [1534]
# 5                  100%      [4]      [1]        [1]       [2]      [42]
# ..                  ...      ...      ...        ...       ...       ...
# 156  Không đủ thông tin      [2]      [4]        [5]       [1]      [42]
# 157                100%      [0]      [0]        [1]       [1]     [105]
# 158  Không đủ thông tin     [13]      [3]       [10]      [17]     [299]
# 159                100%      [1]      [0]        [0]       [0]      [15]
# 160  Không đủ thông tin      [0]      [0]        [0]       [0]       [4]
#
# [160 rows x 19 columns]
