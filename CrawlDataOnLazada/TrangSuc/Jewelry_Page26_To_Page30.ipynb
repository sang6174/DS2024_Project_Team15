# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.request
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
from tqdm import tqdm

# %%
from Main_function import get_Data_On_Page, get_Data_OneProduct_Link 

path = 'chromedriver.exe'

# # Customize chrome displayLa
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')
## chrome_options.add_argument('--headless')  # Optional: run Chrome in headless mode

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
#Empty list, to store data from all pages
AllData = []

for page in tqdm(range(26, 31), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?page={page}&q=Trang%20s%E1%BB%A9c&spm=a2o4n.home-vn.search.d_go'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    df_Jewelry = get_Data_On_Page(driver)
    AllData.append(df_Jewelry)
# Out:
# Crawling pages: 100%|██████████| 5/5 [02:24<00:00, 28.87s/it]

# %%
#Combine into a DataFrame
Data_Jewelry_Page26_To_Page30 = pd.concat(AllData, ignore_index=True)
Data_Jewelry_Page26_To_Page30.index = np.arange(1, len(Data_Jewelry_Page26_To_Page30)+1)
Data_Jewelry_Page26_To_Page30
# Out:
#           Type                                              Title  \
# 1    Trang sức  17km pha lê May Mắn Vòng đeo tay đính hạt cho ...
# 2    Trang sức  JWER Quà Tặng Trang Sức Cặp Đôi Hình Trái Tim ...
# 3    Trang sức  Fashion Angel Girl Hoạt hình dễ thương Mèo Kit...
# 4    Trang sức  2Pcs Kim Cương Twist Nhẫn bạc Phụ Nữ Người Đàn...
# 5    Trang sức  17KM Pink Crystal Bell Orchid Bracelet for Wom...
# ..         ...                                                ...
# 196  Trang sức  Maidu Jewelry Tua Rua Xương Đòn Chuỗi Lớp Vòng...
# 197  Trang sức  AOLD8 Thời Trang Nam Nữ Bán Sỉ MỚI Chuỗi Vòng ...
# 198  Trang sức  Mặt Dây Chuyền Hồ Ly Chín Đuôi Đá Mã Não, Hàng...
# 199  Trang sức  YUP 1 cặp nhẫn đôi trang sức đính hôn đám cưới...
# 200  Trang sức  Nhẫn nữ màu cẩm thạch viền đá tia mạ vàng Kami...
#
#                                                   Link Price_sale  \
# 1    https://www.lazada.vn/products/17km-pha-le-may...    5.900 ₫
# 2    https://www.lazada.vn/products/jwer-qua-tang-t...    5.000 ₫
# 3    https://www.lazada.vn/products/fashion-angel-g...    4.500 ₫
# 4    https://www.lazada.vn/products/2pcs-kim-cuong-...    5.272 ₫
# 5    https://www.lazada.vn/products/17km-pink-cryst...    9.320 ₫
# ..                                                 ...        ...
# 196  https://www.lazada.vn/products/maidu-jewelry-t...   34.225 ₫
# 197  https://www.lazada.vn/products/aold8-thoi-tran...   20.900 ₫
# 198  https://www.lazada.vn/products/mat-day-chuyen-...  188.000 ₫
# 199  https://www.lazada.vn/products/yup-1-cap-nhan-...   15.331 ₫
# 200  https://www.lazada.vn/products/nhan-nu-mau-cam...   66.913 ₫
#
#                      Sale_off   Total_sold Preview     Location
# 1                              1.9K Đã bán   (597)  Hồ Chí Minh
# 2                              1.2K Đã bán   (224)  Hồ Chí Minh
# 3                                56 Đã bán    (12)   Nước ngoài
# 4                                35 Đã bán    (12)  Hồ Chí Minh
# 5                               135 Đã bán    (32)  Hồ Chí Minh
# ..                        ...          ...     ...          ...
# 196                   54% Off    15 Đã bán     (3)   Nước ngoài
# 197  49% Off\nÁp dụng voucher    12 Đã bán     (1)   Nước ngoài
# 198                   62% Off   256 Đã bán    (53)       Hà Nội
# 199                   31% Off    26 Đã bán     (9)   Nước ngoài
# 200                   25% Off    38 Đã bán     (7)  Hồ Chí Minh
#
# [200 rows x 8 columns]

# %%
#Initialize dictionary to store details for all products
Products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [], 
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(Data_Jewelry_Page26_To_Page30.Link, desc="Crawling link product"):
    LinkProduct = get_Data_OneProduct_Link(driver, link)
    for key in Products.keys():
        Products[key].append(LinkProduct[key])
# Out:
# Crawling link product: 100%|██████████| 200/200 [1:38:41<00:00, 29.61s/it]

# %%
#Add columns to combined_data
for key, value in Products.items():
    Data_Jewelry_Page26_To_Page30[key] = value

# %%
# Convert to csv
Data_Jewelry_Page26_To_Page30.to_csv("Data_Jewelry_Page26_To_Page30.csv", index=False)
Data_Jewelry_Page26_To_Page30
# Out:
#           Type                                              Title  \
# 1    Trang sức  17km pha lê May Mắn Vòng đeo tay đính hạt cho ...
# 2    Trang sức  JWER Quà Tặng Trang Sức Cặp Đôi Hình Trái Tim ...
# 3    Trang sức  Fashion Angel Girl Hoạt hình dễ thương Mèo Kit...
# 4    Trang sức  2Pcs Kim Cương Twist Nhẫn bạc Phụ Nữ Người Đàn...
# 5    Trang sức  17KM Pink Crystal Bell Orchid Bracelet for Wom...
# ..         ...                                                ...
# 196  Trang sức  Maidu Jewelry Tua Rua Xương Đòn Chuỗi Lớp Vòng...
# 197  Trang sức  AOLD8 Thời Trang Nam Nữ Bán Sỉ MỚI Chuỗi Vòng ...
# 198  Trang sức  Mặt Dây Chuyền Hồ Ly Chín Đuôi Đá Mã Não, Hàng...
# 199  Trang sức  YUP 1 cặp nhẫn đôi trang sức đính hôn đám cưới...
# 200  Trang sức  Nhẫn nữ màu cẩm thạch viền đá tia mạ vàng Kami...
#
#                                                   Link Price_sale  \
# 1    https://www.lazada.vn/products/17km-pha-le-may...    5.900 ₫
# 2    https://www.lazada.vn/products/jwer-qua-tang-t...    5.000 ₫
# 3    https://www.lazada.vn/products/fashion-angel-g...    4.500 ₫
# 4    https://www.lazada.vn/products/2pcs-kim-cuong-...    5.272 ₫
# 5    https://www.lazada.vn/products/17km-pink-cryst...    9.320 ₫
# ..                                                 ...        ...
# 196  https://www.lazada.vn/products/maidu-jewelry-t...   34.225 ₫
# 197  https://www.lazada.vn/products/aold8-thoi-tran...   20.900 ₫
# 198  https://www.lazada.vn/products/mat-day-chuyen-...  188.000 ₫
# 199  https://www.lazada.vn/products/yup-1-cap-nhan-...   15.331 ₫
# 200  https://www.lazada.vn/products/nhan-nu-mau-cam...   66.913 ₫
#
#                      Sale_off   Total_sold Preview     Location  \
# 1                              1.9K Đã bán   (597)  Hồ Chí Minh
# 2                              1.2K Đã bán   (224)  Hồ Chí Minh
# 3                                56 Đã bán    (12)   Nước ngoài
# 4                                35 Đã bán    (12)  Hồ Chí Minh
# 5                               135 Đã bán    (32)  Hồ Chí Minh
# ..                        ...          ...     ...          ...
# 196                   54% Off    15 Đã bán     (3)   Nước ngoài
# 197  49% Off\nÁp dụng voucher    12 Đã bán     (1)   Nước ngoài
# 198                   62% Off   256 Đã bán    (53)       Hà Nội
# 199                   31% Off    26 Đã bán     (9)   Nước ngoài
# 200                   25% Off    38 Đã bán     (7)  Hồ Chí Minh
#
#     Price_original Ship_price                     Return Sale_rating  \
# 1             None       None                       None        None
# 2          9.000 ₫   17.000 ₫                       None         95%
# 3          8.000 ₫   17.000 ₫                       None         94%
# 4         11.300 ₫   17.000 ₫                       None         97%
# 5         27.975 ₫   17.000 ₫  30 Ngày Trả Hàng Miễn Phí         96%
# ..             ...        ...                        ...         ...
# 196       74.000 ₫   17.000 ₫                       None         96%
# 197       41.000 ₫   17.000 ₫                       None         95%
# 198      500.000 ₫   32.700 ₫                       None         94%
# 199       22.134 ₫   17.000 ₫                       None         93%
# 200       89.000 ₫   16.500 ₫                       None         97%
#
#     Ship_on_time       Chat_response One_star Two_star Three_star Four_star  \
# 1           None                None     [13]      [8]       [15]      [14]
# 2           100%                 71%     [12]      [4]        [6]      [13]
# 3           100%                100%      [0]      [0]        [0]       [0]
# 4            98%                100%      [0]      [0]        [0]       [0]
# 5            95%                 97%      [1]      [0]        [0]       [1]
# ..           ...                 ...      ...      ...        ...       ...
# 196          99%                100%      [0]      [0]        [0]       [0]
# 197         100%  Không đủ thông tin      [0]      [0]        [0]       [0]
# 198         100%                100%      [0]      [1]        [2]       [0]
# 199         100%  Không đủ thông tin      [0]      [0]        [0]       [0]
# 200          99%                 87%      [0]      [0]        [0]       [0]
#
#     Five_star
# 1       [547]
# 2       [189]
# 3        [12]
# 4        [12]
# 5        [30]
# ..        ...
# 196       [4]
# 197       [1]
# 198      [50]
# 199       [9]
# 200       [7]
#
# [200 rows x 19 columns]
