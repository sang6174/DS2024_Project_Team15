# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.request
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
from tqdm import tqdm

# %%
from Main_function import get_Data_On_Page, get_Data_OneProduct_Link 

path = 'chromedriver.exe'

# # Customize chrome displayLa
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')
## chrome_options.add_argument('--headless')  # Optional: run Chrome in headless mode

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
#Empty list, to store data from all pages
AllData = []

for page in tqdm(range(21, 26), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?page={page}&q=Trang%20s%E1%BB%A9c&spm=a2o4n.home-vn.search.d_go'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    df_Jewelry = get_Data_On_Page(driver)
    AllData.append(df_Jewelry)
# Out:
# Crawling pages: 100%|██████████| 5/5 [02:32<00:00, 30.50s/it]

# %%
#Combine into a DataFrame
Data_Jewelry_Page21_To_Page25 = pd.concat(AllData, ignore_index=True)
Data_Jewelry_Page21_To_Page25.index = np.arange(1, len(Data_Jewelry_Page21_To_Page25)+1)
Data_Jewelry_Page21_To_Page25
# Out:
#           Type                                              Title  \
# 1    Trang sức  [HCM]Nước rửa bạc, nước rửa trang sức SIÊU SÁN...
# 2    Trang sức  [HCM]Nước rửa bạc, nước rửa trang sức SIÊU SÁN...
# 3    Trang sức  【COMBO 5 HỘP】Nước rửa trang sức vàng bạc, nước...
# 4    Trang sức  Nước Rửa Trang Sức Bạc Liugems Dung Dịch Làm S...
# 5    Trang sức  17km thanh lịch nơ hình trái tim bướm mặt dây ...
# ..         ...                                                ...
# 196  Trang sức  Fashion Jewelry Shop Phong cách hip-hop 2 Vòng...
# 197  Trang sức           Vòng tay dây rút mèo đen dành cho nam nữ
# 198  Trang sức  Lắc tay trái tim mảnh đính đá đi học - vòng ta...
# 199  Trang sức  Vòng tay sợi chỉ đeo tay dây màu đỏ may mắn dâ...
# 200  Trang sức  Vòng Tay Ngọc Bích Cho Nữ Vòng Tay Hạt Ngọc Bí...
#
#                                                   Link Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/hcmnuoc-rua-bac...   20.000 ₫
# 2    https://www.lazada.vn/products/hcmnuoc-rua-bac...   30.000 ₫
# 3    https://www.lazada.vn/products/combo-5-hopnuoc...   69.569 ₫  55% Off
# 4    https://www.lazada.vn/products/nuoc-rua-trang-...   25.500 ₫  15% Off
# 5    https://www.lazada.vn/products/17km-thanh-lich...    6.587 ₫  56% Off
# ..                                                 ...        ...      ...
# 196  https://www.lazada.vn/products/fashion-jewelry...    8.800 ₫  41% Off
# 197  https://www.lazada.vn/products/vong-tay-day-ru...   55.000 ₫  50% Off
# 198  https://www.lazada.vn/products/lac-tay-trai-ti...   13.955 ₫  45% Off
# 199  https://www.lazada.vn/products/vong-tay-soi-ch...   10.000 ₫
# 200  https://www.lazada.vn/products/vong-tay-ngoc-b...   39.000 ₫  34% Off
#
#       Total_sold Preview     Location
# 1    3.2K Đã bán   (633)  Hồ Chí Minh
# 2     986 Đã bán   (209)  Hồ Chí Minh
# 3    1.5K Đã bán   (363)  Hồ Chí Minh
# 4    2.3K Đã bán   (364)  Hồ Chí Minh
# 5    3.5K Đã bán   (953)  Hồ Chí Minh
# ..           ...     ...          ...
# 196  2.1K Đã bán   (387)   Nước ngoài
# 197         None    None       Hà Nội
# 198         None    None  Hồ Chí Minh
# 199   114 Đã bán     (9)  Hồ Chí Minh
# 200         None    None   Nước ngoài
#
# [200 rows x 8 columns]

# %%
#Initialize dictionary to store details for all products
Products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [], 
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(Data_Jewelry_Page21_To_Page25.Link, desc="Crawling link product"):
    LinkProduct = get_Data_OneProduct_Link(driver, link)
    for key in Products.keys():
        Products[key].append(LinkProduct[key])
# Out:
# Crawling link product: 100%|██████████| 200/200 [1:41:25<00:00, 30.43s/it]

# %%
#Add columns to combined_data
for key, value in Products.items():
    Data_Jewelry_Page21_To_Page25[key] = value

# %%
# Convert to csv
Data_Jewelry_Page21_To_Page25.to_csv("Data_Jewelry_Page21_To_Page25.csv", index=False)
Data_Jewelry_Page21_To_Page25
# Out:
#           Type                                              Title  \
# 1    Trang sức  [HCM]Nước rửa bạc, nước rửa trang sức SIÊU SÁN...
# 2    Trang sức  [HCM]Nước rửa bạc, nước rửa trang sức SIÊU SÁN...
# 3    Trang sức  【COMBO 5 HỘP】Nước rửa trang sức vàng bạc, nước...
# 4    Trang sức  Nước Rửa Trang Sức Bạc Liugems Dung Dịch Làm S...
# 5    Trang sức  17km thanh lịch nơ hình trái tim bướm mặt dây ...
# ..         ...                                                ...
# 196  Trang sức  Fashion Jewelry Shop Phong cách hip-hop 2 Vòng...
# 197  Trang sức           Vòng tay dây rút mèo đen dành cho nam nữ
# 198  Trang sức  Lắc tay trái tim mảnh đính đá đi học - vòng ta...
# 199  Trang sức  Vòng tay sợi chỉ đeo tay dây màu đỏ may mắn dâ...
# 200  Trang sức  Vòng Tay Ngọc Bích Cho Nữ Vòng Tay Hạt Ngọc Bí...
#
#                                                   Link Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/hcmnuoc-rua-bac...   20.000 ₫
# 2    https://www.lazada.vn/products/hcmnuoc-rua-bac...   30.000 ₫
# 3    https://www.lazada.vn/products/combo-5-hopnuoc...   69.569 ₫  55% Off
# 4    https://www.lazada.vn/products/nuoc-rua-trang-...   25.500 ₫  15% Off
# 5    https://www.lazada.vn/products/17km-thanh-lich...    6.587 ₫  56% Off
# ..                                                 ...        ...      ...
# 196  https://www.lazada.vn/products/fashion-jewelry...    8.800 ₫  41% Off
# 197  https://www.lazada.vn/products/vong-tay-day-ru...   55.000 ₫  50% Off
# 198  https://www.lazada.vn/products/lac-tay-trai-ti...   13.955 ₫  45% Off
# 199  https://www.lazada.vn/products/vong-tay-soi-ch...   10.000 ₫
# 200  https://www.lazada.vn/products/vong-tay-ngoc-b...   39.000 ₫  34% Off
#
#       Total_sold Preview     Location Price_original Ship_price  \
# 1    3.2K Đã bán   (633)  Hồ Chí Minh           None       None
# 2     986 Đã bán   (209)  Hồ Chí Minh           None   16.500 ₫
# 3    1.5K Đã bán   (363)  Hồ Chí Minh      154.000 ₫   16.500 ₫
# 4    2.3K Đã bán   (364)  Hồ Chí Minh       30.000 ₫   16.500 ₫
# 5    3.5K Đã bán   (953)  Hồ Chí Minh       18.000 ₫   17.000 ₫
# ..           ...     ...          ...            ...        ...
# 196  2.1K Đã bán   (387)   Nước ngoài       15.000 ₫   17.000 ₫
# 197         None    None       Hà Nội      110.000 ₫   32.700 ₫
# 198         None    None  Hồ Chí Minh       25.539 ₫   16.500 ₫
# 199   114 Đã bán     (9)  Hồ Chí Minh           None   16.500 ₫
# 200         None    None   Nước ngoài       59.000 ₫
#
#                         Return       Sale_rating        Ship_on_time  \
# 1                         None              None                None
# 2                         None               98%                100%
# 3                         None               98%                100%
# 4    30 Ngày Trả Hàng Miễn Phí               98%                 81%
# 5    30 Ngày Trả Hàng Miễn Phí               96%                 95%
# ..                         ...               ...                 ...
# 196                       None               96%                100%
# 197                       None  Nhà bán hàng mới  Không đủ thông tin
# 198                       None               96%                100%
# 199                       None               93%                 99%
# 200                       None               83%  Không đủ thông tin
#
#           Chat_response One_star Two_star Three_star Four_star Five_star
# 1                  None      [6]      [3]        [9]      [17]     [598]
# 2    Không đủ thông tin      [3]      [3]        [1]       [1]     [201]
# 3                  100%      [2]      [0]        [2]       [4]     [355]
# 4                   77%      [5]      [2]        [2]      [10]     [346]
# 5                   97%      [6]      [9]       [11]      [13]     [915]
# ..                  ...      ...      ...        ...       ...       ...
# 196                100%      [9]      [5]       [15]      [19]     [339]
# 197  Không đủ thông tin      [0]      [0]        [0]       [0]       [0]
# 198                100%      [0]      [0]        [0]       [0]       [0]
# 199                 85%      [1]      [0]        [0]       [0]       [8]
# 200                100%      [0]      [0]        [0]       [0]       [0]
#
# [200 rows x 19 columns]
