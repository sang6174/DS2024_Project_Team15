# %%
import pandas as pd
import numpy as np

# %%
#List of CSV file to combined
csv_files = [
    #Thoi trang
    'quanao.csv',
    'giaydep.csv',
    'Data_Jewelry.csv',

    #Dien tu
    'DienThoai.csv',
    'Data_Laptop.csv',
    'Tivi.csv'
]

#Read and combine CSV files into a DataFrame
data_final = pd.concat([pd.read_csv(file) for file in csv_files])
#Reset index
data_final.reset_index(drop=True, inplace=True)
data_final.index = np.arange(1, len(data_final)+1)

# %%
data_final
# Out:
#          Type                                              Title  \
# 1     quần áo  Đồ Bộ Nữ Đi Chơi Chất Thun Mát Size M - dưới 5...
# 2     quần áo  Đồ ngủ nữ pijama mặc nhà bộ ngủ hoạt hình cộc ...
# 3     quần áo  [Đủ size 35-55 cân] Sét bộ 3 món áo 2 dây+áo c...
# 4     quần áo  SÉT BỘ ÁO CỘC TAY CÔ BÉ ĐI XE MÁY KÈM QUẦN BOM...
# 5     quần áo      Bộ Pijama, Đồ Bộ Mặc Nhà Nữ Dáng Cộc xinh xắn
# ...       ...                                                ...
# 7196     tivi  [6.6 HOTDEAL 4790K - Tặng Giá Treo TV DP243 ch...
# 7197     tivi  SMART TIVI DARLING 32 INCH 32HD964S ( Internet...
# 7198     tivi  Google Tivi TCL 4K 43 inch 43P745 - Bảo hành 2...
# 7199     tivi  Smart Tivi Casper 43 Inch 43FX5200 [Hàng Chính...
# 7200     tivi  Tivi Asanzo 32” model 32LS800 màn hình tràn vi...
#
#                                                    Link   Price_sale  \
# 1     https://www.lazada.vn/products/do-bo-nu-di-cho...     35.891 ₫
# 2     https://www.lazada.vn/products/do-ngu-nu-pijam...     25.000 ₫
# 3     https://www.lazada.vn/products/du-size-35-55-c...     79.000 ₫
# 4     https://www.lazada.vn/products/set-bo-ao-coc-t...     36.000 ₫
# 5     https://www.lazada.vn/products/bo-pijama-do-bo...     15.971 ₫
# ...                                                 ...          ...
# 7196  https://www.lazada.vn/products/66-hotdeal-4790...  5.390.000 ₫
# 7197  https://www.lazada.vn/products/smart-tivi-darl...  2.730.000 ₫
# 7198  https://www.lazada.vn/products/google-tivi-tcl...  6.150.000 ₫
# 7199  https://www.lazada.vn/products/smart-tivi-casp...  4.250.000 ₫
# 7200  https://www.lazada.vn/products/tivi-asanzo-32-...  2.650.000 ₫
#
#                                Sale_off   Total_sold Preview     Location  \
# 1                               64% Off  3.0K Đã bán  (1022)  Hồ Chí Minh
# 2                               50% Off   907 Đã bán   (241)  Hồ Chí Minh
# 3                               43% Off   961 Đã bán   (260)       Hà Nội
# 4                               60% Off   102 Đã bán    (21)     Nam Định
# 5                               54% Off   219 Đã bán    (68)       Hà Nội
# ...                                 ...          ...     ...          ...
# 7196  LazFlash Sale,kết thúc sau 1 ngày    34 Đã bán     (9)  Hồ Chí Minh
# 7197                                NaN          NaN     NaN  Hồ Chí Minh
# 7198                                NaN          NaN     NaN  Hồ Chí Minh
# 7199                                NaN          NaN     NaN       Hà Nội
# 7200                                NaN          NaN     NaN  Hồ Chí Minh
#
#      Price_original Ship_price                            Return  \
# 1         100.000 ₫   16.500 ₫  3 ngày trả hàng cho Nhà bán hàng
# 2          71.998 ₫   16.500 ₫  3 ngày trả hàng cho Nhà bán hàng
# 3         139.000 ₫   32.700 ₫  3 ngày trả hàng cho Nhà bán hàng
# 4         189.000 ₫   37.700 ₫  3 ngày trả hàng cho Nhà bán hàng
# 5          59.000 ₫   32.700 ₫  3 ngày trả hàng cho Nhà bán hàng
# ...             ...        ...                               ...
# 7196    5.590.000 ₫   Miễn phí         30 Ngày Trả Hàng Miễn Phí
# 7197            NaN   38.000 ₫                               NaN
# 7198    9.990.000 ₫        NaN         30 Ngày Trả Hàng Miễn Phí
# 7199    4.990.000 ₫  135.500 ₫                               NaN
# 7200            NaN   45.100 ₫                               NaN
#
#              Sale_rating        Ship_on_time       Chat_response One_star  \
# 1                    97%                100%                100%     20.0
# 2                    91%                100%                 50%      5.0
# 3                    92%                 99%                 33%     11.0
# 4                    94%                100%                 83%      1.0
# 5                    95%                100%                100%      0.0
# ...                  ...                 ...                 ...      ...
# 7196                 96%                100%                100%    ['2']
# 7197  Không đủ thông tin  Không đủ thông tin  Không đủ thông tin    ['0']
# 7198                 97%                 98%                 89%    ['0']
# 7199                100%                 40%  Không đủ thông tin    ['0']
# 7200                100%  Không đủ thông tin                 50%    ['0']
#
#      Two_star Three_star Four_star Five_star
# 1         7.0       27.0      36.0     932.0
# 2         2.0        6.0       7.0     222.0
# 3         8.0        8.0      16.0     218.0
# 4         0.0        1.0       1.0      18.0
# 5         1.0        0.0       3.0      65.0
# ...       ...        ...       ...       ...
# 7196    ['0']      ['0']     ['0']     ['7']
# 7197    ['0']      ['0']     ['0']     ['0']
# 7198    ['0']      ['0']     ['0']     ['0']
# 7199    ['0']      ['0']     ['0']     ['0']
# 7200    ['0']      ['0']     ['0']     ['0']
#
# [7200 rows x 19 columns]

# %%
#Convert to "Final_Data_LLM.csv" file
data_final.to_csv("Data_After_Crawl.csv", index=False)
