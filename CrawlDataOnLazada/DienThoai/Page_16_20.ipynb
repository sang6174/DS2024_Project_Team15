# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %% [markdown]
# ##### 1. Load function **get_Data_On_Page, get_Data_Detail_1Product** from file **Main_function.py**

# %%
from Main_function import get_Data_On_Page, get_Data_Detail_1Product

# URL Lazada: dienthoai, sort price high to low
path = 'chromedriver.exe'
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %% [markdown]
# #### 2. Crawl data

# %% [markdown]
# ##### Crawl features displayed on the outside of the page

# %%
#Empty list, to store data from all pages
all_data = []

#Nhận link cho 5 page: 16-20 và sau đó đưa vào vòng lặp for cùng với hàm get_Data_On_Page
for page in tqdm(range(16,21), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?page={page}&q=dien%20thoai&sort=pricedesc'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    dienthoai = get_Data_On_Page(driver)
    all_data.append(dienthoai)
# Out:
# Crawling pages: 100%|██████████| 5/5 [02:46<00:00, 33.37s/it]

# %%
#Combine into a DataFrame
data_16_20 = pd.concat(all_data, ignore_index=True)
data_16_20.index = np.arange(1, len(data_16_20)+1)
data_16_20
# Out:
#            Type                                              Title  \
# 1    dien thoai  Điện thoại Samsung Galaxy S24 Ultra 5G - Hàng ...
# 2    dien thoai  Điện thoại Samsung Galaxy S24 8GB/256GB - Độc ...
# 3    dien thoai  Điện thoại máy chiếu 8849 Tank 3 Pro(máy chiếu...
# 4    dien thoai  Điện thoại Samsung Galaxy S24 Plus 5G 12GB/256...
# 5    dien thoai  Điện thoại 8849 Tank 3 Pro(máy chiếu 100 lumen...
# ..          ...                                                ...
# 196  dien thoai  Điện thoại OPPO Reno11F 5G (8GB/256GB) - Hàng ...
# 197  dien thoai  Điện thoại siêu bền Oukitel WP33 Pro 5G (Loa t...
# 198  dien thoai               Điện thoại thông minh POCO X6 Pro 5G
# 199  dien thoai  Điện thoại chắc chắn Unihertz Tank (RAM 22Gb ,...
# 200  dien thoai  Điện thoại chắc chắn Unihertz Tank (Ram 22Gb,I...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/dien-thoai-sams...  24.188.000 ₫  29% Off
# 2    https://www.lazada.vn/products/dien-thoai-sams...  20.090.000 ₫  13% Off
# 3    https://www.lazada.vn/products/dien-thoai-may-...  19.995.000 ₫   9% Off
# 4    https://www.lazada.vn/products/dien-thoai-sams...  19.990.000 ₫  26% Off
# 5    https://www.lazada.vn/products/dien-thoai-8849...  19.990.000 ₫   5% Off
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/dien-thoai-oppo...   8.990.000 ₫     None
# 197  https://www.lazada.vn/products/dien-thoai-sieu...   8.990.000 ₫  10% Off
# 198  https://www.lazada.vn/products/dien-thoai-thon...   8.990.000 ₫  10% Off
# 199  https://www.lazada.vn/products/dien-thoai-chac...   8.990.000 ₫  18% Off
# 200  https://www.lazada.vn/products/dien-thoai-chac...   8.990.000 ₫     None
#
#     Total_sold Preview     Location
# 1    11 Đã bán     (1)      Đà Nẵng
# 2         None     (1)  Hồ Chí Minh
# 3         None    None  Hồ Chí Minh
# 4         None    None  Hồ Chí Minh
# 5         None    None  Hồ Chí Minh
# ..         ...     ...          ...
# 196       None    None  Hồ Chí Minh
# 197       None    None  Hồ Chí Minh
# 198  25 Đã bán     (5)  Hồ Chí Minh
# 199       None     (1)  Hồ Chí Minh
# 200       None     (1)  Hồ Chí Minh
#
# [200 rows x 8 columns]

# %% [markdown]
# ##### Crawl features data for each product

# %%
#Initialize dictionary to store details for all products
detail_products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(data_16_20.Link, desc = "Crawling product details"):
    details = get_Data_Detail_1Product(driver, link)
    for key in detail_products.keys():
        detail_products[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 200/200 [1:38:29<00:00, 29.55s/it]

# %%
#Add columns to combined_data
for key, value in detail_products.items():
    data_16_20[key] = value

# Convert to csv
data_16_20.to_csv("Page_16_20.csv", index=False)
data_16_20
# Out:
#            Type                                              Title  \
# 1    dien thoai  Điện thoại Samsung Galaxy S24 Ultra 5G - Hàng ...
# 2    dien thoai  Điện thoại Samsung Galaxy S24 8GB/256GB - Độc ...
# 3    dien thoai  Điện thoại máy chiếu 8849 Tank 3 Pro(máy chiếu...
# 4    dien thoai  Điện thoại Samsung Galaxy S24 Plus 5G 12GB/256...
# 5    dien thoai  Điện thoại 8849 Tank 3 Pro(máy chiếu 100 lumen...
# ..          ...                                                ...
# 196  dien thoai  Điện thoại OPPO Reno11F 5G (8GB/256GB) - Hàng ...
# 197  dien thoai  Điện thoại siêu bền Oukitel WP33 Pro 5G (Loa t...
# 198  dien thoai               Điện thoại thông minh POCO X6 Pro 5G
# 199  dien thoai  Điện thoại chắc chắn Unihertz Tank (RAM 22Gb ,...
# 200  dien thoai  Điện thoại chắc chắn Unihertz Tank (Ram 22Gb,I...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/dien-thoai-sams...  24.188.000 ₫  29% Off
# 2    https://www.lazada.vn/products/dien-thoai-sams...  20.090.000 ₫  13% Off
# 3    https://www.lazada.vn/products/dien-thoai-may-...  19.995.000 ₫   9% Off
# 4    https://www.lazada.vn/products/dien-thoai-sams...  19.990.000 ₫  26% Off
# 5    https://www.lazada.vn/products/dien-thoai-8849...  19.990.000 ₫   5% Off
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/dien-thoai-oppo...   8.990.000 ₫     None
# 197  https://www.lazada.vn/products/dien-thoai-sieu...   8.990.000 ₫  10% Off
# 198  https://www.lazada.vn/products/dien-thoai-thon...   8.990.000 ₫  10% Off
# 199  https://www.lazada.vn/products/dien-thoai-chac...   8.990.000 ₫  18% Off
# 200  https://www.lazada.vn/products/dien-thoai-chac...   8.990.000 ₫     None
#
#     Total_sold Preview     Location Price_original Ship_price  \
# 1    11 Đã bán     (1)      Đà Nẵng   33.990.000 ₫   38.000 ₫
# 2         None     (1)  Hồ Chí Minh   22.990.000 ₫
# 3         None    None  Hồ Chí Minh   21.990.000 ₫   Miễn phí
# 4         None    None  Hồ Chí Minh   26.990.000 ₫   16.500 ₫
# 5         None    None  Hồ Chí Minh   20.990.000 ₫   19.600 ₫
# ..         ...     ...          ...            ...        ...
# 196       None    None  Hồ Chí Minh           None   45.100 ₫
# 197       None    None  Hồ Chí Minh    9.990.000 ₫   19.600 ₫
# 198  25 Đã bán     (5)  Hồ Chí Minh   11.490.000 ₫   18.300 ₫
# 199       None     (1)  Hồ Chí Minh   10.990.000 ₫   18.300 ₫
# 200       None     (1)  Hồ Chí Minh    9.000.000 ₫   Miễn phí
#
#                         Return Sale_rating        Ship_on_time Chat_response  \
# 1                         None         97%                 81%           80%
# 2    30 Ngày Trả Hàng Miễn Phí         91%  Không đủ thông tin          100%
# 3                         None         97%                100%           33%
# 4    30 Ngày Trả Hàng Miễn Phí         98%                 83%          100%
# 5                         None         85%  Không đủ thông tin          100%
# ..                         ...         ...                 ...           ...
# 196  30 Ngày Trả Hàng Miễn Phí        100%                100%          100%
# 197                       None         85%  Không đủ thông tin          100%
# 198  30 Ngày Trả Hàng Miễn Phí         99%                 99%           98%
# 199                       None         85%  Không đủ thông tin          100%
# 200                       None         97%                100%           33%
#
#     One_star Two_star Three_star Four_star Five_star
# 1        [0]      [0]        [0]       [0]       [2]
# 2        [0]      [0]        [0]       [0]       [1]
# 3        [0]      [0]        [0]       [0]       [0]
# 4        [0]      [0]        [0]       [0]       [0]
# 5        [0]      [0]        [0]       [0]       [0]
# ..       ...      ...        ...       ...       ...
# 196      [0]      [0]        [0]       [0]       [0]
# 197      [0]      [0]        [0]       [0]       [0]
# 198      [0]      [0]        [0]       [0]       [5]
# 199      [0]      [0]        [0]       [0]       [1]
# 200      [0]      [0]        [0]       [0]       [1]
#
# [200 rows x 19 columns]
