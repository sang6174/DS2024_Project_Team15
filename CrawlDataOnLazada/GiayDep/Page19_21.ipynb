# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()
link = "https://www.lazada.vn/catalog/?page=1&q=gi%C3%A0y&sort=pricedesc"
driver.get(link)

# %%
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details:   0%|          | 0/120 [00:00<?, ?it/s]
# Crawling product details: 100%|██████████| 120/120 [1:08:21<00:00, 34.18s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("Page19_21.csv", index = True)
df
# Out:
#      Type                                              Title  \
# 0    giày  [6-8.6: VOUCHER LAZADA] adidas Chạy ADIZERO SL...
# 1    giày  [6-8.6: MUA 3 GIẢM 40%] adidas Chạy Giày SOLAR...
# 2    giày  [6-8.6: MUA 3 GIẢM 40%] adidas Phong cách sống...
# 3    giày  [6-8.6: MUA 3 GIẢM 40%] adidas Chạy Giày Respo...
# 4    giày  [6-8.6: MUA 3 GIẢM 40%] adidas Chạy Giày Respo...
# ..    ...                                                ...
# 115  giày  Giày thể thao jordan 4cổ cao, Giày sneaker JD4...
# 116  giày  Ảnh thật - Siêu hot! Giày boot nữ cao gót 11.5...
# 117  giày  Dép Lê Li-ning Giày Cặp Đôi Đi Bên Ngoài Chống...
# 118  giày  Giày Thể Thao Nam N Balance 574 Giày Thể Thao ...
# 119  giày  (DA XỊN - FULL BOX 2023) Chelsea boot nam tăng...
#
#                                                  Links        Price  \
# 0    https://www.lazada.vn/products/6-86-voucher-la...  3.000.000 ₫
# 1    https://www.lazada.vn/products/6-86-mua-3-giam...  2.660.000 ₫
# 2    https://www.lazada.vn/products/6-86-mua-3-giam...  2.100.000 ₫
# 3    https://www.lazada.vn/products/6-86-mua-3-giam...  1.900.000 ₫
# 4    https://www.lazada.vn/products/6-86-mua-3-giam...  1.900.000 ₫
# ..                                                 ...          ...
# 115  https://www.lazada.vn/products/giay-the-thao-j...    379.000 ₫
# 116  https://www.lazada.vn/products/anh-that-sieu-h...    379.000 ₫
# 117  https://www.lazada.vn/products/dep-le-li-ning-...    378.000 ₫
# 118  https://www.lazada.vn/products/giay-the-thao-n...    370.000 ₫
# 119  https://www.lazada.vn/products/da-xin-full-box...    369.000 ₫
#
#     Discount_percent        Sold Preview    Location     Original Ship_price  \
# 0               None        None    None  Bình Dương         None   Miễn phí
# 1            30% Off   30 Đã bán    None  Bình Dương  3.800.000 ₫   Miễn phí
# 2            30% Off   52 Đã bán    None  Bình Dương  3.000.000 ₫   Miễn phí
# 3             5% Off        None    None  Bình Dương  2.000.000 ₫   Miễn phí
# 4             5% Off   50 Đã bán     (1)  Bình Dương  2.000.000 ₫   Miễn phí
# ..               ...         ...     ...         ...          ...        ...
# 115          24% Off    7 Đã bán     (0)     Phú Thọ    500.000 ₫   37.700 ₫
# 116          16% Off  161 Đã bán    (45)      Hà Nội    450.000 ₫   38.000 ₫
# 117          46% Off   33 Đã bán     (9)  Nước ngoài    699.000 ₫   17.000 ₫
# 118          31% Off   29 Đã bán     (4)  Nước ngoài    540.000 ₫   17.000 ₫
# 119          59% Off   30 Đã bán    (12)    Hưng Yên    900.000 ₫   40.100 ₫
#
#                                 Return Positive_review        Ship_on_time  \
# 0                           Được đổi ý             97%                 91%
# 1                           Được đổi ý             97%                 91%
# 2                           Được đổi ý             97%                 91%
# 3                           Được đổi ý             97%                 91%
# 4                           Được đổi ý             97%                 91%
# ..                                 ...             ...                 ...
# 115   3 ngày trả hàng cho Nhà bán hàng             94%  Không đủ thông tin
# 116   3 ngày trả hàng cho Nhà bán hàng             96%                100%
# 117  Không áp dụng chính sách bảo hành             95%                 99%
# 118  Không áp dụng chính sách bảo hành             96%                100%
# 119   3 ngày trả hàng cho Nhà bán hàng             95%                 25%
#
#           Rate_response One_star Two_star Three_star Four_star Five_star
# 0                  100%        0        0          0         0         0
# 1                  100%        0        0          0         0         0
# 2                  100%        0        0          0         0         1
# 3                  100%        0        0          0         0         0
# 4                  100%        0        0          0         0         1
# ..                  ...      ...      ...        ...       ...       ...
# 115  Không đủ thông tin        0        0          0         0         1
# 116                100%        0        0          1         2        42
# 117                100%        0        0          0         0         9
# 118  Không đủ thông tin        0        1          0         0         3
# 119  Không đủ thông tin      N/A      N/A        N/A       N/A       N/A
#
# [120 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# Type                 0
# Title                0
# Links                0
# Price                0
# Discount_percent    10
# Sold                21
# Preview             20
# Location             0
# Original            15
# Ship_price          10
# Return               9
# Positive_review      9
# Ship_on_time         9
# Rate_response        9
# One_star             0
# Two_star             0
# Three_star           0
# Four_star            0
# Five_star            0
# dtype: int64
