# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=30&q=gi%C3%A0y%20d%C3%A9p&spm=a2o4n.home-vn.search.d_go"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [56:22<00:00, 28.19s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("Page10_12.csv", index = True)
df
# Out:
#          Type                                              Title  \
# 0    giày dép  Dép Trẻ Em Dép Khủng Long Hoạt Hình Đế Mềm Chố...
# 1    giày dép  Dép Quai Ngang Đế Dày Chống Trượt Thời Trang H...
# 2    giày dép  (Giá tận xưởng) Dép chữ C unisex nam nữ bền đẹ...
# 3    giày dép             Giày đi nước mùa hè dép nhựa nam GS188
# 4    giày dép  Dép xỏ ngón Nam 2024 Phiên Bản Hàn Quốc Giày Đ...
# ..        ...                                                ...
# 115  giày dép  BW Dép Sandal Đế Xuồng Dày Dặn Chống Thấm Nước...
# 116  giày dép  FUJIN Mới năm sandal nữ dép quai hậu nữ...
# 117  giày dép  Giày sandal bít mũi đi mưa nam nữ 3 quai ngang...
# 118  giày dép  ㍿┅۞ LJ8.15 STARRY dép đế xuồng sandal gia...
# 119  giày dép  Dép Cao Su Việt Nam Cho Nam Giày Đi Biển Trơn ...
#
#                                                  Links      Price  \
# 0    https://www.lazada.vn/products/dep-tre-em-dep-...   35.100 ₫
# 1    https://www.lazada.vn/products/dep-quai-ngang-...   47.723 ₫
# 2    https://www.lazada.vn/products/gia-tan-xuong-d...   32.000 ₫
# 3    https://www.lazada.vn/products/giay-di-nuoc-mu...   59.000 ₫
# 4    https://www.lazada.vn/products/dep-xo-ngon-nam...   19.000 ₫
# ..                                                 ...        ...
# 115  https://www.lazada.vn/products/bw-dep-sandal-d...  107.264 ₫
# 116  https://www.lazada.vn/products/fujin-moi-nam-s...   43.576 ₫
# 117  https://www.lazada.vn/products/giay-sandal-bit...   97.000 ₫
# 118  https://www.lazada.vn/products/lj815-starry-de...  109.036 ₫
# 119  https://www.lazada.vn/products/dep-cao-su-viet...   56.120 ₫
#
#     Discount_percent        Sold Preview     Location   Original Ship_price  \
# 0            10% Off  387 Đã bán   (144)  Hồ Chí Minh   41.000 ₫   17.000 ₫
# 1            52% Off  277 Đã bán    (77)   Nước ngoài   99.000 ₫
# 2            54% Off   83 Đã bán    (20)  Hồ Chí Minh   69.000 ₫   16.500 ₫
# 3            61% Off  519 Đã bán   (123)       Hà Nội  151.000 ₫   45.100 ₫
# 4            50% Off  547 Đã bán    (99)   Nước ngoài   38.000 ₫
# ..               ...         ...     ...          ...        ...        ...
# 115          46% Off   67 Đã bán    (16)   Nước ngoài  199.000 ₫
# 116          58% Off    9 Đã bán     (4)   Nước ngoài  104.000 ₫
# 117          11% Off   49 Đã bán     (7)  Hồ Chí Minh       None   19.600 ₫
# 118          48% Off    6 Đã bán     (2)   Nước ngoài  209.685 ₫   17.000 ₫
# 119          15% Off   25 Đã bán     (9)   Nước ngoài   66.000 ₫   17.000 ₫
#
#                                 Return Positive_review        Ship_on_time  \
# 0    Không áp dụng chính sách bảo hành             95%                 93%
# 1    Không áp dụng chính sách bảo hành             97%  Không đủ thông tin
# 2     3 ngày trả hàng cho Nhà bán hàng             93%                 92%
# 3     3 ngày trả hàng cho Nhà bán hàng             97%                 99%
# 4    Không áp dụng chính sách bảo hành             96%  Không đủ thông tin
# ..                                 ...             ...                 ...
# 115  Không áp dụng chính sách bảo hành             94%  Không đủ thông tin
# 116  Không áp dụng chính sách bảo hành             98%  Không đủ thông tin
# 117   3 ngày trả hàng cho Nhà bán hàng             95%                 99%
# 118  Không áp dụng chính sách bảo hành             73%                 97%
# 119  Không áp dụng chính sách bảo hành             95%                 95%
#
#           Rate_response One_star Two_star Three_star Four_star Five_star
# 0                   98%        0        1          2         4       137
# 1                  100%        2        0          4         3        69
# 2                  100%        0        0          1         0        19
# 3                   88%        1        1          2         7       113
# 4                  100%        0        0          0         1        98
# ..                  ...      ...      ...        ...       ...       ...
# 115                100%        0        0          0         1        15
# 116                100%        0        0          0         0         4
# 117                 33%        0        0          1         2        11
# 118  Không đủ thông tin        0        1          0         0         1
# 119                100%        1        0          0         0         8
#
# [120 rows x 19 columns]
