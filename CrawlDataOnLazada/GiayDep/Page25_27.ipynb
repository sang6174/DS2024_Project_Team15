# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=10&q=gi%C3%A0y"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [1:03:18<00:00, 31.66s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("Page25_27.csv", index = True)
df
# Out:
#      Type                                              Title  \
# 0    giày  Wenzhou High Quality Genuine Leather Thick Sol...
# 1    giày  Business Casual Leather Shoes Fashionable And ...
# 2    giày  Popular New Bean Shoes Lefu Shoes Men'S Small ...
# 3    giày  Qiaoyuluo mùa thu Giày nam thoáng khí mới Giày...
# 4    giày  YUNGUANG Giày trắng nhỏ màu trắng dành cho nữ ...
# ..    ...                                                ...
# 115  giày  Giày Nam Giày Mùa Hè Giày Chạy Bộ Thể Thao Thư...
# 116  giày  Yierku 【Free Shipping Miễn phí vận chuyển】Giày...
# 117  giày  Giày Vải Bắc Kinh Cũ Mẫu Mới Xuân Thu Giày Vải...
# 118  giày  Giày Nam Giày Sành Điệu Instagram Bố Già Siêu ...
# 119  giày  Mary-jane Giày cổ điển Muffin đế dày phụ nữ mớ...
#
#                                                  Links      Price  \
# 0    https://www.lazada.vn/products/wenzhou-high-qu...      135 ₫
# 1    https://www.lazada.vn/products/business-casual...      658 ₫
# 2    https://www.lazada.vn/products/popular-new-bea...      592 ₫
# 3    https://www.lazada.vn/products/qiaoyuluo-mua-t...  113.000 ₫
# 4    https://www.lazada.vn/products/yunguang-giay-t...   86.000 ₫
# ..                                                 ...        ...
# 115  https://www.lazada.vn/products/giay-nam-giay-m...  158.240 ₫
# 116  https://www.lazada.vn/products/yierku-free-shi...  144.000 ₫
# 117  https://www.lazada.vn/products/giay-vai-bac-ki...   90.160 ₫
# 118  https://www.lazada.vn/products/giay-nam-giay-s...  130.000 ₫
# 119  https://www.lazada.vn/products/mary-jane-giay-...   99.500 ₫
#
#     Discount_percent        Sold Preview     Location   Original Ship_price  \
# 0            83% Off  209 Đã bán    None   Nước ngoài      801 ₫   17.000 ₫
# 1            40% Off  148 Đã bán    None   Nước ngoài    1.096 ₫   17.000 ₫
# 2            40% Off   56 Đã bán    None   Nước ngoài      986 ₫   17.000 ₫
# 3            57% Off  667 Đã bán   (278)   Nước ngoài  262.000 ₫
# 4            59% Off  884 Đã bán   (426)   Nước ngoài  208.000 ₫
# ..               ...         ...     ...          ...        ...        ...
# 115          47% Off   28 Đã bán    (15)  Hồ Chí Minh       None       None
# 116          49% Off   71 Đã bán    (14)   Nước ngoài       None       None
# 117          77% Off  633 Đã bán   (190)  Hồ Chí Minh       None       None
# 118             None  322 Đã bán    (92)   Nước ngoài       None   17.000 ₫
# 119          57% Off  671 Đã bán   (268)   Bình Dương  230.000 ₫   32.200 ₫
#
#                                 Return     Positive_review  \
# 0    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 1    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 2    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 3                           Được đổi ý                 98%
# 4                           Được đổi ý                 99%
# ..                                 ...                 ...
# 115                               None                None
# 116                               None                None
# 117                               None                None
# 118  Không áp dụng chính sách bảo hành                 95%
# 119   3 ngày trả hàng cho Nhà bán hàng                 97%
#
#            Ship_on_time       Rate_response One_star Two_star Three_star  \
# 0    Không đủ thông tin  Không đủ thông tin        0        0          0
# 1    Không đủ thông tin  Không đủ thông tin        0        0          0
# 2    Không đủ thông tin  Không đủ thông tin        0        0          0
# 3    Không đủ thông tin                100%        3        2          3
# 4    Không đủ thông tin                100%        1        1          4
# ..                  ...                 ...      ...      ...        ...
# 115                None                None      N/A      N/A        N/A
# 116                None                None      N/A      N/A        N/A
# 117                 96%                100%        3        0          1
# 118                 93%                 99%        0        0          0
# 119                100%                100%        1        0          0
#
#     Four_star Five_star
# 0           0         0
# 1           0         0
# 2           0         0
# 3           6       264
# 4           7       413
# ..        ...       ...
# 115       N/A       N/A
# 116       N/A       N/A
# 117         2       184
# 118         1        91
# 119        12       255
#
# [120 rows x 19 columns]
