# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=4&q=gi%C3%A0y%20d%C3%A9p&spm=a2o4n.home-vn.search.d_go"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [1:07:52<00:00, 33.94s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("lazada1_1.csv", index = True)
df
# Out:
#          Type                                              Title  \
# 0    giày dép  (Giá tận xưởng) Dép chữ C unisex nam nữ bền đẹ...
# 1    giày dép  Men'S Flip Flops, Beach Shoes, Casual Shoes, S...
# 2    giày dép  [FACOTA CHÍNH HÃNG] Giày Dép Sandals Facota Na...
# 3    giày dép  Matsuke thick soled sandals with a high-end fe...
# 4    giày dép  Dép sandal nữ đế mềm phong cách Hàn Quốc thời ...
# ..        ...                                                ...
# 115  giày dép  Dép cho nam Kasut selipar Lelaki virus dewasa ...
# 116  giày dép  Yierku【Free Shipping Miễn phí vận chuyển】 2023...
# 117  giày dép  [HCM]GIÀY SANDAL NAM ISKULLS By Aries - Đen Bạ...
# 118  giày dép                   Dép lê nữ mùa hè Ins Dép lê WA71
# 119  giày dép  Dép Lê Nữ Mùa Hè 2024 Dép Lê Lười Đế Bằng Đi B...
#
#                                                  Links      Price  \
# 0    https://www.lazada.vn/products/gia-tan-xuong-d...   32.000 ₫
# 1    https://www.lazada.vn/products/mens-flip-flops...      174 ₫
# 2    https://www.lazada.vn/products/facota-chinh-ha...  208.662 ₫
# 3    https://www.lazada.vn/products/matsuke-thick-s...       83 ₫
# 4    https://www.lazada.vn/products/dep-sandal-nu-d...   12.000 ₫
# ..                                                 ...        ...
# 115  https://www.lazada.vn/products/dep-cho-nam-kas...  178.245 ₫
# 116  https://www.lazada.vn/products/yierkufree-ship...  105.000 ₫
# 117  https://www.lazada.vn/products/hcmgiay-sandal-...   55.000 ₫
# 118  https://www.lazada.vn/products/dep-le-nu-mua-h...   57.822 ₫
# 119  https://www.lazada.vn/products/dep-le-nu-mua-h...   27.645 ₫
#
#     Discount_percent         Sold Preview     Location   Original Ship_price  \
# 0            54% Off    83 Đã bán    (20)  Hồ Chí Minh   69.000 ₫   16.500 ₫
# 1            40% Off     8 Đã bán    None   Nước ngoài      290 ₫   17.000 ₫
# 2            46% Off   885 Đã bán   (127)  Hồ Chí Minh  389.000 ₫   18.300 ₫
# 3            40% Off         None    None   Nước ngoài      138 ₫   17.000 ₫
# 4            73% Off   640 Đã bán   (173)   Nước ngoài   45.000 ₫
# ..               ...          ...     ...          ...        ...        ...
# 115          49% Off    43 Đã bán    (22)   Nước ngoài  349.000 ₫       None
# 116          46% Off    99 Đã bán    (43)   Nước ngoài  193.000 ₫
# 117          71% Off    53 Đã bán    (12)  Hồ Chí Minh  189.000 ₫   18.300 ₫
# 118          62% Off  1.7K Đã bán   (632)   Nước ngoài  153.000 ₫
# 119          58% Off     8 Đã bán     (5)   Nước ngoài   66.000 ₫
#
#                                 Return     Positive_review  \
# 0     3 ngày trả hàng cho Nhà bán hàng                 93%
# 1    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 2     3 ngày trả hàng cho Nhà bán hàng                 99%
# 3    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 4                           Được đổi ý                 90%
# ..                                 ...                 ...
# 115  Không áp dụng chính sách bảo hành                 95%
# 116                         Được đổi ý                 94%
# 117   3 ngày trả hàng cho Nhà bán hàng                 94%
# 118  Không áp dụng chính sách bảo hành                 96%
# 119  Không áp dụng chính sách bảo hành                 95%
#
#            Ship_on_time       Rate_response One_star Two_star Three_star  \
# 0                   92%                100%        0        0          1
# 1    Không đủ thông tin  Không đủ thông tin        0        0          0
# 2                   99%                 50%      N/A      N/A        N/A
# 3    Không đủ thông tin  Không đủ thông tin        0        0          0
# 4    Không đủ thông tin                100%        4        2          3
# ..                  ...                 ...      ...      ...        ...
# 115                 93%                100%        0        0          2
# 116  Không đủ thông tin                100%        1        1          4
# 117  Không đủ thông tin                100%        2        0          0
# 118  Không đủ thông tin                100%       12        3         11
# 119  Không đủ thông tin                100%        0        0          0
#
#     Four_star Five_star
# 0           0        18
# 1           0         0
# 2         N/A       N/A
# 3           0         0
# 4           5       159
# ..        ...       ...
# 115         0        20
# 116         4        34
# 117         1        10
# 118        25       581
# 119         1         4
#
# [120 rows x 19 columns]
