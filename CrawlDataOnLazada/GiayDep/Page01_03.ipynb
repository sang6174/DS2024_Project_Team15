# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=1&q=gi%C3%A0y%20d%C3%A9p&spm=a2o4n.home-vn.search.d_go"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [1:07:59<00:00, 34.00s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("Page01_03.csv", index = True)
df
# Out:
#          Type                                              Title  \
# 0    giày dép  Xăng đan diwa lốp nhún bèo cho nữ dành cho ngư...
# 1    giày dép            Summer Thick Sole Roman Women'S Sandals
# 2    giày dép  (Giá tận xưởng) Dép chữ C unisex nam nữ bền đẹ...
# 3    giày dép  Dép sandal nữ đế mềm phong cách Hàn Quốc thời ...
# 4    giày dép  Summer New Fashion Trend Thick Sole Outdoor Tw...
# ..        ...                                                ...
# 115  giày dép  [FACOTA CHÍNH HÃNG] Giày Dép Sandals Facota Na...
# 116  giày dép  Dép Sandal quai hậu đế cao 4 cm staycool siêu ...
# 117  giày dép  Dép sandal xăng đan thanh lịch cho bé đi học đ...
# 118  giày dép  FUJIN Mới năm sandal nữ dép quai hậu nữ...
# 119  giày dép  Dép cao gót thời trang mũi vuông nhúm gót tam ...
#
#                                                  Links      Price  \
# 0    https://www.lazada.vn/products/xang-dan-diwa-l...      174 ₫
# 1    https://www.lazada.vn/products/summer-thick-so...      371 ₫
# 2    https://www.lazada.vn/products/gia-tan-xuong-d...   32.000 ₫
# 3    https://www.lazada.vn/products/dep-sandal-nu-d...   12.000 ₫
# 4    https://www.lazada.vn/products/summer-new-fash...      383 ₫
# ..                                                 ...        ...
# 115  https://www.lazada.vn/products/facota-chinh-ha...  210.267 ₫
# 116  https://www.lazada.vn/products/dep-sandal-quai...   45.000 ₫
# 117  https://www.lazada.vn/products/dep-sandal-xang...   71.026 ₫
# 118  https://www.lazada.vn/products/fujin-moi-nam-s...   43.576 ₫
# 119  https://www.lazada.vn/products/dep-cao-got-tho...   59.000 ₫
#
#     Discount_percent        Sold Preview     Location   Original Ship_price  \
# 0               None  494 Đã bán    None   Nước ngoài       None       None
# 1            40% Off  319 Đã bán    None   Nước ngoài      618 ₫   17.000 ₫
# 2            54% Off   83 Đã bán    (20)  Hồ Chí Minh   69.000 ₫   16.500 ₫
# 3            73% Off  640 Đã bán   (173)   Nước ngoài   45.000 ₫
# 4            40% Off  250 Đã bán    None   Nước ngoài      638 ₫   17.000 ₫
# ..               ...         ...     ...          ...        ...        ...
# 115          34% Off  606 Đã bán   (141)  Hồ Chí Minh  320.000 ₫   18.300 ₫
# 116          50% Off   27 Đã bán     (5)     Nam Định   90.000 ₫   37.700 ₫
# 117          21% Off   98 Đã bán    (41)       Hà Nội   90.000 ₫   32.700 ₫
# 118          58% Off    9 Đã bán     (4)   Nước ngoài  104.000 ₫
# 119          72% Off   42 Đã bán     (2)  Hồ Chí Minh       None       None
#
#                                 Return     Positive_review  \
# 0    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 1    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 2     3 ngày trả hàng cho Nhà bán hàng                 93%
# 3                           Được đổi ý                 90%
# 4    Không áp dụng chính sách bảo hành  Không đủ thông tin
# ..                                 ...                 ...
# 115   3 ngày trả hàng cho Nhà bán hàng                 99%
# 116   3 ngày trả hàng cho Nhà bán hàng                 94%
# 117   3 ngày trả hàng cho Nhà bán hàng                 98%
# 118  Không áp dụng chính sách bảo hành                 98%
# 119                               None                None
#
#            Ship_on_time       Rate_response One_star Two_star Three_star  \
# 0    Không đủ thông tin  Không đủ thông tin        0        0          0
# 1    Không đủ thông tin  Không đủ thông tin        0        0          0
# 2                   92%                100%        0        0          1
# 3    Không đủ thông tin                100%        4        2          3
# 4    Không đủ thông tin  Không đủ thông tin        0        0          0
# ..                  ...                 ...      ...      ...        ...
# 115                 99%                 50%      N/A      N/A        N/A
# 116                100%                 50%        0        0          0
# 117                 99%                 91%        0        0          1
# 118  Không đủ thông tin                100%        0        0          0
# 119                None                None      N/A      N/A        N/A
#
#     Four_star Five_star
# 0           0         0
# 1           0         0
# 2           0        19
# 3           5       159
# 4           0         0
# ..        ...       ...
# 115       N/A       N/A
# 116         0         5
# 117         0        40
# 118         0         4
# 119       N/A       N/A
#
# [120 rows x 19 columns]
