# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=20&q=gi%C3%A0y%20d%C3%A9p&spm=a2o4n.home-vn.search.d_go"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [1:03:29<00:00, 31.75s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("lazada1_2.csv", index = True)
df
# Out:
#          Type                                              Title  \
# 0    giày dép  Xăng đan diwa lốp nhún bèo cho nữ dành cho ngư...
# 1    giày dép            Summer Thick Sole Roman Women'S Sandals
# 2    giày dép  Dép sandal nữ đế mềm phong cách Hàn Quốc thời ...
# 3    giày dép  Summer New Fashion Trend Thick Sole Outdoor Tw...
# 4    giày dép  Dép xỏ ngón Nam 2024 Phiên Bản Hàn Quốc Giày Đ...
# ..        ...                                                ...
# 115  giày dép  Qiaoyuluo nam dép đi trong nhà phong cách dày ...
# 116  giày dép  Dép Lê Hoạt Hình Có Lỗ Bít Mũi Trẻ Em Giày Tập...
# 117  giày dép  BW Dép Sandal Đế Xuồng Dày Dặn Chống Thấm Nước...
# 118  giày dép  [FACOTA CHÍNH HÃNG] Giày Dép Sandals Facota Na...
# 119  giày dép  Dép Adida.s đúc nguyên khối siêu nhẹ dép quai ...
#
#                                                  Links      Price  \
# 0    https://www.lazada.vn/products/xang-dan-diwa-l...      174 ₫
# 1    https://www.lazada.vn/products/summer-thick-so...      371 ₫
# 2    https://www.lazada.vn/products/dep-sandal-nu-d...   12.000 ₫
# 3    https://www.lazada.vn/products/summer-new-fash...      383 ₫
# 4    https://www.lazada.vn/products/dep-xo-ngon-nam...   19.000 ₫
# ..                                                 ...        ...
# 115  https://www.lazada.vn/products/qiaoyuluo-nam-d...   79.000 ₫
# 116  https://www.lazada.vn/products/dep-le-hoat-hin...   31.280 ₫
# 117  https://www.lazada.vn/products/bw-dep-sandal-d...  107.264 ₫
# 118  https://www.lazada.vn/products/facota-chinh-ha...  208.662 ₫
# 119  https://www.lazada.vn/products/dep-adidas-duc-...   71.230 ₫
#
#     Discount_percent        Sold Preview     Location  Original Ship_price  \
# 0               None  494 Đã bán    None   Nước ngoài      None       None
# 1            40% Off  319 Đã bán    None   Nước ngoài     618 ₫   17.000 ₫
# 2            73% Off  640 Đã bán   (173)   Nước ngoài  45.000 ₫
# 3            40% Off  250 Đã bán    None   Nước ngoài      None       None
# 4            50% Off  547 Đã bán    (99)   Nước ngoài  38.000 ₫
# ..               ...         ...     ...          ...       ...        ...
# 115          44% Off   29 Đã bán     (3)   Nước ngoài      None       None
# 116          11% Off   11 Đã bán     (3)  Hồ Chí Minh      None       None
# 117          46% Off   67 Đã bán    (16)   Nước ngoài      None       None
# 118          46% Off  721 Đã bán    (98)  Hồ Chí Minh      None       None
# 119          53% Off  146 Đã bán    (47)       Hà Nội      None       None
#
#                                 Return     Positive_review  \
# 0    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 1    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 2                           Được đổi ý                 90%
# 3                                 None                None
# 4    Không áp dụng chính sách bảo hành                 96%
# ..                                 ...                 ...
# 115                               None                None
# 116                               None                None
# 117                               None                None
# 118                               None                None
# 119                               None                None
#
#            Ship_on_time       Rate_response One_star Two_star Three_star  \
# 0    Không đủ thông tin  Không đủ thông tin        0        0          0
# 1    Không đủ thông tin  Không đủ thông tin        0        0          0
# 2    Không đủ thông tin                100%        4        2          3
# 3                  None                None        0        0          0
# 4    Không đủ thông tin                100%        0        0          0
# ..                  ...                 ...      ...      ...        ...
# 115                None                None      N/A      N/A        N/A
# 116                None                None      N/A      N/A        N/A
# 117                None                None      N/A      N/A        N/A
# 118                None                None      N/A      N/A        N/A
# 119                None                None      N/A      N/A        N/A
#
#     Four_star Five_star
# 0           0         0
# 1           0         0
# 2           5       159
# 3           0         0
# 4           1        98
# ..        ...       ...
# 115       N/A       N/A
# 116       N/A       N/A
# 117       N/A       N/A
# 118       N/A       N/A
# 119       N/A       N/A
#
# [120 rows x 19 columns]
