# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=50&q=gi%C3%A0y%20d%C3%A9p&spm=a2o4n.home-vn.search.d_go"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [1:06:43<00:00, 33.36s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("lazada1_4.csv", index = True)
df
# Out:
#          Type                                              Title  \
# 0    giày dép  Men'S Flip Flops, Beach Shoes, Casual Shoes, S...
# 1    giày dép            Summer Thick Sole Roman Women'S Sandals
# 2    giày dép  Summer New Fashion Trend Thick Sole Outdoor Tw...
# 3    giày dép  Dép Quai Ngang Đế Dày Chống Trượt Thời Trang H...
# 4    giày dép  Dép sandal nữ đế mềm phong cách Hàn Quốc thời ...
# ..        ...                                                ...
# 115  giày dép  Dép nam da bò cao cấp, dép nam qua hậu đế cao ...
# 116  giày dép  TTITDEE Dép NALL Hot Nam Thoáng Khí EVA Dép Xă...
# 117  giày dép  Laochra Dép nam nam mùa hè của Slide thương hi...
# 118  giày dép  Dép cho phong cách nam mới kasut selipar lelak...
# 119  giày dép  Xăng Đan Da Chống Trượt Thường Ngày Mùa Hè Dép...
#
#                                                  Links      Price  \
# 0    https://www.lazada.vn/products/mens-flip-flops...      174 ₫
# 1    https://www.lazada.vn/products/summer-thick-so...      371 ₫
# 2    https://www.lazada.vn/products/summer-new-fash...      383 ₫
# 3    https://www.lazada.vn/products/dep-quai-ngang-...   47.723 ₫
# 4    https://www.lazada.vn/products/dep-sandal-nu-d...   12.000 ₫
# ..                                                 ...        ...
# 115  https://www.lazada.vn/products/dep-nam-da-bo-c...   99.000 ₫
# 116  https://www.lazada.vn/products/ttitdee-dep-nal...   98.000 ₫
# 117  https://www.lazada.vn/products/laochra-dep-nam...  107.589 ₫
# 118  https://www.lazada.vn/products/dep-cho-phong-c...  129.427 ₫
# 119  https://www.lazada.vn/products/xang-dan-da-cho...  116.422 ₫
#
#     Discount_percent        Sold Preview    Location   Original Ship_price  \
# 0            40% Off    8 Đã bán    None  Nước ngoài      290 ₫   17.000 ₫
# 1            40% Off  319 Đã bán    None  Nước ngoài      618 ₫   17.000 ₫
# 2            40% Off  250 Đã bán    None  Nước ngoài      638 ₫   17.000 ₫
# 3            52% Off  277 Đã bán    (77)  Nước ngoài   99.000 ₫
# 4            73% Off  640 Đã bán   (173)  Nước ngoài   45.000 ₫
# ..               ...         ...     ...         ...        ...        ...
# 115          34% Off  180 Đã bán    (49)      Hà Nội  149.000 ₫   38.000 ₫
# 116          67% Off   22 Đã bán     (9)  Nước ngoài  300.000 ₫   17.000 ₫
# 117          63% Off  137 Đã bán    (46)  Nước ngoài  289.560 ₫   17.000 ₫
# 118          41% Off   39 Đã bán     (8)  Nước ngoài  285.000 ₫       None
# 119          59% Off   82 Đã bán    (23)  Nước ngoài  331.000 ₫   17.000 ₫
#
#                                 Return     Positive_review  \
# 0    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 1    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 2    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 3    Không áp dụng chính sách bảo hành                 97%
# 4                           Được đổi ý                 90%
# ..                                 ...                 ...
# 115   3 ngày trả hàng cho Nhà bán hàng                 94%
# 116  Không áp dụng chính sách bảo hành                 98%
# 117                         Được đổi ý                 95%
# 118  Không áp dụng chính sách bảo hành                 95%
# 119  Không áp dụng chính sách bảo hành                 96%
#
#            Ship_on_time       Rate_response One_star Two_star Three_star  \
# 0    Không đủ thông tin  Không đủ thông tin        0        0          0
# 1    Không đủ thông tin  Không đủ thông tin        0        0          0
# 2    Không đủ thông tin  Không đủ thông tin        0        0          0
# 3    Không đủ thông tin                100%        2        0          4
# 4    Không đủ thông tin                100%        4        2          3
# ..                  ...                 ...      ...      ...        ...
# 115                 99%                100%        2        1          1
# 116                100%                100%        0        0          0
# 117                 94%                 44%        1        1          3
# 118                 93%                100%        1        0          1
# 119                100%  Không đủ thông tin        0        0          0
#
#     Four_star Five_star
# 0           0         0
# 1           0         0
# 2           0         0
# 3           3        69
# 4           5       159
# ..        ...       ...
# 115         3        42
# 116         0         9
# 117         0        40
# 118         0         6
# 119         1        22
#
# [120 rows x 19 columns]
