# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=5&q=gi%C3%A0y"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [1:10:35<00:00, 35.30s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("lazada1_7.csv", index = True)
df
# Out:
#      Type                                              Title  \
# 0    giày  Fashionable New Casual Men'S Shoes Sports Shoe...
# 1    giày  Wenzhou High Quality Genuine Leather Thick Sol...
# 2    giày  Business Casual Leather Shoes Fashionable And ...
# 3    giày  🔥HOT SALE🔥 BW Giày Nữ Mẫu Mới Mùa Xuân Hè 2024...
# 4    giày  Qiaoyuluo mùa thu Giày nam thoáng khí mới Giày...
# ..    ...                                                ...
# 115  giày  Kuangaokai【Free Shipping Miễn phí vận chuyển】 ...
# 116  giày  Pioneer Land Mall Giày lười thể thao đế bằng m...
# 117  giày  [ 𝐒𝐀𝐋𝐄 ĐẬ𝐌 ] Giày 𝐉𝐨𝐫𝐝𝐚𝐧 hight, Giày 𝐚𝐢𝐫 𝐉𝐨𝐫𝐝𝐚...
# 118  giày  Giày lười mùa xuân và mùa thu phong cách anh c...
# 119  giày  Skechers Nam Giày Thể Thao Tập Gym, Đi Học, Đi...
#
#                                                  Links      Price  \
# 0    https://www.lazada.vn/products/fashionable-new...      135 ₫
# 1    https://www.lazada.vn/products/wenzhou-high-qu...      135 ₫
# 2    https://www.lazada.vn/products/business-casual...      658 ₫
# 3    https://www.lazada.vn/products/hot-sale-bw-gia...   46.818 ₫
# 4    https://www.lazada.vn/products/qiaoyuluo-mua-t...  113.000 ₫
# ..                                                 ...        ...
# 115  https://www.lazada.vn/products/kuangaokaifree-...  160.000 ₫
# 116  https://www.lazada.vn/products/pioneer-land-ma...  133.000 ₫
# 117  https://www.lazada.vn/products/da-giay-hight-g...  229.000 ₫
# 118  https://www.lazada.vn/products/giay-luoi-mua-x...   24.305 ₫
# 119  https://www.lazada.vn/products/skechers-nam-gi...  845.000 ₫
#
#     Discount_percent         Sold Preview    Location     Original Ship_price  \
# 0           100% Off    43 Đã bán    None  Nước ngoài    458.952 ₫   17.000 ₫
# 1            83% Off   209 Đã bán    None  Nước ngoài        801 ₫   17.000 ₫
# 2            40% Off   148 Đã bán    None  Nước ngoài      1.096 ₫   17.000 ₫
# 3            47% Off  1.0K Đã bán   (304)  Nước ngoài     89.000 ₫
# 4            57% Off   667 Đã bán   (278)  Nước ngoài    262.000 ₫
# ..               ...          ...     ...         ...          ...        ...
# 115          21% Off  3.0K Đã bán   (647)  Nước ngoài    225.000 ₫
# 116          31% Off   150 Đã bán   (105)  Nước ngoài    379.000 ₫
# 117          49% Off   135 Đã bán    (33)     Phú Thọ    450.000 ₫   37.700 ₫
# 118          75% Off     5 Đã bán    None     Long An     97.220 ₫   32.200 ₫
# 119          50% Off   130 Đã bán    (60)  Bình Dương  1.690.000 ₫   44.100 ₫
#
#                                         Return     Positive_review  \
# 0            Không áp dụng chính sách bảo hành  Không đủ thông tin
# 1            Không áp dụng chính sách bảo hành  Không đủ thông tin
# 2            Không áp dụng chính sách bảo hành  Không đủ thông tin
# 3    Bảo hành bởi Nhà sản xuất quốc tế 6 tháng                 94%
# 4                                   Được đổi ý                 98%
# ..                                         ...                 ...
# 115          Không áp dụng chính sách bảo hành                 96%
# 116          Không áp dụng chính sách bảo hành                 97%
# 117           3 ngày trả hàng cho Nhà bán hàng                 90%
# 118           3 ngày trả hàng cho Nhà bán hàng                 98%
# 119                                 Được đổi ý                 98%
#
#            Ship_on_time       Rate_response One_star Two_star Three_star  \
# 0    Không đủ thông tin  Không đủ thông tin        0        0          0
# 1    Không đủ thông tin  Không đủ thông tin        0        0          0
# 2    Không đủ thông tin  Không đủ thông tin        0        0          0
# 3    Không đủ thông tin                100%        0        2          8
# 4    Không đủ thông tin                100%        3        2          3
# ..                  ...                 ...      ...      ...        ...
# 115  Không đủ thông tin                100%       12        5         17
# 116  Không đủ thông tin                100%        1        0          0
# 117  Không đủ thông tin  Không đủ thông tin        3        0          1
# 118                100%                100%        0        0          0
# 119                 94%                100%        1        0          0
#
#     Four_star Five_star
# 0           0         0
# 1           0         0
# 2           0         0
# 3           8       285
# 4           6       263
# ..        ...       ...
# 115        15       598
# 116         1       103
# 117         3        26
# 118         0         0
# 119         3        57
#
# [120 rows x 19 columns]
