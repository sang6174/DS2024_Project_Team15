# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=40&q=gi%C3%A0y%20d%C3%A9p&spm=a2o4n.home-vn.search.d_go"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details:   0%|          | 0/120 [00:00<?, ?it/s]
# Crawling product details: 100%|██████████| 120/120 [56:40<00:00, 28.34s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
driver.close()

# %%
# save to csv
df.to_csv("lazada1_5.csv", index = True)
df
# Out:
#          Type                                              Title  \
# 0    giày dép  Xăng đan diwa lốp nhún bèo cho nữ dành cho ngư...
# 1    giày dép            Summer Thick Sole Roman Women'S Sandals
# 2    giày dép  Dép xỏ ngón thường ngày cho nam | Xăng đan dis...
# 3    giày dép  Dép xỏ ngón Nam 2024 Phiên Bản Hàn Quốc Giày Đ...
# 4    giày dép  Summer New Fashion Trend Thick Sole Outdoor Tw...
# ..        ...                                                ...
# 115  giày dép  Giày Lỗ Dừa Nam Dép Lê Bít Mũi Chống Thối Chốn...
# 116  giày dép  Dép Sandal Đế Mềm Chống Trượt Thời Trang Hàn Q...
# 117  giày dép  Giày Có Lỗ Thoáng Khí Mẫu Mới Mùa Hè 2024 Giày...
# 118  giày dép  Dép Lê Việt Nam Chống Nước Mùa Hè Dép Sục Thời...
# 119  giày dép  Dép Lê Nữ Mùa Hè 2024 Dép Lê Lười Đế Bằng Đi B...
#
#                                                  Links     Price  \
# 0    https://www.lazada.vn/products/xang-dan-diwa-l...     174 ₫
# 1    https://www.lazada.vn/products/summer-thick-so...     371 ₫
# 2    https://www.lazada.vn/products/dep-xo-ngon-thu...     146 ₫
# 3    https://www.lazada.vn/products/dep-xo-ngon-nam...  19.000 ₫
# 4    https://www.lazada.vn/products/summer-new-fash...     383 ₫
# ..                                                 ...       ...
# 115  https://www.lazada.vn/products/giay-lo-dua-nam...  81.880 ₫
# 116  https://www.lazada.vn/products/dep-sandal-de-m...  55.000 ₫
# 117  https://www.lazada.vn/products/giay-co-lo-thoa...  90.000 ₫
# 118  https://www.lazada.vn/products/dep-le-viet-nam...  64.400 ₫
# 119  https://www.lazada.vn/products/dep-le-nu-mua-h...  27.645 ₫
#
#     Discount_percent         Sold Preview     Location   Original Ship_price  \
# 0               None   494 Đã bán    None   Nước ngoài       None       None
# 1            40% Off   319 Đã bán    None   Nước ngoài      618 ₫   17.000 ₫
# 2               None  3.3K Đã bán    None   Nước ngoài       None       None
# 3            50% Off   547 Đã bán    (99)   Nước ngoài   38.000 ₫
# 4            40% Off   250 Đã bán    None   Nước ngoài      638 ₫   17.000 ₫
# ..               ...          ...     ...          ...        ...        ...
# 115          37% Off    83 Đã bán    (21)  Hồ Chí Minh  171.000 ₫   17.000 ₫
# 116          44% Off     6 Đã bán     (2)   Nước ngoài   99.000 ₫
# 117             None         None    None  Hồ Chí Minh       None   17.000 ₫
# 118           8% Off    27 Đã bán     (8)   Nước ngoài   81.000 ₫   17.000 ₫
# 119          58% Off     8 Đã bán     (5)   Nước ngoài   66.000 ₫
#
#                                 Return     Positive_review  \
# 0    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 1    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 2    Không áp dụng chính sách bảo hành  Không đủ thông tin
# 3    Không áp dụng chính sách bảo hành                 96%
# 4    Không áp dụng chính sách bảo hành  Không đủ thông tin
# ..                                 ...                 ...
# 115  Không áp dụng chính sách bảo hành                 95%
# 116  Không áp dụng chính sách bảo hành                 97%
# 117  Không áp dụng chính sách bảo hành                 96%
# 118  Không áp dụng chính sách bảo hành                 94%
# 119  Không áp dụng chính sách bảo hành                 95%
#
#            Ship_on_time       Rate_response One_star Two_star Three_star  \
# 0    Không đủ thông tin  Không đủ thông tin        0        0          0
# 1    Không đủ thông tin  Không đủ thông tin        0        0          0
# 2    Không đủ thông tin  Không đủ thông tin        0        0          0
# 3    Không đủ thông tin                100%        0        0          0
# 4    Không đủ thông tin  Không đủ thông tin        0        0          0
# ..                  ...                 ...      ...      ...        ...
# 115                 95%                100%        0        1          0
# 116  Không đủ thông tin                100%        0        0          0
# 117                 95%                100%        0        0          0
# 118                 96%                100%        0        1          0
# 119  Không đủ thông tin                100%        0        0          0
#
#     Four_star Five_star
# 0           0         0
# 1           0         0
# 2           0         0
# 3           1        98
# 4           0         0
# ..        ...       ...
# 115         1        19
# 116         0         2
# 117         0         0
# 118         0         7
# 119         1         4
#
# [120 rows x 19 columns]
