# %%
import numpy as np
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm
import funcs

# %%
driver = funcs.initializeChrome()

# %%
link = "https://www.lazada.vn/catalog/?page=1&q=qu%E1%BA%A7n%20%C3%A1o%20nam"
dataProducts = funcs.getDataInNPage(driver, link, 3)
# Out:
# Collecting data:
#
# Crawling data page 1 successful.
# Crawling data page 2 successful.
# Crawling data page 3 successful.
# Stopped in page 3.

# %%
df = pd.DataFrame(dataProducts)

# %%
df.head()
# Out:
#           Type                                              Title  \
# 0  quần áo nam  Bộ Đồ Nam Mùa Hè Áo Thun Tay Lỡ Unisex Quần Sh...
# 1  quần áo nam  ĐỒ BỘ THỂ THAO DONT STOP TRÀ SỮA SET ĐỒ BỘ THỂ...
# 2  quần áo nam  ĐỒ BỘ THỂ THAO GẤU TRÚC PAN.DA SET ĐỒ BỘ THỂ T...
# 3  quần áo nam  [ Hoàn Tiền 15% ] Set Bộ Quần Áo Thun Hè Nam M...
# 4  quần áo nam  Bộ thun nam cổ tròn mặc hè chất liệu vân gạo...
#
#                                                Links     Price  \
# 0  https://www.lazada.vn/products/bo-do-nam-mua-h...  55.000 ₫
# 1  https://www.lazada.vn/products/do-bo-the-thao-...  29.799 ₫
# 2  https://www.lazada.vn/products/do-bo-the-thao-...  32.000 ₫
# 3  https://www.lazada.vn/products/hoan-tien-15-se...  28.698 ₫
# 4  https://www.lazada.vn/products/bo-thun-nam-co-...  39.082 ₫
#
#   Discount_percent         Sold Preview     Location
# 0          61% Off  5.9K Đã bán  (1661)       Hà Nội
# 1          57% Off  2.4K Đã bán   (624)  Hồ Chí Minh
# 2          54% Off  7.3K Đã bán  (1502)  Hồ Chí Minh
# 3          63% Off  2.9K Đã bán  (1578)       Hà Nội
# 4          60% Off   405 Đã bán   (170)       Hà Nội

# %%
detailProducts = {
    "Original": [],
    "Ship_price": [],
    "Return": [],
    "Positive_review": [],
    "Ship_on_time": [],
    "Rate_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

# %%
# Create a progress bar to track the crawl process
for link in tqdm(df.Links, desc="Crawling product details"):
    details = funcs.getDetailItems(driver, link)
    for key in detailProducts.keys():
        detailProducts[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 120/120 [1:04:17<00:00, 32.15s/it]

# %%
# add columns to df
for key, value in detailProducts.items():
    df[key] = value

# %%
# save to csv
df.to_csv("lazada_5.csv", index = True)
df.head()
# Out:
#           Type                                              Title  \
# 0  quần áo nam  Bộ Đồ Nam Mùa Hè Áo Thun Tay Lỡ Unisex Quần Sh...
# 1  quần áo nam  ĐỒ BỘ THỂ THAO DONT STOP TRÀ SỮA SET ĐỒ BỘ THỂ...
# 2  quần áo nam  ĐỒ BỘ THỂ THAO GẤU TRÚC PAN.DA SET ĐỒ BỘ THỂ T...
# 3  quần áo nam  [ Hoàn Tiền 15% ] Set Bộ Quần Áo Thun Hè Nam M...
# 4  quần áo nam  Bộ thun nam cổ tròn mặc hè chất liệu vân gạo...
#
#                                                Links     Price  \
# 0  https://www.lazada.vn/products/bo-do-nam-mua-h...  55.000 ₫
# 1  https://www.lazada.vn/products/do-bo-the-thao-...  29.799 ₫
# 2  https://www.lazada.vn/products/do-bo-the-thao-...  32.000 ₫
# 3  https://www.lazada.vn/products/hoan-tien-15-se...  28.698 ₫
# 4  https://www.lazada.vn/products/bo-thun-nam-co-...  39.082 ₫
#
#   Discount_percent         Sold Preview     Location   Original Ship_price  \
# 0          61% Off  5.9K Đã bán  (1661)       Hà Nội  142.200 ₫   32.700 ₫
# 1          57% Off  2.4K Đã bán   (624)  Hồ Chí Minh  150.000 ₫   16.500 ₫
# 2          54% Off  7.3K Đã bán  (1502)  Hồ Chí Minh  120.000 ₫   16.500 ₫
# 3          63% Off  2.9K Đã bán  (1578)       Hà Nội   90.000 ₫   38.000 ₫
# 4          60% Off   405 Đã bán   (170)       Hà Nội   98.000 ₫   38.000 ₫
#
#                              Return Positive_review Ship_on_time  \
# 0  3 ngày trả hàng cho Nhà bán hàng             87%         100%
# 1  3 ngày trả hàng cho Nhà bán hàng             88%          99%
# 2  3 ngày trả hàng cho Nhà bán hàng             88%          99%
# 3  3 ngày trả hàng cho Nhà bán hàng             68%         100%
# 4  3 ngày trả hàng cho Nhà bán hàng             65%         100%
#
#   Rate_response One_star Two_star Three_star Four_star Five_star
# 0           95%       81       28         51        88      1413
# 1          100%      N/A      N/A        N/A       N/A       N/A
# 2          100%      126       46         65       109      1156
# 3           77%      144       23         10         9      1392
# 4           77%       61        3          0         0       106
