# %%
import pandas as pd

# %%
#List of CSV file to combined
csv_files = [
    'lazada.csv',
    'lazada_1.csv',
    'lazada_2.csv',
    'lazada_3.csv',
    'lazada_4.csv',
    'lazada_5.csv',
    'lazada_6.csv',
    'lazada_7.csv'
]

#Read and combine CSV files into a DataFrame
combined_df = pd.concat([pd.read_csv(file) for file in csv_files])
combined_df = combined_df.drop(columns=(['Unnamed: 0']))
combined_df.head(3)
# Out:
#       Type                                              Title  \
# 0  quần áo  Đồ Bộ Nữ Đi Chơi Chất Thun Mát Size M - dưới 5...
# 1  quần áo  Đồ ngủ nữ pijama mặc nhà bộ ngủ hoạt hình cộc ...
# 2  quần áo  [Đủ size 35-55 cân] Sét bộ 3 món áo 2 dây+áo c...
#
#                                                Links     Price  \
# 0  https://www.lazada.vn/products/do-bo-nu-di-cho...  35.891 ₫
# 1  https://www.lazada.vn/products/do-ngu-nu-pijam...  25.000 ₫
# 2  https://www.lazada.vn/products/du-size-35-55-c...  79.000 ₫
#
#   Discount_percent         Sold Preview     Location   Original Ship_price  \
# 0          64% Off  3.0K Đã bán  (1022)  Hồ Chí Minh  100.000 ₫   16.500 ₫
# 1          50% Off   907 Đã bán   (241)  Hồ Chí Minh   71.998 ₫   16.500 ₫
# 2          43% Off   961 Đã bán   (260)       Hà Nội  139.000 ₫   32.700 ₫
#
#                              Return Positive_review Ship_on_time  \
# 0  3 ngày trả hàng cho Nhà bán hàng             97%         100%
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 119
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              1200 non-null   object
#  1   Title             1200 non-null   object
#  2   Links             1200 non-null   object
#  3   Price             1200 non-null   object
#  4   Discount_percent  1145 non-null   object
#  5   Sold              1169 non-null   object
#  6   Preview           1163 non-null   object
#  7   Location          1200 non-null   object
#  8   Original          1135 non-null   object
#  9   Ship_price        1066 non-null   object
#  10  Return            1184 non-null   object
#  11  Positive_review   1185 non-null   object
#  12  Ship_on_time      1187 non-null   object
#  13  Rate_response     1187 non-null   object
#  14  One_star          1112 non-null   float64
#  15  Two_star          1112 non-null   float64
# ...

# %%
#Rename colums
combined_df = combined_df.rename(columns={
    'Links': 'Link',
    'Price': 'Price_sale',
    'Discount_percent': 'Sale_off',
    'Sold': 'Total_sold',
    'Original': 'Price_original',
    'Positive_review': 'Sale_rating',
    'Rate_response': 'Chat_response'
})

combined_df.to_csv("quanao.csv", index=False)
