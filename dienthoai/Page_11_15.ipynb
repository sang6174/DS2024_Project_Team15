# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %% [markdown]
# ##### 1. Load function **get_Data_On_Page, get_Data_Detail_1Product** from file **Main_function.py**

# %%
from Main_function import get_Data_On_Page, get_Data_Detail_1Product

# URL Lazada: dienthoai, sort price high to low
path = 'chromedriver.exe'
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %% [markdown]
# #### 2. Crawl data

# %% [markdown]
# ##### Crawl features displayed on the outside of the page

# %%
#Empty list, to store data from all pages
all_data = []

#Nhận link cho 5 page: 11-15 và sau đó đưa vào vòng lặp for cùng với hàm get_Data_On_Page
for page in tqdm(range(11, 16), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?page={page}&q=dien%20thoai&sort=pricedesc'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    dienthoai = get_Data_On_Page(driver)
    all_data.append(dienthoai)
# Out:
# Crawling pages: 100%|██████████| 5/5 [03:22<00:00, 40.42s/it]

# %%
#Combine into a DataFrame
data_11_15 = pd.concat(all_data, ignore_index=True)
data_11_15.index = np.arange(1, len(data_11_15)+1)
data_11_15
# Out:
#            Type                                              Title  \
# 1    dien thoai  Điện thoại Samsung Galaxy S23 Ultra - Mầu độc ...
# 2    dien thoai  Điện Thoại Realme 11 Pro+ 5G trang bị camera 2...
# 3    dien thoai                              Điện thoại 12 pro max
# 4    dien thoai  Điện thoại Samsung Galaxy S23 FE (2023) - 128G...
# 5    dien thoai    Điện thoại 13 pro max fullbox bản quốc tế 256GB
# ..          ...                                                ...
# 196  dien thoai  Điện Thoại OPPO A18 (4GB/128GB) - Hàng Chính Hãng
# 197  dien thoai  điện thoại Chính Hãng Giá siêu rẻ IPHONES Plus...
# 198  dien thoai  Điện thoại Samsung Galaxy M14 5G 4GB|128GB ; 4...
# 199  dien thoai  Điện Thoại Samsung A05s 4GB/128GB - Hàng Chính...
# 200  dien thoai  Điện thoại di động Redmi 13C 6GB/128GB - Chính...
#
#                                                   Link    Price_sale  \
# 1    https://www.lazada.vn/products/dien-thoai-sams...  28.791.000 ₫
# 2    https://www.lazada.vn/products/dien-thoai-real...  14.990.000 ₫
# 3    https://www.lazada.vn/products/dien-thoai-12-p...  13.400.000 ₫
# 4    https://www.lazada.vn/products/dien-thoai-sams...  12.200.000 ₫
# 5    https://www.lazada.vn/products/dien-thoai-13-p...  11.800.000 ₫
# ..                                                 ...           ...
# 196  https://www.lazada.vn/products/dien-thoai-oppo...   3.270.000 ₫
# 197  https://www.lazada.vn/products/dien-thoai-chin...   3.240.179 ₫
# 198  https://www.lazada.vn/products/dien-thoai-sams...   3.200.000 ₫
# 199  https://www.lazada.vn/products/dien-thoai-sams...   3.139.000 ₫
# 200  https://www.lazada.vn/products/dien-thoai-di-d...   3.120.000 ₫
#
#                            Sale_off  Total_sold Preview     Location
# 1                           10% Off        None    None       Hà Nội
# 2                              None        None     (1)  Hồ Chí Minh
# 3                              None        None    None     Nam Định
# 4                           18% Off        None    None       Hà Nội
# 5                              None        None    None     Nam Định
# ..                              ...         ...     ...          ...
# 196  LazFlash Sale,kết thúc sau 13h  123 Đã bán    (46)  Hồ Chí Minh
# 197                            None   88 Đã bán    (30)  Hồ Chí Minh
# 198                            None    6 Đã bán    None       Hà Nội
# 199                            None   12 Đã bán     (2)      Bến Tre
# 200                            None  221 Đã bán   (118)  Hồ Chí Minh
#
# [200 rows x 8 columns]

# %% [markdown]
# ##### Crawl features data for each product

# %%
#Initialize dictionary to store details for all products
detail_products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(data_11_15.Link, desc = "Crawling product details"):
    details = get_Data_Detail_1Product(driver, link)
    for key in detail_products.keys():
        detail_products[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 200/200 [1:14:45<00:00, 22.43s/it]

# %%
#Add columns to combined_data
for key, value in detail_products.items():
    data_11_15[key] = value

# Convert to csv
data_11_15.to_csv("Page_11_15.csv", index=False)
data_11_15
# Out:
#            Type                                              Title  \
# 1    dien thoai  Điện thoại Samsung Galaxy S23 Ultra - Mầu độc ...
# 2    dien thoai  Điện Thoại Realme 11 Pro+ 5G trang bị camera 2...
# 3    dien thoai                              Điện thoại 12 pro max
# 4    dien thoai  Điện thoại Samsung Galaxy S23 FE (2023) - 128G...
# 5    dien thoai    Điện thoại 13 pro max fullbox bản quốc tế 256GB
# ..          ...                                                ...
# 196  dien thoai  Điện Thoại OPPO A18 (4GB/128GB) - Hàng Chính Hãng
# 197  dien thoai  điện thoại Chính Hãng Giá siêu rẻ IPHONES Plus...
# 198  dien thoai  Điện thoại Samsung Galaxy M14 5G 4GB|128GB ; 4...
# 199  dien thoai  Điện Thoại Samsung A05s 4GB/128GB - Hàng Chính...
# 200  dien thoai  Điện thoại di động Redmi 13C 6GB/128GB - Chính...
#
#                                                   Link    Price_sale  \
# 1    https://www.lazada.vn/products/dien-thoai-sams...  28.791.000 ₫
# 2    https://www.lazada.vn/products/dien-thoai-real...  14.990.000 ₫
# 3    https://www.lazada.vn/products/dien-thoai-12-p...  13.400.000 ₫
# 4    https://www.lazada.vn/products/dien-thoai-sams...  12.200.000 ₫
# 5    https://www.lazada.vn/products/dien-thoai-13-p...  11.800.000 ₫
# ..                                                 ...           ...
# 196  https://www.lazada.vn/products/dien-thoai-oppo...   3.270.000 ₫
# 197  https://www.lazada.vn/products/dien-thoai-chin...   3.240.179 ₫
# 198  https://www.lazada.vn/products/dien-thoai-sams...   3.200.000 ₫
# 199  https://www.lazada.vn/products/dien-thoai-sams...   3.139.000 ₫
# 200  https://www.lazada.vn/products/dien-thoai-di-d...   3.120.000 ₫
#
#                            Sale_off  Total_sold Preview     Location  \
# 1                           10% Off        None    None       Hà Nội
# 2                              None        None     (1)  Hồ Chí Minh
# 3                              None        None    None     Nam Định
# 4                           18% Off        None    None       Hà Nội
# 5                              None        None    None     Nam Định
# ..                              ...         ...     ...          ...
# 196  LazFlash Sale,kết thúc sau 13h  123 Đã bán    (46)  Hồ Chí Minh
# 197                            None   88 Đã bán    (30)  Hồ Chí Minh
# 198                            None    6 Đã bán    None       Hà Nội
# 199                            None   12 Đã bán     (2)      Bến Tre
# 200                            None  221 Đã bán   (118)  Hồ Chí Minh
#
#     Price_original Ship_price                     Return Sale_rating  \
# 1     31.990.200 ₫             30 Ngày Trả Hàng Miễn Phí         92%
# 2             None   Miễn phí                       None        100%
# 3             None   37.700 ₫                       None         87%
# 4     16.890.500 ₫             30 Ngày Trả Hàng Miễn Phí         92%
# 5             None   37.700 ₫                       None         87%
# ..             ...        ...                        ...         ...
# 196    3.990.000 ₫   18.300 ₫  30 Ngày Trả Hàng Miễn Phí        100%
# 197      449.000 ₫   16.500 ₫                       None         97%
# 198    4.990.000 ₫             30 Ngày Trả Hàng Miễn Phí         94%
# 199    3.990.000 ₫   28.700 ₫  30 Ngày Trả Hàng Miễn Phí         99%
# 200    3.490.000 ₫   18.300 ₫                       None         98%
#
#            Ship_on_time Chat_response One_star Two_star Three_star Four_star  \
# 1    Không đủ thông tin           33%      [0]      [0]        [0]       [0]
# 2    Không đủ thông tin          100%      [0]      [0]        [0]       [0]
# 3                   80%          100%      [0]      [0]        [0]       [0]
# 4    Không đủ thông tin           33%      [0]      [0]        [0]       [0]
# 5                   80%          100%      [0]      [0]        [0]       [0]
# ..                  ...           ...      ...      ...        ...       ...
# 196                100%          100%      [0]      [0]        [1]       [0]
# 197                 98%          100%      [0]      [0]        [0]       [0]
# 198  Không đủ thông tin           83%      [0]      [0]        [0]       [0]
# 199                100%          100%      [0]      [0]        [0]       [0]
# 200                100%           92%      [0]      [0]        [1]       [0]
#
#     Five_star
# 1         [0]
# 2         [1]
# 3         [0]
# 4         [0]
# 5         [0]
# ..        ...
# 196      [45]
# 197      [31]
# 198       [0]
# 199       [3]
# 200     [117]
#
# [200 rows x 19 columns]
