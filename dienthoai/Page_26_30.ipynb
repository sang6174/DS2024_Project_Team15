# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %% [markdown]
# ##### 1. Load function **get_Data_On_Page, get_Data_Detail_1Product** from file **Main_function.py**

# %%
from Main_function import get_Data_On_Page, get_Data_Detail_1Product

# URL Lazada: dienthoai, sort price high to low
path = 'chromedriver.exe'
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %% [markdown]
# #### 2. Crawl data

# %% [markdown]
# ##### Crawl features displayed on the outside of the page

# %%
#Empty list, to store data from all pages
all_data = []

#Nhận link cho 5 page: 26-30 và sau đó đưa vào vòng lặp for cùng với hàm get_Data_On_Page
for page in tqdm(range(26,31), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?page={page}&q=dien%20thoai&sort=pricedesc'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    dienthoai = get_Data_On_Page(driver)
    all_data.append(dienthoai)
# Out:
# Crawling pages: 100%|██████████| 5/5 [02:52<00:00, 34.52s/it]

# %%
#Combine into a DataFrame
data_26_30 = pd.concat(all_data, ignore_index=True)
data_26_30.index = np.arange(1, len(data_26_30)+1)
data_26_30
# Out:
#            Type                                              Title  \
# 1    dien thoai  Điện thoại OPPO FIND N3 (16GB/512GB) - Hàng ch...
# 2    dien thoai  Điện thoại Samsung Galaxy S24 Ultra 12GB/1TB -...
# 3    dien thoai  [NGÀY CUỐI SALE TO] iPhone 15 Pro - Hàng Chính...
# 4    dien thoai  [GIÁ SỐC CHỈ 6.6] [TẶNG Buds2 Pro + Duo Charge...
# 5    dien thoai  [NGÀY CUỐI SALE TO] iPhone 15 Plus - Hàng Chín...
# ..          ...                                                ...
# 196  dien thoai  Blackview BV9300 PRO điện thoại siêu bền(CHỐNG...
# 197  dien thoai  Blackview BV9300 Pro (2 màn hình,CPU Helio G99...
# 198  dien thoai  Điện thoại 8849 Tank Mini thông minh chắc chắn...
# 199  dien thoai  Điện thoại Oukitel WP33 Pro 5G Chính hãng mới ...
# 200  dien thoai  Điện thoại siêu bền 8849 TANK MINI( chống nước...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/dien-thoai-oppo...  41.990.000 ₫     None
# 2    https://www.lazada.vn/products/dien-thoai-sams...  37.590.001 ₫     None
# 3    https://www.lazada.vn/products/ngay-cuoi-sale-...  34.590.000 ₫     None
# 4    https://www.lazada.vn/products/gia-soc-chi-66-...  31.990.000 ₫     None
# 5    https://www.lazada.vn/products/ngay-cuoi-sale-...  31.990.000 ₫     None
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/blackview-bv930...   8.490.000 ₫     None
# 197  https://www.lazada.vn/products/blackview-bv930...   8.490.000 ₫     None
# 198  https://www.lazada.vn/products/dien-thoai-8849...   8.490.000 ₫     None
# 199  https://www.lazada.vn/products/dien-thoai-ouki...   8.490.000 ₫     None
# 200  https://www.lazada.vn/products/dien-thoai-sieu...   8.480.000 ₫     None
#
#       Total_sold Preview     Location
# 1      11 Đã bán    None  Hồ Chí Minh
# 2      25 Đã bán     (2)  Hồ Chí Minh
# 3    1.7K Đã bán   (347)  Hồ Chí Minh
# 4    1.5K Đã bán   (358)  Hồ Chí Minh
# 5     714 Đã bán   (151)     Bắc Ninh
# ..           ...     ...          ...
# 196         None    None  Hồ Chí Minh
# 197         None    None  Hồ Chí Minh
# 198         None    None  Hồ Chí Minh
# 199         None    None      Đà Nẵng
# 200         None    None  Hồ Chí Minh
#
# [200 rows x 8 columns]

# %% [markdown]
# ##### Crawl features data for each product

# %%
#Initialize dictionary to store details for all products
detail_products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(data_26_30.Link, desc = "Crawling product details"):
    details = get_Data_Detail_1Product(driver, link)
    for key in detail_products.keys():
        detail_products[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 200/200 [1:37:24<00:00, 29.22s/it]

# %%
#Add columns to combined_data
for key, value in detail_products.items():
    data_26_30[key] = value

# Convert to csv
data_26_30.to_csv("Page_26_30.csv", index=False)
data_26_30
# Out:
#            Type                                              Title  \
# 1    dien thoai  Điện thoại OPPO FIND N3 (16GB/512GB) - Hàng ch...
# 2    dien thoai  Điện thoại Samsung Galaxy S24 Ultra 12GB/1TB -...
# 3    dien thoai  [NGÀY CUỐI SALE TO] iPhone 15 Pro - Hàng Chính...
# 4    dien thoai  [GIÁ SỐC CHỈ 6.6] [TẶNG Buds2 Pro + Duo Charge...
# 5    dien thoai  [NGÀY CUỐI SALE TO] iPhone 15 Plus - Hàng Chín...
# ..          ...                                                ...
# 196  dien thoai  Blackview BV9300 PRO điện thoại siêu bền(CHỐNG...
# 197  dien thoai  Blackview BV9300 Pro (2 màn hình,CPU Helio G99...
# 198  dien thoai  Điện thoại 8849 Tank Mini thông minh chắc chắn...
# 199  dien thoai  Điện thoại Oukitel WP33 Pro 5G Chính hãng mới ...
# 200  dien thoai  Điện thoại siêu bền 8849 TANK MINI( chống nước...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/dien-thoai-oppo...  41.990.000 ₫     None
# 2    https://www.lazada.vn/products/dien-thoai-sams...  37.590.001 ₫     None
# 3    https://www.lazada.vn/products/ngay-cuoi-sale-...  34.590.000 ₫     None
# 4    https://www.lazada.vn/products/gia-soc-chi-66-...  31.990.000 ₫     None
# 5    https://www.lazada.vn/products/ngay-cuoi-sale-...  31.990.000 ₫     None
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/blackview-bv930...   8.490.000 ₫     None
# 197  https://www.lazada.vn/products/blackview-bv930...   8.490.000 ₫     None
# 198  https://www.lazada.vn/products/dien-thoai-8849...   8.490.000 ₫     None
# 199  https://www.lazada.vn/products/dien-thoai-ouki...   8.490.000 ₫     None
# 200  https://www.lazada.vn/products/dien-thoai-sieu...   8.480.000 ₫     None
#
#       Total_sold Preview     Location Price_original Ship_price  \
# 1      11 Đã bán    None  Hồ Chí Minh   44.990.000 ₫   20.100 ₫
# 2      25 Đã bán     (2)  Hồ Chí Minh   44.490.000 ₫
# 3    1.7K Đã bán   (347)  Hồ Chí Minh   37.999.000 ₫    5.500 ₫
# 4    1.5K Đã bán   (358)  Hồ Chí Minh   33.990.000 ₫   16.500 ₫
# 5     714 Đã bán   (151)     Bắc Ninh   34.990.000 ₫    5.500 ₫
# ..           ...     ...          ...            ...        ...
# 196         None    None  Hồ Chí Minh    9.990.000 ₫   Miễn phí
# 197         None    None  Hồ Chí Minh           None       None
# 198         None    None  Hồ Chí Minh    8.990.000 ₫   18.300 ₫
# 199         None    None      Đà Nẵng    9.990.000 ₫   Miễn phí
# 200         None    None  Hồ Chí Minh    8.990.000 ₫   Miễn phí
#
#                         Return Sale_rating        Ship_on_time  \
# 1    30 Ngày Trả Hàng Miễn Phí         99%                100%
# 2    30 Ngày Trả Hàng Miễn Phí         91%  Không đủ thông tin
# 3    30 Ngày Trả Hàng Miễn Phí         94%                 99%
# 4    30 Ngày Trả Hàng Miễn Phí         91%                 99%
# 5    30 Ngày Trả Hàng Miễn Phí         94%                 99%
# ..                         ...         ...                 ...
# 196                       None         97%                100%
# 197                       None        None                None
# 198                       None         85%  Không đủ thông tin
# 199                       None         97%                100%
# 200                       None         97%                100%
#
#           Chat_response One_star Two_star Three_star Four_star Five_star
# 1                   92%      [0]      [0]        [0]       [0]       [0]
# 2                  100%      [0]      [0]        [0]       [0]       [2]
# 3                  100%      [1]      [0]        [0]       [1]     [345]
# 4                  100%      [2]      [0]        [1]       [0]     [356]
# 5                  100%      [1]      [0]        [1]       [0]     [149]
# ..                  ...      ...      ...        ...       ...       ...
# 196                 33%      [0]      [0]        [0]       [0]       [0]
# 197                None      [0]      [0]        [0]       [0]       [0]
# 198                100%      [0]      [0]        [0]       [0]       [0]
# 199  Không đủ thông tin      [0]      [0]        [0]       [0]       [0]
# 200                 33%      [0]      [0]        [0]       [0]       [0]
#
# [200 rows x 19 columns]
