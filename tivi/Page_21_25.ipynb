# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %% [markdown]
# ##### 1. Load function **get_Data_On_Page, get_Data_Detail_1Product** from file **Main_function.py**

# %%
from Main_function import get_Data_On_Page, get_Data_Detail_1Product

# URL Lazada: tivi
path = 'chromedriver.exe'
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %% [markdown]
# #### 2. Crawl data

# %% [markdown]
# ##### Crawl features displayed on the outside of the page

# %%
#Empty list, to store data from all pages
all_data = []

#Nhận link cho 5 page: 21-25 và sau đó đưa vào vòng lặp for cùng với hàm get_Data_On_Page
for page in tqdm(range(21, 26), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?_keyori=ss&from=search_history&page={page}&q=tivi&spm=a2o4n.home-vn.search.6.4d423bdcueaQbu&sugg=tivi_4_1'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    tivi = get_Data_On_Page(driver)
    all_data.append(tivi)
# Out:
# Crawling pages: 100%|██████████| 5/5 [02:30<00:00, 30.05s/it]

# %%
#Combine into a DataFrame
data_21_25 = pd.concat(all_data, ignore_index=True)
data_21_25.index = np.arange(1, len(data_21_25)+1)
data_21_25
# Out:
#      Type                                              Title  \
# 1    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 55 inch U...
# 2    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 50 inch U...
# 3    tivi  Google Tivi TOSHIBA 50 inch 50C350LP, Smart TV...
# 4    tivi  [Giao hàng và lắp đặt miễn phí toàn quốc] 55BU...
# 5    tivi  [Giao hàng và lắp đặt miễn phí toàn quốc] 43Q6...
# ..    ...                                                ...
# 196  tivi  Thanh lý tivi TOSHIBA 32inch chính hãng,hình ả...
# 197  tivi  [6.6 HOTDEAL 14490K ] Google Tivi TCL 4K 65inc...
# 198  tivi  Google Tivi TCL 4K 50 inch 50P745 - Bảo hành 2...
# 199  tivi  Smart Google Tivi Coocaa 4K 70 inch 70C9 - Hàn...
# 200  tivi  [6.6 HOTDEAL 27990K - Tặng Loa S522W cho 20 đơ...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/sale-66-smart-t...   8.589.000 ₫  33% Off
# 2    https://www.lazada.vn/products/sale-66-smart-t...   8.189.000 ₫  28% Off
# 3    https://www.lazada.vn/products/google-tivi-tos...   7.451.000 ₫  49% Off
# 4    https://www.lazada.vn/products/giao-hang-va-la...   8.920.000 ₫  47% Off
# 5    https://www.lazada.vn/products/giao-hang-va-la...   8.600.000 ₫  46% Off
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/thanh-ly-tivi-t...   1.500.000 ₫   5% Off
# 197  https://www.lazada.vn/products/66-hotdeal-1449...  14.490.000 ₫     None
# 198  https://www.lazada.vn/products/google-tivi-tcl...   7.090.000 ₫  41% Off
# 199  https://www.lazada.vn/products/smart-google-ti...  10.689.000 ₫  33% Off
# 200  https://www.lazada.vn/products/66-hotdeal-2799...  37.995.000 ₫   5% Off
#
#       Total_sold Preview     Location
# 1    1.1K Đã bán   (235)  Hồ Chí Minh
# 2     103 Đã bán    (26)  Hồ Chí Minh
# 3      78 Đã bán    (33)  Hồ Chí Minh
# 4      23 Đã bán     (5)  Hồ Chí Minh
# 5      15 Đã bán     (2)  Hồ Chí Minh
# ..           ...     ...          ...
# 196         None     (1)       Hà Nội
# 197         None    None  Hồ Chí Minh
# 198         None    None  Hồ Chí Minh
# 199         None    None       Hà Nội
# 200         None     (1)  Hồ Chí Minh
#
# [200 rows x 8 columns]

# %% [markdown]
# ##### Crawl features data for each product

# %%
#Initialize dictionary to store details for all products
detail_products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(data_21_25.Link, desc = "Crawling product details"):
    details = get_Data_Detail_1Product(driver, link)
    for key in detail_products.keys():
        detail_products[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 200/200 [1:44:41<00:00, 31.41s/it]

# %%
#Add columns to combined_data
for key, value in detail_products.items():
    data_21_25[key] = value

# Convert to csv
data_21_25.to_csv("Page_21_25.csv", index=False)
data_21_25
# Out:
#      Type                                              Title  \
# 1    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 55 inch U...
# 2    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 50 inch U...
# 3    tivi  Google Tivi TOSHIBA 50 inch 50C350LP, Smart TV...
# 4    tivi  [Giao hàng và lắp đặt miễn phí toàn quốc] 55BU...
# 5    tivi  [Giao hàng và lắp đặt miễn phí toàn quốc] 43Q6...
# ..    ...                                                ...
# 196  tivi  Thanh lý tivi TOSHIBA 32inch chính hãng,hình ả...
# 197  tivi  [6.6 HOTDEAL 14490K ] Google Tivi TCL 4K 65inc...
# 198  tivi  Google Tivi TCL 4K 50 inch 50P745 - Bảo hành 2...
# 199  tivi  Smart Google Tivi Coocaa 4K 70 inch 70C9 - Hàn...
# 200  tivi  [6.6 HOTDEAL 27990K - Tặng Loa S522W cho 20 đơ...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/sale-66-smart-t...   8.589.000 ₫  33% Off
# 2    https://www.lazada.vn/products/sale-66-smart-t...   8.189.000 ₫  28% Off
# 3    https://www.lazada.vn/products/google-tivi-tos...   7.451.000 ₫  49% Off
# 4    https://www.lazada.vn/products/giao-hang-va-la...   8.920.000 ₫  47% Off
# 5    https://www.lazada.vn/products/giao-hang-va-la...   8.600.000 ₫  46% Off
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/thanh-ly-tivi-t...   1.500.000 ₫   5% Off
# 197  https://www.lazada.vn/products/66-hotdeal-1449...  14.490.000 ₫     None
# 198  https://www.lazada.vn/products/google-tivi-tcl...   7.090.000 ₫  41% Off
# 199  https://www.lazada.vn/products/smart-google-ti...  10.689.000 ₫  33% Off
# 200  https://www.lazada.vn/products/66-hotdeal-2799...  37.995.000 ₫   5% Off
#
#       Total_sold Preview     Location Price_original Ship_price  \
# 1    1.1K Đã bán   (235)  Hồ Chí Minh   12.900.000 ₫  159.200 ₫
# 2     103 Đã bán    (26)  Hồ Chí Minh   11.400.000 ₫  131.600 ₫
# 3      78 Đã bán    (33)  Hồ Chí Minh           None       None
# 4      23 Đã bán     (5)  Hồ Chí Minh   16.900.000 ₫
# 5      15 Đã bán     (2)  Hồ Chí Minh   15.900.000 ₫
# ..           ...     ...          ...            ...        ...
# 196         None     (1)       Hà Nội    1.580.000 ₫  198.200 ₫
# 197         None    None  Hồ Chí Minh           None   Miễn phí
# 198         None    None  Hồ Chí Minh   11.990.000 ₫
# 199         None    None       Hà Nội   15.990.000 ₫
# 200         None     (1)  Hồ Chí Minh   39.990.000 ₫   Miễn phí
#
#                         Return         Sale_rating        Ship_on_time  \
# 1    30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 2    30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 3                         None                None                None
# 4    30 Ngày Trả Hàng Miễn Phí                 99%  Không đủ thông tin
# 5    30 Ngày Trả Hàng Miễn Phí                 99%  Không đủ thông tin
# ..                         ...                 ...                 ...
# 196                       None                 91%                 90%
# 197  30 Ngày Trả Hàng Miễn Phí                 96%                100%
# 198  30 Ngày Trả Hàng Miễn Phí                 97%                 98%
# 199  30 Ngày Trả Hàng Miễn Phí    Nhà bán hàng mới  Không đủ thông tin
# 200  30 Ngày Trả Hàng Miễn Phí                 96%                100%
#
#     Chat_response One_star Two_star Three_star Four_star Five_star
# 1             94%      [1]      [0]        [0]       [2]     [232]
# 2             94%      [0]      [0]        [0]       [1]      [25]
# 3            None      [0]      [0]        [0]       [1]      [32]
# 4             97%      [0]      [0]        [0]       [0]       [5]
# 5             97%      [0]      [0]        [0]       [0]       [2]
# ..            ...      ...      ...        ...       ...       ...
# 196           96%      [0]      [0]        [0]       [0]       [1]
# 197          100%      [0]      [0]        [0]       [0]       [0]
# 198           89%      [0]      [0]        [0]       [0]       [0]
# 199          100%      [0]      [0]        [0]       [0]       [0]
# 200          100%      [0]      [0]        [0]       [0]       [1]
#
# [200 rows x 19 columns]
