# %%
import pandas as pd

# %%
#List of CSV file to combined
csv_files = [
    'Page_01.csv',
    'Page_02_05.csv',
    'Page_06_10.csv',
    'Page_11_15.csv',
    'Page_16_20.csv',
    'Page_21_25.csv',
    'Page_26_30.csv'
]

#Read and combine CSV files into a DataFrame
combined_df = pd.concat([pd.read_csv(file) for file in csv_files])

#Convert to "DienThoai.csv" file
combined_df.to_csv("Tivi.csv", index=False)

# %%
combined_df
# Out:
#      Type                                              Title  \
# 0    tivi  [NEW MODEL 2024] QLED TIVI 4K SAMSUNG 85 INCH ...
# 1    tivi  GIAO HÀ NỘI - Smart Tivi Casper 4K 50 inch 50U...
# 2    tivi  Thanh lý TIVI TOSHIBA 24inch đầy đủ cổng kết n...
# 3    tivi            Smart Tivi Coocaa Full HD 43 Inch 43S3U
# 4    tivi               Smart Tivi Samsung 32 inch UA32T4202
# ..    ...                                                ...
# 195  tivi  [6.6 HOTDEAL 4790K - Tặng Giá Treo TV DP243 ch...
# 196  tivi  SMART TIVI DARLING 32 INCH 32HD964S ( Internet...
# 197  tivi  Google Tivi TCL 4K 43 inch 43P745 - Bảo hành 2...
# 198  tivi  Smart Tivi Casper 43 Inch 43FX5200 [Hàng Chính...
# 199  tivi  Tivi Asanzo 32” model 32LS800 màn hình tràn vi...
#
#                                                   Link    Price_sale  \
# 0    https://www.lazada.vn/products/new-model-2024-...  64.690.000 ₫
# 1    https://www.lazada.vn/products/giao-ha-noi-sma...   5.389.000 ₫
# 2    https://www.lazada.vn/products/thanh-ly-tivi-t...     920.486 ₫
# 3    https://www.lazada.vn/products/smart-tivi-cooc...   3.989.000 ₫
# 4    https://www.lazada.vn/products/smart-tivi-sams...   4.689.000 ₫
# ..                                                 ...           ...
# 195  https://www.lazada.vn/products/66-hotdeal-4790...   5.390.000 ₫
# 196  https://www.lazada.vn/products/smart-tivi-darl...   2.730.000 ₫
# 197  https://www.lazada.vn/products/google-tivi-tcl...   6.150.000 ₫
# 198  https://www.lazada.vn/products/smart-tivi-casp...   4.250.000 ₫
# 199  https://www.lazada.vn/products/tivi-asanzo-32-...   2.650.000 ₫
#
#                               Sale_off  Total_sold Preview     Location  \
# 0                               6% Off         NaN     NaN  Hồ Chí Minh
# 1                              46% Off  130 Đã bán     (6)       Hà Nội
# 2                               3% Off   77 Đã bán    (26)       Hà Nội
# 3                              50% Off         NaN     NaN       Hà Nội
# 4                              41% Off   16 Đã bán     NaN       Hà Nội
# ..                                 ...         ...     ...          ...
# 195  LazFlash Sale,kết thúc sau 1 ngày   34 Đã bán     (9)  Hồ Chí Minh
# 196                                NaN         NaN     NaN  Hồ Chí Minh
# 197                                NaN         NaN     NaN  Hồ Chí Minh
# 198                                NaN         NaN     NaN       Hà Nội
# 199                                NaN         NaN     NaN  Hồ Chí Minh
#
#     Price_original Ship_price                     Return         Sale_rating  \
# 0     68.790.000 ₫        NaN                        NaN                100%
# 1      9.890.000 ₫        NaN                        NaN                100%
# 2        950.000 ₫  115.100 ₫                        NaN                 91%
# 3      7.990.000 ₫        NaN  30 Ngày Trả Hàng Miễn Phí    Nhà bán hàng mới
# 4      7.900.000 ₫        NaN                        NaN                100%
# ..             ...        ...                        ...                 ...
# 195    5.590.000 ₫   Miễn phí  30 Ngày Trả Hàng Miễn Phí                 96%
# 196            NaN   38.000 ₫                        NaN  Không đủ thông tin
# 197    9.990.000 ₫        NaN  30 Ngày Trả Hàng Miễn Phí                 97%
# 198    4.990.000 ₫  135.500 ₫                        NaN                100%
# 199            NaN   45.100 ₫                        NaN                100%
#
#            Ship_on_time       Chat_response One_star Two_star Three_star  \
# 0    Không đủ thông tin                100%    ['0']    ['0']      ['0']
# 1    Không đủ thông tin                100%    ['0']    ['0']      ['0']
# 2                   95%                 92%    ['0']    ['0']      ['0']
# 3    Không đủ thông tin                100%    ['0']    ['0']      ['0']
# 4    Không đủ thông tin                100%    ['0']    ['0']      ['0']
# ..                  ...                 ...      ...      ...        ...
# 195                100%                100%    ['2']    ['0']      ['0']
# 196  Không đủ thông tin  Không đủ thông tin    ['0']    ['0']      ['0']
# 197                 98%                 89%    ['0']    ['0']      ['0']
# 198                 40%  Không đủ thông tin    ['0']    ['0']      ['0']
# 199  Không đủ thông tin                 50%    ['0']    ['0']      ['0']
#
#     Four_star Five_star
# 0       ['0']     ['0']
# 1       ['0']     ['6']
# 2       ['2']    ['24']
# 3       ['0']     ['0']
# 4       ['0']     ['1']
# ..        ...       ...
# 195     ['0']     ['7']
# 196     ['0']     ['0']
# 197     ['0']     ['0']
# 198     ['0']     ['0']
# 199     ['0']     ['0']
#
# [1200 rows x 19 columns]
