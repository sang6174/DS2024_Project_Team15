# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %% [markdown]
# ##### 1. Load function **get_Data_On_Page, get_Data_Detail_1Product** from file **Main_function.py**

# %%
from Main_function import get_Data_On_Page, get_Data_Detail_1Product

# URL Lazada: tivi
path = 'chromedriver.exe'
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %% [markdown]
# #### 2. Crawl data

# %% [markdown]
# ##### Crawl features displayed on the outside of the page

# %%
#Empty list, to store data from all pages
all_data = []

#Nhận link cho 5 page: 11-15 và sau đó đưa vào vòng lặp for cùng với hàm get_Data_On_Page
for page in tqdm(range(11, 16), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?_keyori=ss&from=search_history&page={page}&q=tivi&spm=a2o4n.home-vn.search.6.4d423bdcueaQbu&sugg=tivi_4_1'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    tivi = get_Data_On_Page(driver)
    all_data.append(tivi)
# Out:
# Crawling pages:   0%|          | 0/5 [00:00<?, ?it/s]
# Crawling pages: 100%|██████████| 5/5 [02:24<00:00, 28.85s/it]

# %%
#Combine into a DataFrame
data_11_15 = pd.concat(all_data, ignore_index=True)
data_11_15.index = np.arange(1, len(data_11_15)+1)
data_11_15
# Out:
#      Type                                              Title  \
# 1    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 55 inch U...
# 2    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 50 inch U...
# 3    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 65 inch U...
# 4    tivi  [ 6.6 HOTDEAL 7290K - Tặng Giá Treo TV DP243 c...
# 5    tivi  [ 6.6 HOTDEAL 5290K - Tặng Giá Treo TV DP243 c...
# ..    ...                                                ...
# 196  tivi  Tivi Sony Mới Nhất 2024 - BRAVIA 3 43 Inch | 4...
# 197  tivi  Google Tivi TCL 4K 65 inch 65P745 - Hàng chính...
# 198  tivi           Tivi Led TCL 32S5400A 32 inch Android TV
# 199  tivi  [6.6 HOTDEAL 27990K - Tặng Loa S522W cho 20 đơ...
# 200  tivi  Smart TV TOSHIBA Google QLED Quantum Dot 4k UH...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/sale-66-smart-t...   8.589.000 ₫  33% Off
# 2    https://www.lazada.vn/products/sale-66-smart-t...   8.189.000 ₫  28% Off
# 3    https://www.lazada.vn/products/sale-66-smart-t...  11.589.000 ₫  27% Off
# 4    https://www.lazada.vn/products/66-hotdeal-7290...   7.847.300 ₫  44% Off
# 5    https://www.lazada.vn/products/66-hotdeal-5290...   6.492.000 ₫  38% Off
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/tivi-sony-moi-n...  14.790.000 ₫  15% Off
# 197  https://www.lazada.vn/products/google-tivi-tcl...  10.190.000 ₫     None
# 198  https://www.lazada.vn/products/tivi-led-tcl-32...   4.490.000 ₫  43% Off
# 199  https://www.lazada.vn/products/66-hotdeal-2799...  37.990.000 ₫   5% Off
# 200  https://www.lazada.vn/products/smart-tv-toshib...  11.271.000 ₫  44% Off
#
#       Total_sold Preview     Location
# 1    1.1K Đã bán   (234)  Hồ Chí Minh
# 2     103 Đã bán    (26)  Hồ Chí Minh
# 3     324 Đã bán    (64)  Hồ Chí Minh
# 4    1.7K Đã bán   (682)  Hồ Chí Minh
# 5     494 Đã bán   (142)  Hồ Chí Minh
# ..           ...     ...          ...
# 196         None     (1)   Bình Dương
# 197         None    None   Bình Dương
# 198         None    None       Hà Nội
# 199         None     (1)  Hồ Chí Minh
# 200     5 Đã bán     (3)  Hồ Chí Minh
#
# [200 rows x 8 columns]

# %% [markdown]
# ##### Crawl features data for each product

# %%
#Initialize dictionary to store details for all products
detail_products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(data_11_15.Link, desc = "Crawling product details"):
    details = get_Data_Detail_1Product(driver, link)
    for key in detail_products.keys():
        detail_products[key].append(details[key])
# Out:
# Crawling product details: 100%|██████████| 200/200 [1:46:09<00:00, 31.85s/it]

# %%
#Add columns to combined_data
for key, value in detail_products.items():
    data_11_15[key] = value

# Convert to csv
data_11_15.to_csv("Page_11_15.csv", index=False)
data_11_15
# Out:
#      Type                                              Title  \
# 1    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 55 inch U...
# 2    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 50 inch U...
# 3    tivi  [SALE 6.6] Smart Tivi Samsung 4K UHD 65 inch U...
# 4    tivi  [ 6.6 HOTDEAL 7290K - Tặng Giá Treo TV DP243 c...
# 5    tivi  [ 6.6 HOTDEAL 5290K - Tặng Giá Treo TV DP243 c...
# ..    ...                                                ...
# 196  tivi  Tivi Sony Mới Nhất 2024 - BRAVIA 3 43 Inch | 4...
# 197  tivi  Google Tivi TCL 4K 65 inch 65P745 - Hàng chính...
# 198  tivi           Tivi Led TCL 32S5400A 32 inch Android TV
# 199  tivi  [6.6 HOTDEAL 27990K - Tặng Loa S522W cho 20 đơ...
# 200  tivi  Smart TV TOSHIBA Google QLED Quantum Dot 4k UH...
#
#                                                   Link    Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/sale-66-smart-t...   8.589.000 ₫  33% Off
# 2    https://www.lazada.vn/products/sale-66-smart-t...   8.189.000 ₫  28% Off
# 3    https://www.lazada.vn/products/sale-66-smart-t...  11.589.000 ₫  27% Off
# 4    https://www.lazada.vn/products/66-hotdeal-7290...   7.847.300 ₫  44% Off
# 5    https://www.lazada.vn/products/66-hotdeal-5290...   6.492.000 ₫  38% Off
# ..                                                 ...           ...      ...
# 196  https://www.lazada.vn/products/tivi-sony-moi-n...  14.790.000 ₫  15% Off
# 197  https://www.lazada.vn/products/google-tivi-tcl...  10.190.000 ₫     None
# 198  https://www.lazada.vn/products/tivi-led-tcl-32...   4.490.000 ₫  43% Off
# 199  https://www.lazada.vn/products/66-hotdeal-2799...  37.990.000 ₫   5% Off
# 200  https://www.lazada.vn/products/smart-tv-toshib...  11.271.000 ₫  44% Off
#
#       Total_sold Preview     Location Price_original Ship_price  \
# 1    1.1K Đã bán   (234)  Hồ Chí Minh   12.900.000 ₫  159.200 ₫
# 2     103 Đã bán    (26)  Hồ Chí Minh           None       None
# 3     324 Đã bán    (64)  Hồ Chí Minh   15.900.000 ₫  258.200 ₫
# 4    1.7K Đã bán   (682)  Hồ Chí Minh   13.990.000 ₫   Miễn phí
# 5     494 Đã bán   (142)  Hồ Chí Minh   10.490.000 ₫   Miễn phí
# ..           ...     ...          ...            ...        ...
# 196         None     (1)   Bình Dương   17.400.000 ₫
# 197         None    None   Bình Dương           None
# 198         None    None       Hà Nội    7.900.000 ₫
# 199         None     (1)  Hồ Chí Minh   39.990.000 ₫   Miễn phí
# 200     5 Đã bán     (3)  Hồ Chí Minh   19.990.000 ₫  148.600 ₫
#
#                         Return         Sale_rating        Ship_on_time  \
# 1    30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 2                         None                None                None
# 3    30 Ngày Trả Hàng Miễn Phí  Không đủ thông tin                100%
# 4    30 Ngày Trả Hàng Miễn Phí                 96%                100%
# 5    30 Ngày Trả Hàng Miễn Phí                 96%                100%
# ..                         ...                 ...                 ...
# 196  30 Ngày Trả Hàng Miễn Phí                 98%  Không đủ thông tin
# 197  30 Ngày Trả Hàng Miễn Phí                 96%                100%
# 198  30 Ngày Trả Hàng Miễn Phí    Nhà bán hàng mới  Không đủ thông tin
# 199  30 Ngày Trả Hàng Miễn Phí                 96%                100%
# 200  30 Ngày Trả Hàng Miễn Phí                 97%                100%
#
#     Chat_response One_star Two_star Three_star Four_star Five_star
# 1            100%      [1]      [0]        [0]       [1]     [232]
# 2            None      [0]      [0]        [0]       [0]       [0]
# 3            100%      [1]      [0]        [0]       [2]      [61]
# 4            100%     [18]      [4]        [6]      [12]     [641]
# 5            100%      [2]      [1]        [1]       [1]     [137]
# ..            ...      ...      ...        ...       ...       ...
# 196           98%      [0]      [0]        [0]       [0]       [1]
# 197          100%      [0]      [0]        [0]       [0]       [0]
# 198          100%      [0]      [0]        [0]       [0]       [0]
# 199          100%      [0]      [0]        [0]       [0]       [1]
# 200          100%      [0]      [0]        [0]       [0]       [2]
#
# [200 rows x 19 columns]
