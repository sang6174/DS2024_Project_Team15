# %%
import pandas as pd
import numpy as np

# %%
name_input = "FINAL.csv"
name_output = "Finalver1.csv"

# %%
data = pd.read_csv(name_input)
data.head(3)
# Out:
#       Type                                              Title  \
# 0  quần áo  Đồ Bộ Nữ Đi Chơi Chất Thun Mát Size M - dưới 5...
# 1  quần áo  Đồ ngủ nữ pijama mặc nhà bộ ngủ hoạt hình cộc ...
# 2  quần áo  [Đủ size 35-55 cân] Sét bộ 3 món áo 2 dây+áo c...
#
#                                                 Link Price_sale Sale_off  \
# 0  https://www.lazada.vn/products/do-bo-nu-di-cho...   35.891 ₫  64% Off
# 1  https://www.lazada.vn/products/do-ngu-nu-pijam...   25.000 ₫  50% Off
# 2  https://www.lazada.vn/products/du-size-35-55-c...   79.000 ₫  43% Off
#
#     Total_sold Preview     Location Price_original Ship_price  \
# 0  3.0K Đã bán  (1022)  Hồ Chí Minh      100.000 ₫   16.500 ₫
# 1   907 Đã bán   (241)  Hồ Chí Minh       71.998 ₫   16.500 ₫
# 2   961 Đã bán   (260)       Hà Nội      139.000 ₫   32.700 ₫
#
#                              Return Sale_rating Ship_on_time Chat_response  \
# 0  3 ngày trả hàng cho Nhà bán hàng         97%         100%          100%
# 1  3 ngày trả hàng cho Nhà bán hàng         91%         100%           50%
# 2  3 ngày trả hàng cho Nhà bán hàng         92%          99%           33%
#
#   One_star Two_star Three_star Four_star Five_star
# 0     20.0      7.0       27.0      36.0     932.0
# 1      5.0      2.0        6.0       7.0     222.0
# 2     11.0      8.0        8.0      16.0     218.0

# %%
#Check missing value
data.isnull().sum().sort_values(ascending=False)
# Out:
# Return            3513
# Total_sold        1846
# Sale_off          1838
# Preview           1716
# Price_original    1408
# Ship_price        1268
# Four_star          212
# Three_star         212
# Two_star           212
# One_star           212
# Five_star          212
# Sale_rating        145
# Ship_on_time       141
# Chat_response      141
# Title                0
# Location             0
# Price_sale           0
# Link                 0
# Type                 0
# dtype: int64

# %% [markdown]
# - Remove the columns **Title** & **Link** because they are not necessary.
# - Remove columns **Return** because:
#     * it has too many NULL values, nearly 50% of the total data.
#     * it is not relevant to the hypothesis being used.

# %%
#Drop Title, Link, Return
new_data = data.drop(columns=['Title', 'Link', 'Return'], axis=1)
new_data.head(3)
# Out:
#       Type Price_sale Sale_off   Total_sold Preview     Location  \
# 0  quần áo   35.891 ₫  64% Off  3.0K Đã bán  (1022)  Hồ Chí Minh
# 1  quần áo   25.000 ₫  50% Off   907 Đã bán   (241)  Hồ Chí Minh
# 2  quần áo   79.000 ₫  43% Off   961 Đã bán   (260)       Hà Nội
#
#   Price_original Ship_price Sale_rating Ship_on_time Chat_response One_star  \
# 0      100.000 ₫   16.500 ₫         97%         100%          100%     20.0
# 1       71.998 ₫   16.500 ₫         91%         100%           50%      5.0
# 2      139.000 ₫   32.700 ₫         92%          99%           33%     11.0
#
#   Two_star Three_star Four_star Five_star
# 0      7.0       27.0      36.0     932.0
# 1      2.0        6.0       7.0     222.0
# 2      8.0        8.0      16.0     218.0

# %%
#Display the unique values of columns: Sale_rating, Ship_on_time, và Chat_response
unique_sale_rating = new_data['Sale_rating'].unique()
unique_ship_on_time = new_data['Ship_on_time'].unique()
unique_chat_response = new_data['Chat_response'].unique()

print(unique_sale_rating, "\n")
print(unique_ship_on_time, "\n")
print(unique_chat_response, "\n")
# Out:
# ['97%' '91%' '92%' '94%' '95%' '99%' '88%' '98%' '93%' '96%' '86%'
#  'Không đủ thông tin' '85%' nan '69%' '90%' '87%' '89%' '83%' '62%' '64%'
#  '84%' '100%' 'Nhà bán hàng mới' '78%' '66%' '68%' '65%' '77%' '76%' '71%'
#  '74%' '75%' '73%' '81%' '60%' '80%' '40%' '79%' '82%' '67%']
#
# ['100%' '99%' '96%' 'Không đủ thông tin' '98%' '93%' '97%' nan '91%' '87%'
#  '84%' '92%' '95%' '83%' '80%' '63%' '86%' '67%' '28%' '82%' '85%' '94%'
#  '60%' '88%' '3%' '79%' '89%' '74%' '33%' '90%' '41%' '81%' '76%' '29%'
#  '71%' '66%' '25%' '13%' '50%' '72%' '75%' '44%' '70%' '68%' '57%' '55%'
#  '78%' '14%' '20%' '37%' '65%' '77%' '40%']
#
# ['100%' '50%' '33%' '83%' '97%' '60%' '66%' '90%' '81%'
#  'Không đủ thông tin' '99%' '54%' '42%' nan '91%' '82%' '96%' '34%' '69%'
#  '64%' '80%' '58%' '94%' '98%' '87%' '85%' '57%' '86%' '75%' '63%' '79%'
#  '71%' '88%' '92%' '56%' '77%' '84%' '93%' '95%' '72%' '46%' '73%' '78%'
#  '44%' '76%' '40%' '70%' '62%' '53%' '36%' '89%' '37%' '55%' '65%' '52%']

# %% [markdown]
# - We will replace the cells **Không đủ thông tin** & **Nhà bán hàng mới** to NULL.

# %%
new_data['Sale_rating'].replace(['Nhà bán hàng mới', 'Không đủ thông tin'], np.nan, inplace=True)
new_data['Ship_on_time'].replace(['Không đủ thông tin'], np.nan, inplace=True)
new_data['Chat_response'].replace(['Không đủ thông tin'], np.nan, inplace=True)

# %%
#Check columns: Sale_rating, Ship_on_time, và Chat_response
unique_sale_rating = new_data['Sale_rating'].unique()
unique_ship_on_time = new_data['Ship_on_time'].unique()
unique_chat_response = new_data['Chat_response'].unique()

print(unique_sale_rating, "\n")
print(unique_ship_on_time, "\n")
print(unique_chat_response, "\n")
# Out:
# ['97%' '91%' '92%' '94%' '95%' '99%' '88%' '98%' '93%' '96%' '86%' nan
#  '85%' '69%' '90%' '87%' '89%' '83%' '62%' '64%' '84%' '100%' '78%' '66%'
#  '68%' '65%' '77%' '76%' '71%' '74%' '75%' '73%' '81%' '60%' '80%' '40%'
#  '79%' '82%' '67%']
#
# ['100%' '99%' '96%' nan '98%' '93%' '97%' '91%' '87%' '84%' '92%' '95%'
#  '83%' '80%' '63%' '86%' '67%' '28%' '82%' '85%' '94%' '60%' '88%' '3%'
#  '79%' '89%' '74%' '33%' '90%' '41%' '81%' '76%' '29%' '71%' '66%' '25%'
#  '13%' '50%' '72%' '75%' '44%' '70%' '68%' '57%' '55%' '78%' '14%' '20%'
#  '37%' '65%' '77%' '40%']
#
# ['100%' '50%' '33%' '83%' '97%' '60%' '66%' '90%' '81%' nan '99%' '54%'
#  '42%' '91%' '82%' '96%' '34%' '69%' '64%' '80%' '58%' '94%' '98%' '87%'
#  '85%' '57%' '86%' '75%' '63%' '79%' '71%' '88%' '92%' '56%' '77%' '84%'
#  '93%' '95%' '72%' '46%' '73%' '78%' '44%' '76%' '40%' '70%' '62%' '53%'
#  '36%' '89%' '37%' '55%' '65%' '52%']

# %%
#NOTE: ai làm trang sức, laptop, điện thoại, tivi thì thêm phần này nha. Chỉnh cái 12345 sao lại thành số luôn á. 
#Cho đồng nhất với ở trên.

# Hàm để loại bỏ ký tự không mong muốn và lấy giá trị bên trong
def extract_number(val):
    if isinstance(val, str):
        return val.strip("[]'")  # loại bỏ các ký tự không mong muốn
    return val

# Áp dụng hàm extract_number cho từng cột
for column in new_data.columns[11:16]:
    new_data[column] = new_data[column].apply(extract_number)

# %%
print(new_data.dtypes)
# Out:
# Type              object
# Price_sale        object
# Sale_off          object
# Total_sold        object
# Preview           object
# Location          object
# Price_original    object
# Ship_price        object
# Sale_rating       object
# Ship_on_time      object
# Chat_response     object
# One_star          object
# Two_star          object
# Three_star        object
# Four_star         object
# Five_star         object
# dtype: object

# %%
new_data
# Out:
#          Type   Price_sale                           Sale_off   Total_sold  \
# 0     quần áo     35.891 ₫                            64% Off  3.0K Đã bán
# 1     quần áo     25.000 ₫                            50% Off   907 Đã bán
# 2     quần áo     79.000 ₫                            43% Off   961 Đã bán
# 3     quần áo     36.000 ₫                            60% Off   102 Đã bán
# 4     quần áo     15.971 ₫                            54% Off   219 Đã bán
# ...       ...          ...                                ...          ...
# 7195     tivi  5.390.000 ₫  LazFlash Sale,kết thúc sau 1 ngày    34 Đã bán
# 7196     tivi  2.730.000 ₫                                NaN          NaN
# 7197     tivi  6.150.000 ₫                                NaN          NaN
# 7198     tivi  4.250.000 ₫                                NaN          NaN
# 7199     tivi  2.650.000 ₫                                NaN          NaN
#
#      Preview     Location Price_original Ship_price Sale_rating Ship_on_time  \
# 0     (1022)  Hồ Chí Minh      100.000 ₫   16.500 ₫         97%         100%
# 1      (241)  Hồ Chí Minh       71.998 ₫   16.500 ₫         91%         100%
# 2      (260)       Hà Nội      139.000 ₫   32.700 ₫         92%          99%
# 3       (21)     Nam Định      189.000 ₫   37.700 ₫         94%         100%
# 4       (68)       Hà Nội       59.000 ₫   32.700 ₫         95%         100%
# ...      ...          ...            ...        ...         ...          ...
# 7195     (9)  Hồ Chí Minh    5.590.000 ₫   Miễn phí         96%         100%
# 7196     NaN  Hồ Chí Minh            NaN   38.000 ₫         NaN          NaN
# 7197     NaN  Hồ Chí Minh    9.990.000 ₫        NaN         97%          98%
# 7198     NaN       Hà Nội    4.990.000 ₫  135.500 ₫        100%          40%
# 7199     NaN  Hồ Chí Minh            NaN   45.100 ₫        100%          NaN
#
#      Chat_response One_star Two_star Three_star Four_star Five_star
# 0             100%     20.0      7.0       27.0      36.0     932.0
# 1              50%      5.0      2.0        6.0       7.0     222.0
# 2              33%     11.0      8.0        8.0      16.0     218.0
# 3              83%      1.0      0.0        1.0       1.0      18.0
# 4             100%      0.0      1.0        0.0       3.0      65.0
# ...            ...      ...      ...        ...       ...       ...
# 7195          100%        2        0          0         0         7
# 7196           NaN        0        0          0         0         0
# 7197           89%        0        0          0         0         0
# 7198           NaN        0        0          0         0         0
# 7199           50%        0        0          0         0         0
#
# [7200 rows x 16 columns]

# %%
# Thay thế 'quần áo nam' bằng 'quần áo', 'giày' bằng 'giày dép'
new_data['Type'] = new_data['Type'].replace('quần áo nam', 'quần áo')
new_data['Type'] = new_data['Type'].replace('giày', 'giày dép')
new_data
# Out:
#          Type   Price_sale                           Sale_off   Total_sold  \
# 0     quần áo     35.891 ₫                            64% Off  3.0K Đã bán
# 1     quần áo     25.000 ₫                            50% Off   907 Đã bán
# 2     quần áo     79.000 ₫                            43% Off   961 Đã bán
# 3     quần áo     36.000 ₫                            60% Off   102 Đã bán
# 4     quần áo     15.971 ₫                            54% Off   219 Đã bán
# ...       ...          ...                                ...          ...
# 7195     tivi  5.390.000 ₫  LazFlash Sale,kết thúc sau 1 ngày    34 Đã bán
# 7196     tivi  2.730.000 ₫                                NaN          NaN
# 7197     tivi  6.150.000 ₫                                NaN          NaN
# 7198     tivi  4.250.000 ₫                                NaN          NaN
# 7199     tivi  2.650.000 ₫                                NaN          NaN
#
#      Preview     Location Price_original Ship_price Sale_rating Ship_on_time  \
# 0     (1022)  Hồ Chí Minh      100.000 ₫   16.500 ₫         97%         100%
# 1      (241)  Hồ Chí Minh       71.998 ₫   16.500 ₫         91%         100%
# 2      (260)       Hà Nội      139.000 ₫   32.700 ₫         92%          99%
# 3       (21)     Nam Định      189.000 ₫   37.700 ₫         94%         100%
# 4       (68)       Hà Nội       59.000 ₫   32.700 ₫         95%         100%
# ...      ...          ...            ...        ...         ...          ...
# 7195     (9)  Hồ Chí Minh    5.590.000 ₫   Miễn phí         96%         100%
# 7196     NaN  Hồ Chí Minh            NaN   38.000 ₫         NaN          NaN
# 7197     NaN  Hồ Chí Minh    9.990.000 ₫        NaN         97%          98%
# 7198     NaN       Hà Nội    4.990.000 ₫  135.500 ₫        100%          40%
# 7199     NaN  Hồ Chí Minh            NaN   45.100 ₫        100%          NaN
#
#      Chat_response One_star Two_star Three_star Four_star Five_star
# 0             100%     20.0      7.0       27.0      36.0     932.0
# 1              50%      5.0      2.0        6.0       7.0     222.0
# 2              33%     11.0      8.0        8.0      16.0     218.0
# 3              83%      1.0      0.0        1.0       1.0      18.0
# 4             100%      0.0      1.0        0.0       3.0      65.0
# ...            ...      ...      ...        ...       ...       ...
# 7195          100%        2        0          0         0         7
# 7196           NaN        0        0          0         0         0
# 7197           89%        0        0          0         0         0
# 7198           NaN        0        0          0         0         0
# 7199           50%        0        0          0         0         0
#
# [7200 rows x 16 columns]

# %%
# Hàm để trích xuất phần trăm giảm giá từ chuỗi
def extract_discount(promo):
    # Kiểm tra nếu chuỗi có chứa phần trăm giảm giá
    if isinstance(promo, str) and '% Off' in promo:
        # Tách chuỗi bằng ký tự xuống dòng (\r\n) và lấy phần đầu tiên
        return promo.split('\r\n')[0]
    else:
        return None

# %%
# Áp dụng hàm để thay thế giá trị trong cột 'Promotion'
new_data['Sale_off'] = new_data['Sale_off'].apply(extract_discount)
new_data
# Out:
#          Type   Price_sale Sale_off   Total_sold Preview     Location  \
# 0     quần áo     35.891 ₫  64% Off  3.0K Đã bán  (1022)  Hồ Chí Minh
# 1     quần áo     25.000 ₫  50% Off   907 Đã bán   (241)  Hồ Chí Minh
# 2     quần áo     79.000 ₫  43% Off   961 Đã bán   (260)       Hà Nội
# 3     quần áo     36.000 ₫  60% Off   102 Đã bán    (21)     Nam Định
# 4     quần áo     15.971 ₫  54% Off   219 Đã bán    (68)       Hà Nội
# ...       ...          ...      ...          ...     ...          ...
# 7195     tivi  5.390.000 ₫     None    34 Đã bán     (9)  Hồ Chí Minh
# 7196     tivi  2.730.000 ₫     None          NaN     NaN  Hồ Chí Minh
# 7197     tivi  6.150.000 ₫     None          NaN     NaN  Hồ Chí Minh
# 7198     tivi  4.250.000 ₫     None          NaN     NaN       Hà Nội
# 7199     tivi  2.650.000 ₫     None          NaN     NaN  Hồ Chí Minh
#
#      Price_original Ship_price Sale_rating Ship_on_time Chat_response  \
# 0         100.000 ₫   16.500 ₫         97%         100%          100%
# 1          71.998 ₫   16.500 ₫         91%         100%           50%
# 2         139.000 ₫   32.700 ₫         92%          99%           33%
# 3         189.000 ₫   37.700 ₫         94%         100%           83%
# 4          59.000 ₫   32.700 ₫         95%         100%          100%
# ...             ...        ...         ...          ...           ...
# 7195    5.590.000 ₫   Miễn phí         96%         100%          100%
# 7196            NaN   38.000 ₫         NaN          NaN           NaN
# 7197    9.990.000 ₫        NaN         97%          98%           89%
# 7198    4.990.000 ₫  135.500 ₫        100%          40%           NaN
# 7199            NaN   45.100 ₫        100%          NaN           50%
#
#      One_star Two_star Three_star Four_star Five_star
# 0        20.0      7.0       27.0      36.0     932.0
# 1         5.0      2.0        6.0       7.0     222.0
# 2        11.0      8.0        8.0      16.0     218.0
# 3         1.0      0.0        1.0       1.0      18.0
# 4         0.0      1.0        0.0       3.0      65.0
# ...       ...      ...        ...       ...       ...
# 7195        2        0          0         0         7
# 7196        0        0          0         0         0
# 7197        0        0          0         0         0
# 7198        0        0          0         0         0
# 7199        0        0          0         0         0
#
# [7200 rows x 16 columns]

# %%
# Thay thế 'Miễn phí' bằng '0 đ'
new_data['Ship_price'] = new_data['Ship_price'].replace('Miễn phí', '0 ₫')
new_data
# Out:
#          Type   Price_sale Sale_off   Total_sold Preview     Location  \
# 0     quần áo     35.891 ₫  64% Off  3.0K Đã bán  (1022)  Hồ Chí Minh
# 1     quần áo     25.000 ₫  50% Off   907 Đã bán   (241)  Hồ Chí Minh
# 2     quần áo     79.000 ₫  43% Off   961 Đã bán   (260)       Hà Nội
# 3     quần áo     36.000 ₫  60% Off   102 Đã bán    (21)     Nam Định
# 4     quần áo     15.971 ₫  54% Off   219 Đã bán    (68)       Hà Nội
# ...       ...          ...      ...          ...     ...          ...
# 7195     tivi  5.390.000 ₫     None    34 Đã bán     (9)  Hồ Chí Minh
# 7196     tivi  2.730.000 ₫     None          NaN     NaN  Hồ Chí Minh
# 7197     tivi  6.150.000 ₫     None          NaN     NaN  Hồ Chí Minh
# 7198     tivi  4.250.000 ₫     None          NaN     NaN       Hà Nội
# 7199     tivi  2.650.000 ₫     None          NaN     NaN  Hồ Chí Minh
#
#      Price_original Ship_price Sale_rating Ship_on_time Chat_response  \
# 0         100.000 ₫   16.500 ₫         97%         100%          100%
# 1          71.998 ₫   16.500 ₫         91%         100%           50%
# 2         139.000 ₫   32.700 ₫         92%          99%           33%
# 3         189.000 ₫   37.700 ₫         94%         100%           83%
# 4          59.000 ₫   32.700 ₫         95%         100%          100%
# ...             ...        ...         ...          ...           ...
# 7195    5.590.000 ₫        0 ₫         96%         100%          100%
# 7196            NaN   38.000 ₫         NaN          NaN           NaN
# 7197    9.990.000 ₫        NaN         97%          98%           89%
# 7198    4.990.000 ₫  135.500 ₫        100%          40%           NaN
# 7199            NaN   45.100 ₫        100%          NaN           50%
#
#      One_star Two_star Three_star Four_star Five_star
# 0        20.0      7.0       27.0      36.0     932.0
# 1         5.0      2.0        6.0       7.0     222.0
# 2        11.0      8.0        8.0      16.0     218.0
# 3         1.0      0.0        1.0       1.0      18.0
# 4         0.0      1.0        0.0       3.0      65.0
# ...       ...      ...        ...       ...       ...
# 7195        2        0          0         0         7
# 7196        0        0          0         0         0
# 7197        0        0          0         0         0
# 7198        0        0          0         0         0
# 7199        0        0          0         0         0
#
# [7200 rows x 16 columns]

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7200 entries, 0 to 7199
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            7200 non-null   object
#  1   Price_sale      7200 non-null   object
#  2   Sale_off        5291 non-null   object
#  3   Total_sold      5354 non-null   object
#  4   Preview         5484 non-null   object
#  5   Location        7200 non-null   object
#  6   Price_original  5792 non-null   object
#  7   Ship_price      5932 non-null   object
#  8   Sale_rating     6533 non-null   object
#  9   Ship_on_time    5421 non-null   object
#  10  Chat_response   6064 non-null   object
#  11  One_star        6988 non-null   object
#  12  Two_star        6988 non-null   object
#  13  Three_star      6988 non-null   object
#  14  Four_star       6988 non-null   object
#  15  Five_star       6988 non-null   object
# dtypes: object(16)
# memory usage: 900.1+ KB

# %%
new_data.to_csv(name_output, index=False, encoding='utf-8-sig')
