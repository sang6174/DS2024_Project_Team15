# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Data_Jewelry.csv")
data.head()
# Out:
#         Type                                              Title  \
# 0  Trang sức  17km pha lê May Mắn Vòng đeo tay đính hạt cho ...
# 1  Trang sức  🔥 Vòng kim cương mạ bạc đơn giản S925 dành cho...
# 2  Trang sức  【YIDEA HONGKONG】1pc nhẫn Cặp Đôi Đồng Tâm Thắt...
# 3  Trang sức  Vòng Cổ Dây Chuyền Chạm Xương Quai Xanh Hình T...
# 4  Trang sức  JWER Quà Tặng Trang Sức Cặp Đôi Hình Trái Tim ...
#
#                                                 Link Price_sale Sale_off  \
# 0  https://www.lazada.vn/products/17km-pha-le-may...    6.848 ₫  46% Off
# 1  https://www.lazada.vn/products/vong-kim-cuong-...    7.458 ₫  58% Off
# 2  https://www.lazada.vn/products/yidea-hongkong1...   16.000 ₫  47% Off
# 3  https://www.lazada.vn/products/vong-co-day-chu...    4.850 ₫  49% Off
# 4  https://www.lazada.vn/products/jwer-qua-tang-t...    5.000 ₫  44% Off
#
#     Total_sold Preview     Location Price_original Ship_price  \
# 0  1.9K Đã bán   (594)  Hồ Chí Minh       22.906 ₫   17.000 ₫
# 1  2.0K Đã bán   (406)  Hồ Chí Minh       17.600 ₫   16.500 ₫
# 2  1.2K Đã bán   (239)  Hồ Chí Minh       34.000 ₫   17.000 ₫
# 3    82 Đã bán    (21)  Hồ Chí Minh        9.534 ₫   17.000 ₫
# 4  1.2K Đã bán   (222)  Hồ Chí Minh        9.000 ₫   17.000 ₫
#
#                       Return Sale_rating Ship_on_time Chat_response One_star  \
# 0  30 Ngày Trả Hàng Miễn Phí         96%          95%           96%   ['13']
# 1                        NaN         97%          89%          100%    ['6']
# 2                        NaN         93%          98%          100%    ['7']
# 3                        NaN         96%         100%           83%    ['0']
# 4                        NaN         95%          99%           62%   ['12']
#
#   Two_star Three_star Four_star Five_star
# 0    ['8']     ['15']    ['14']   ['544']
# 1    ['1']      ['9']    ['17']   ['373']
# 2    ['0']      ['3']     ['9']   ['220']
# 3    ['0']      ['0']     ['0']    ['21']
# 4    ['4']      ['6']    ['13']   ['187']

# %%
#Check missing value
data.isnull().sum().sort_values(ascending=False)
# Out:
# Return            1034
# Sale_off           112
# Total_sold          64
# Price_original      48
# Preview             37
# Ship_price          11
# Chat_response        9
# Sale_rating          9
# Ship_on_time         9
# Four_star            0
# Three_star           0
# Two_star             0
# One_star             0
# Type                 0
# Title                0
# Location             0
# Price_sale           0
# Link                 0
# Five_star            0
# dtype: int64

# %%
#Drop Title, Link, Return
new_data = data.drop(columns=['Title', 'Link', 'Return'], axis=1)
new_data.head(5)
# Out:
#         Type Price_sale Sale_off   Total_sold Preview     Location  \
# 0  Trang sức    6.848 ₫  46% Off  1.9K Đã bán   (594)  Hồ Chí Minh
# 1  Trang sức    7.458 ₫  58% Off  2.0K Đã bán   (406)  Hồ Chí Minh
# 2  Trang sức   16.000 ₫  47% Off  1.2K Đã bán   (239)  Hồ Chí Minh
# 3  Trang sức    4.850 ₫  49% Off    82 Đã bán    (21)  Hồ Chí Minh
# 4  Trang sức    5.000 ₫  44% Off  1.2K Đã bán   (222)  Hồ Chí Minh
#
#   Price_original Ship_price Sale_rating Ship_on_time Chat_response One_star  \
# 0       22.906 ₫   17.000 ₫         96%          95%           96%   ['13']
# 1       17.600 ₫   16.500 ₫         97%          89%          100%    ['6']
# 2       34.000 ₫   17.000 ₫         93%          98%          100%    ['7']
# 3        9.534 ₫   17.000 ₫         96%         100%           83%    ['0']
# 4        9.000 ₫   17.000 ₫         95%          99%           62%   ['12']
#
#   Two_star Three_star Four_star Five_star
# 0    ['8']     ['15']    ['14']   ['544']
# 1    ['1']      ['9']    ['17']   ['373']
# 2    ['0']      ['3']     ['9']   ['220']
# 3    ['0']      ['0']     ['0']    ['21']
# 4    ['4']      ['6']    ['13']   ['187']

# %%
#Display the unique values of columns: Sale_rating, Ship_on_time, và Chat_response
unique_sale_rating = new_data['Sale_rating'].unique()
unique_ship_on_time = new_data['Ship_on_time'].unique()
unique_chat_response = new_data['Chat_response'].unique()

print(unique_sale_rating, "\n")
print(unique_ship_on_time, "\n")
print(unique_chat_response, "\n")
# Out:
# ['96%' '97%' '93%' '95%' '94%' '98%' '80%' '99%' 'Nhà bán hàng mới' '88%'
#  '87%' nan '84%' 'Không đủ thông tin' '85%' '92%' '91%' '90%' '100%' '40%'
#  '83%' '89%' '79%' '86%']
#
# ['95%' '89%' '98%' '100%' '99%' '96%' '94%' '97%' '93%'
#  'Không đủ thông tin' '87%' nan '67%' '90%' '91%' '88%' '86%' '92%' '50%'
#  '84%' '70%' '60%' '66%' '81%' '85%' '71%' '76%' '82%']
#
# ['96%' '100%' '83%' '62%' '50%' '80%' 'Không đủ thông tin' '86%' '85%'
#  '90%' '92%' '87%' '78%' '94%' '60%' '95%' '84%' nan '91%' '97%' '99%'
#  '66%' '75%' '81%' '53%' '82%' '36%' '71%' '77%' '63%']

# %%
new_data['Sale_rating'].replace(['Nhà bán hàng mới', 'Không đủ thông tin'], np.nan, inplace=True)
new_data['Ship_on_time'].replace(['Không đủ thông tin'], np.nan, inplace=True)
new_data['Chat_response'].replace(['Không đủ thông tin'], np.nan, inplace=True)

# %%
#Check columns: Sale_rating, Ship_on_time, và Chat_response
unique_sale_rating = new_data['Sale_rating'].unique()
unique_ship_on_time = new_data['Ship_on_time'].unique()
unique_chat_response = new_data['Chat_response'].unique()

print(unique_sale_rating, "\n")
print(unique_ship_on_time, "\n")
print(unique_chat_response, "\n")
# Out:
# ['96%' '97%' '93%' '95%' '94%' '98%' '80%' '99%' nan '88%' '87%' '84%'
#  '85%' '92%' '91%' '90%' '100%' '40%' '83%' '89%' '79%' '86%']
#
# ['95%' '89%' '98%' '100%' '99%' '96%' '94%' '97%' '93%' nan '87%' '67%'
#  '90%' '91%' '88%' '86%' '92%' '50%' '84%' '70%' '60%' '66%' '81%' '85%'
#  '71%' '76%' '82%']
#
# ['96%' '100%' '83%' '62%' '50%' '80%' nan '86%' '85%' '90%' '92%' '87%'
#  '78%' '94%' '60%' '95%' '84%' '91%' '97%' '99%' '66%' '75%' '81%' '53%'
#  '82%' '36%' '71%' '77%' '63%']

# %%
# Hàm để loại bỏ ký tự không mong muốn và lấy giá trị bên trong
def extract_number(val):
    if isinstance(val, str):
        return val.strip("[]'")  # loại bỏ các ký tự không mong muốn
    return val

# Áp dụng hàm extract_number cho từng cột
for column in new_data.columns[11:16]:
    new_data[column] = new_data[column].apply(extract_number)

# %%
new_data
# Out:
#            Type Price_sale                  Sale_off   Total_sold Preview  \
# 0     Trang sức    6.848 ₫                   46% Off  1.9K Đã bán   (594)
# 1     Trang sức    7.458 ₫                   58% Off  2.0K Đã bán   (406)
# 2     Trang sức   16.000 ₫                   47% Off  1.2K Đã bán   (239)
# 3     Trang sức    4.850 ₫                   49% Off    82 Đã bán    (21)
# 4     Trang sức    5.000 ₫                   44% Off  1.2K Đã bán   (222)
# ...         ...        ...                       ...          ...     ...
# 1195  Trang sức   34.225 ₫                   54% Off    15 Đã bán     (3)
# 1196  Trang sức   20.900 ₫  49% Off\nÁp dụng voucher    12 Đã bán     (1)
# 1197  Trang sức  188.000 ₫                   62% Off   256 Đã bán    (53)
# 1198  Trang sức   15.331 ₫                   31% Off    26 Đã bán     (9)
# 1199  Trang sức   66.913 ₫                   25% Off    38 Đã bán     (7)
#
#          Location Price_original Ship_price Sale_rating Ship_on_time  \
# 0     Hồ Chí Minh       22.906 ₫   17.000 ₫         96%          95%
# 1     Hồ Chí Minh       17.600 ₫   16.500 ₫         97%          89%
# 2     Hồ Chí Minh       34.000 ₫   17.000 ₫         93%          98%
# 3     Hồ Chí Minh        9.534 ₫   17.000 ₫         96%         100%
# 4     Hồ Chí Minh        9.000 ₫   17.000 ₫         95%          99%
# ...           ...            ...        ...         ...          ...
# 1195   Nước ngoài       74.000 ₫   17.000 ₫         96%          99%
# 1196   Nước ngoài       41.000 ₫   17.000 ₫         95%         100%
# 1197       Hà Nội      500.000 ₫   32.700 ₫         94%         100%
# 1198   Nước ngoài       22.134 ₫   17.000 ₫         93%         100%
# 1199  Hồ Chí Minh       89.000 ₫   16.500 ₫         97%          99%
#
#      Chat_response One_star Two_star Three_star Four_star Five_star
# 0              96%       13        8         15        14       544
# 1             100%        6        1          9        17       373
# 2             100%        7        0          3         9       220
# 3              83%        0        0          0         0        21
# 4              62%       12        4          6        13       187
# ...            ...      ...      ...        ...       ...       ...
# 1195          100%        0        0          0         0         4
# 1196           NaN        0        0          0         0         1
# 1197          100%        0        1          2         0        50
# 1198           NaN        0        0          0         0         9
# 1199           87%        0        0          0         0         7
#
# [1200 rows x 16 columns]

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            1200 non-null   object
#  1   Price_sale      1200 non-null   object
#  2   Sale_off        1088 non-null   object
#  3   Total_sold      1136 non-null   object
#  4   Preview         1163 non-null   object
#  5   Location        1200 non-null   object
#  6   Price_original  1152 non-null   object
#  7   Ship_price      1189 non-null   object
#  8   Sale_rating     1177 non-null   object
#  9   Ship_on_time    1170 non-null   object
#  10  Chat_response   938 non-null    object
#  11  One_star        1200 non-null   object
#  12  Two_star        1200 non-null   object
#  13  Three_star      1200 non-null   object
#  14  Four_star       1200 non-null   object
#  15  Five_star       1200 non-null   object
# dtypes: object(16)
# memory usage: 150.1+ KB

# %%
new_data.to_csv("Preprocessing_Data_Jewelry.csv", index=False)
