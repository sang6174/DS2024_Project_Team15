# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.request
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
from tqdm import tqdm

# %%
from Main_function import get_Data_On_Page, get_Data_OneProduct_Link 

path = 'chromedriver.exe'

# # Customize chrome displayLa
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')
## chrome_options.add_argument('--headless')  # Optional: run Chrome in headless mode

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
#Empty list, to store data from all pages
AllData = []

for page in tqdm(range(16, 21), desc="Crawling pages"):
    main_link = f'https://www.lazada.vn/catalog/?page={page}&q=Trang%20s%E1%BB%A9c&spm=a2o4n.home-vn.search.d_go'
    driver.get(main_link)
    sleep(random.uniform(2,5))                             #Random sleep to mimic human behavior and avoid getting blocked

    df_Jewelry = get_Data_On_Page(driver)
    AllData.append(df_Jewelry)
# Out:
# Crawling pages: 100%|██████████| 5/5 [02:38<00:00, 31.75s/it]

# %%
#Combine into a DataFrame
Data_Jewelry_Page16_To_Page20 = pd.concat(AllData, ignore_index=True)
Data_Jewelry_Page16_To_Page20.index = np.arange(1, len(Data_Jewelry_Page16_To_Page20)+1)
Data_Jewelry_Page16_To_Page20
# Out:
#           Type                                              Title  \
# 1    Trang sức  Nước rửa trang sức Hoàng Kim Jewelry, nước làm...
# 2    Trang sức  Lấp lánh hơn cả ánh đèn đêm: Bộ Trang Sức 5 mó...
# 3    Trang sức  17 MILE Colorful Beads Bracelet for Women Crys...
# 4    Trang sức  JWER Vòng Cổ Dây Chuyền Màu Bạc Mặt Trái Tim P...
# 5    Trang sức  HZS Nhẫn Nam Và Nữ Bằng Thép Không Gỉ Bán Chạy...
# ..         ...                                                ...
# 196  Trang sức  Bộ trang sức bạc mặt hoa chất liệu bằng bạc s9...
# 197  Trang sức  OYJR Nhẫn Titan nữ chống gỉ 18k vàng cá tính c...
# 198  Trang sức  MIAOYA Phiên bản Hàn Quốc của màu xanh navy To...
# 199  Trang sức  Hoa Chúng Tôi Nhẫn Xoắn Hình Học Bạc Sang Trọn...
# 200  Trang sức  Bộ trang sức bạc mặt hình kim cương chất liệu ...
#
#                                                   Link Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/nuoc-rua-trang-...   16.250 ₫
# 2    https://www.lazada.vn/products/lap-lanh-hon-ca...   31.844 ₫
# 3    https://www.lazada.vn/products/17-mile-colorfu...    6.146 ₫
# 4    https://www.lazada.vn/products/jwer-vong-co-da...    7.000 ₫
# 5    https://www.lazada.vn/products/hzs-nhan-nam-va...    9.035 ₫
# ..                                                 ...        ...      ...
# 196  https://www.lazada.vn/products/bo-trang-suc-ba...   96.000 ₫  13% Off
# 197  https://www.lazada.vn/products/oyjr-nhan-titan...   50.000 ₫  38% Off
# 198  https://www.lazada.vn/products/miaoya-phien-ba...    6.820 ₫  45% Off
# 199  https://www.lazada.vn/products/hoa-chung-toi-n...    8.000 ₫  47% Off
# 200  https://www.lazada.vn/products/bo-trang-suc-ba...  200.000 ₫   9% Off
#
#       Total_sold Preview     Location
# 1      26 Đã bán     (4)       Hà Nội
# 2      14 Đã bán     (4)  Hồ Chí Minh
# 3     241 Đã bán    (61)  Hồ Chí Minh
# 4     628 Đã bán   (117)  Hồ Chí Minh
# 5    1.0K Đã bán   (220)  Hồ Chí Minh
# ..           ...     ...          ...
# 196         None     (1)    Hải Dương
# 197    18 Đã bán     (4)   Nước ngoài
# 198    11 Đã bán     (4)   Nước ngoài
# 199    13 Đã bán     (4)   Nước ngoài
# 200         None    None    Hải Dương
#
# [200 rows x 8 columns]

# %%
#Initialize dictionary to store details for all products
Products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [], 
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(Data_Jewelry_Page16_To_Page20.Link, desc="Crawling link product"):
    LinkProduct = get_Data_OneProduct_Link(driver, link)
    for key in Products.keys():
        Products[key].append(LinkProduct[key])
# Out:
# Crawling link product: 100%|██████████| 200/200 [1:41:05<00:00, 30.33s/it]

# %%
#Add columns to combined_data
for key, value in Products.items():
    Data_Jewelry_Page16_To_Page20[key] = value

# %%
# Convert to csv
Data_Jewelry_Page16_To_Page20.to_csv("Data_Jewelry_Page16_To_Page20.csv", index=False)
Data_Jewelry_Page16_To_Page20
# Out:
#           Type                                              Title  \
# 1    Trang sức  Nước rửa trang sức Hoàng Kim Jewelry, nước làm...
# 2    Trang sức  Lấp lánh hơn cả ánh đèn đêm: Bộ Trang Sức 5 mó...
# 3    Trang sức  17 MILE Colorful Beads Bracelet for Women Crys...
# 4    Trang sức  JWER Vòng Cổ Dây Chuyền Màu Bạc Mặt Trái Tim P...
# 5    Trang sức  HZS Nhẫn Nam Và Nữ Bằng Thép Không Gỉ Bán Chạy...
# ..         ...                                                ...
# 196  Trang sức  Bộ trang sức bạc mặt hoa chất liệu bằng bạc s9...
# 197  Trang sức  OYJR Nhẫn Titan nữ chống gỉ 18k vàng cá tính c...
# 198  Trang sức  MIAOYA Phiên bản Hàn Quốc của màu xanh navy To...
# 199  Trang sức  Hoa Chúng Tôi Nhẫn Xoắn Hình Học Bạc Sang Trọn...
# 200  Trang sức  Bộ trang sức bạc mặt hình kim cương chất liệu ...
#
#                                                   Link Price_sale Sale_off  \
# 1    https://www.lazada.vn/products/nuoc-rua-trang-...   16.250 ₫
# 2    https://www.lazada.vn/products/lap-lanh-hon-ca...   31.844 ₫
# 3    https://www.lazada.vn/products/17-mile-colorfu...    6.146 ₫
# 4    https://www.lazada.vn/products/jwer-vong-co-da...    7.000 ₫
# 5    https://www.lazada.vn/products/hzs-nhan-nam-va...    9.035 ₫
# ..                                                 ...        ...      ...
# 196  https://www.lazada.vn/products/bo-trang-suc-ba...   96.000 ₫  13% Off
# 197  https://www.lazada.vn/products/oyjr-nhan-titan...   50.000 ₫  38% Off
# 198  https://www.lazada.vn/products/miaoya-phien-ba...    6.820 ₫  45% Off
# 199  https://www.lazada.vn/products/hoa-chung-toi-n...    8.000 ₫  47% Off
# 200  https://www.lazada.vn/products/bo-trang-suc-ba...  200.000 ₫   9% Off
#
#       Total_sold Preview     Location Price_original Ship_price  \
# 1      26 Đã bán     (4)       Hà Nội           None       None
# 2      14 Đã bán     (4)  Hồ Chí Minh      199.000 ₫   16.500 ₫
# 3     241 Đã bán    (61)  Hồ Chí Minh       15.833 ₫   17.000 ₫
# 4     628 Đã bán   (117)  Hồ Chí Minh       19.000 ₫   17.000 ₫
# 5    1.0K Đã bán   (220)  Hồ Chí Minh       17.000 ₫   17.000 ₫
# ..           ...     ...          ...            ...        ...
# 196         None     (1)    Hải Dương      110.000 ₫   37.700 ₫
# 197    18 Đã bán     (4)   Nước ngoài       80.000 ₫   17.000 ₫
# 198    11 Đã bán     (4)   Nước ngoài       12.399 ₫   17.000 ₫
# 199    13 Đã bán     (4)   Nước ngoài       15.000 ₫   17.000 ₫
# 200         None    None    Hải Dương      400.000 ₫   37.700 ₫
#
#                         Return Sale_rating Ship_on_time       Chat_response  \
# 1                         None        None         None                None
# 2                         None         98%         100%  Không đủ thông tin
# 3    30 Ngày Trả Hàng Miễn Phí         95%          99%                100%
# 4                         None         95%         100%                 71%
# 5                         None         97%         100%  Không đủ thông tin
# ..                         ...         ...          ...                 ...
# 196                       None         96%          94%                 83%
# 197                       None         98%         100%                100%
# 198                       None         96%         100%                100%
# 199                       None         97%         100%  Không đủ thông tin
# 200                       None         96%          94%                 83%
#
#     One_star Two_star Three_star Four_star Five_star
# 1        [0]      [0]        [0]       [0]       [4]
# 2        [1]      [0]        [0]       [0]       [3]
# 3        [2]      [0]        [1]       [2]      [57]
# 4       [10]      [1]        [4]       [7]      [95]
# 5        [2]      [2]        [4]       [7]     [206]
# ..       ...      ...        ...       ...       ...
# 196      [0]      [0]        [0]       [0]       [1]
# 197      [1]      [0]        [0]       [0]       [4]
# 198      [0]      [0]        [0]       [0]       [4]
# 199      [0]      [0]        [0]       [0]       [4]
# 200      [0]      [0]        [0]       [0]       [0]
#
# [200 rows x 19 columns]
