# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.request
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from time import sleep
import random
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
from tqdm import tqdm

# %%
main_link = 'https://www.lazada.vn/catalog/?q=laptop'
path = 'chromedriver.exe'

# # Customize chrome displayLa
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-infobars')

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=chrome_options)

driver.get(main_link)

# %%
#Crawl the information displayed on the outside of the page
def get_Data_On_Page():
    #The information is definitely there
    Type = [elem.get_attribute("value") for elem in driver.find_elements(By.CSS_SELECTOR, ".search-box__input--O34g")]
    Title = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".RfADt [href]")]
    Link = [elem.get_attribute('href') for elem in driver.find_elements(By.CSS_SELECTOR, ".RfADt [href]")]
    Price_sale = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".ooOxS")]
    
    #The information may or may not be available
    #If not, assign None
    Sale_off, Total_sold, Preview = [], [], []
    for i in range(1, len(Title)+1):
        try:
            one_sale_off = driver.find_element("xpath", "/html/body/div[3]/div/div[2]/div[1]/div/div[1]/div[2]/div[{}]/div/div/div[2]/div[4]/span".format(i))
            Sale_off.append(one_sale_off.text)
        except NoSuchElementException:
            Sale_off.append(None)

        try:
            one_total_sold = driver.find_element("xpath", "/html/body/div[3]/div/div[2]/div[1]/div/div[1]/div[2]/div[{}]/div/div/div[2]/div[5]/span[1]/span[1]".format(i))
            Total_sold.append(one_total_sold.text)
        except NoSuchElementException:
            Total_sold.append(None)

        try:
            one_preview = driver.find_element("xpath", "/html/body/div[3]/div/div[2]/div[1]/div/div[1]/div[2]/div[{}]/div/div/div[2]/div[5]/div/span".format(i))
            Preview.append(one_preview.text)
        except NoSuchElementException:
            Preview.append(None)
    
    Location = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".oa6ri")]
    if len(Type) == 1:
        Type = Type * len(Title)

    #Create a dictionary with the lists
    data = {
        "Type": Type,
        "Title": Title,
        "Link": Link,
        "Price_sale": Price_sale,
        "Sale_off": Sale_off,
        "Total_sold": Total_sold,
        "Preview": Preview,
        "Location": Location
    }

    # Convert the dictionary to a DataFrame
    df = pd.DataFrame(data)
    return df

# %%
#Call the function and get the DF
df_Laptop = get_Data_On_Page()
df_Laptop.index = np.arange(1, len(df_Laptop)+1)
print(df_Laptop)
# Out:
#       Type                                              Title  \
# 1   laptop  [6.6 SALE TO] MacBook Air 2020 13.3 inches M1-...
# 2   laptop  Máy Tính Xách Tay Bàn Phím Bao Gồm, Màng Bảo V...
# 3   laptop  Laptop Dell Inspiron 7567 máy tính giá rẻ(Core...
# 4   laptop  Lenovo mới tinh core Intel i7 6560U laptop 15,...
# 5   laptop  LaptopLENOVO THINKPAD X1 Carbon Gen 7 X1 Carbo...
# 6   laptop  Laptop cũ nhiều lựa chọn Pentium đến i3 i5 i7 ...
# 7   laptop  Lenovo Thinkpad / Tosiba / Dell Core i5 / RAM ...
# 8   laptop  Lenovo Laptop 14 FHD Màn hình Intel Core i5 12...
# 9   laptop                               Laptop mini hàng đẹp
# 10  laptop  Laptop Cũ Rẻ Các Hãng Core i7 / i5 / Ram 8gb /...
# 11  laptop  Laptop game và đồ họa giá tốt HP 6470b Core i5...
# 12  laptop  Laptop Dell Latitude E7250 màn 12.5 - Core i7 ...
# 13  laptop  Laptop Dell Latitude E7270 ram 8G SSD 256G - C...
# 14  laptop  Laptop Dell Latitude E5480 màn 14 inch Ram 8G ...
# 15  laptop  Laptop cũ giá rẻ - Máy tính zin ram 4GB ổ 250g...
# 16  laptop  Ổ cứng Laptop HDD, SSD M2 1TB, 750GB, 640Gb, 5...
# 17  laptop  Laptop HP 15s-fq5228TU - 8U240PA (i3-1215U) (X...
# 18  laptop  [Trả Góp 0% đến 12 Tháng] MacBook Air 15 inch ...
# 19  laptop  [Trả Góp 0% đến 12 Tháng] MacBook Air M3 13.6 ...
# 20  laptop  Laptop core 2 giá rẻ, ram 4G, HDD 250G, đầy đủ...
# 21  laptop  [Voucher Discount 15% Max 3000k ] Laptop HP Pa...
# 22  laptop                                       ELITER X2 g4
# 23  laptop  Apple Macbook Air 2024 15.3" M3 - Chính Hãng A...
# 24  laptop  Laptop Dell Intel Core i5 4310U 2.0Ghz ~ 3.0Gh...
# 25  laptop  Microsoft Surface Pro 2018 - Core i7-8650U/8G/...
# 26  laptop  Máy tính laptop cấu hình đời cao chip I3 siêu ...
# 27  laptop  Voucher Discount 15% Max 3000k Laptop HP Pavil...
# 28  laptop  ThinkPad X1 Carbon Gen 6 Core i5 8250U / RAM 8...
# 29  laptop  Laptop Dell Precision 5550/ i7-10750H/ Ram 16G...
# 30  laptop  ASUS Factory 14 inch Máy tính xách tay mới Int...
# 31  laptop  Laptop Giá rẻ Dell Latitude 3590 Core™ i5 | Co...
# 32  laptop  Mới[Mới 100%]【Lennovo Factory】Monsprin 2024 ne...
# 33  laptop  Laptop Lenovo Gaming Legion 5 Pro 16ARH7H R7 6...
# 34  laptop  【Vietnam spot】【ASUS Factory】Monsprin 2024 new ...
# 35  laptop  Laptop HP Probook / Intel Core i5 ~ 2.4Ghz / R...
# 36  laptop  Lenovo new Intel core i5 laptop laptop 14 inch...
# 37  laptop  Laptop HP ProBook 450 G10 873J7PA (Core i5 134...
# 38  laptop  Laptop HP 14-em0085AU (835T8PA) (AMD Ryzen 3-7...
# 39  laptop  Laptop HP Pavilion 15-eg3112TU i7-1355U/16GB/5...
# 40  laptop  [Trả góp]Laptop HP ENVY x360 13-bf0114TU,Core ...
#
#                                                  Link    Price_sale  \
# 1   https://www.lazada.vn/products/66-sale-to-macb...  17.990.000 ₫
# 2   https://www.lazada.vn/products/may-tinh-xach-t...      39.000 ₫
# 3   https://www.lazada.vn/products/laptop-dell-ins...   3.200.000 ₫
# 4   https://www.lazada.vn/products/lenovo-moi-tinh...   7.223.999 ₫
# 5   https://www.lazada.vn/products/laptoplenovo-th...   4.390.000 ₫
# 6   https://www.lazada.vn/products/laptop-cu-nhieu...   1.000.000 ₫
# 7   https://www.lazada.vn/products/lenovo-thinkpad...   1.798.761 ₫
# 8   https://www.lazada.vn/products/lenovo-laptop-1...   4.804.919 ₫
# 9   https://www.lazada.vn/products/laptop-mini-han...     902.899 ₫
# 10  https://www.lazada.vn/products/laptop-cu-re-ca...   2.622.600 ₫
# 11  https://www.lazada.vn/products/laptop-game-va-...   1.300.000 ₫
# 12  https://www.lazada.vn/products/laptop-dell-lat...   2.668.000 ₫
# 13  https://www.lazada.vn/products/laptop-dell-lat...   3.248.000 ₫
# 14  https://www.lazada.vn/products/laptop-dell-lat...   3.258.000 ₫
# 15  https://www.lazada.vn/products/laptop-cu-gia-r...   1.200.000 ₫
# 16  https://www.lazada.vn/products/o-cung-laptop-h...     269.233 ₫
# 17  https://www.lazada.vn/products/laptop-hp-15s-f...  10.490.000 ₫
# 18  https://www.lazada.vn/products/tra-gop-0-den-1...  27.590.000 ₫
# 19  https://www.lazada.vn/products/tra-gop-0-den-1...  27.290.000 ₫
# 20  https://www.lazada.vn/products/laptop-core-2-g...   1.239.000 ₫
# 21  https://www.lazada.vn/products/voucher-discoun...  14.699.000 ₫
# 22  https://www.lazada.vn/products/eliter-x2-g4-i2...   7.689.000 ₫
# 23  https://www.lazada.vn/products/apple-macbook-a...  32.940.000 ₫
# 24  https://www.lazada.vn/products/laptop-dell-int...   3.390.000 ₫
# 25  https://www.lazada.vn/products/microsoft-surfa...  55.188.000 ₫
# 26  https://www.lazada.vn/products/may-tinh-laptop...   1.089.839 ₫
# 27  https://www.lazada.vn/products/voucher-discoun...  15.200.000 ₫
# 28  https://www.lazada.vn/products/thinkpad-x1-car...   4.560.080 ₫
# 29  https://www.lazada.vn/products/laptop-dell-pre...  24.610.000 ₫
# 30  https://www.lazada.vn/products/asus-factory-14...   4.799.999 ₫
# 31  https://www.lazada.vn/products/laptop-gia-re-d...   2.833.699 ₫
# 32  https://www.lazada.vn/products/moimoi-100lenno...   6.614.299 ₫
# 33  https://www.lazada.vn/products/laptop-lenovo-g...  46.490.000 ₫
# 34  https://www.lazada.vn/products/vietnam-spotasu...   6.519.809 ₫
# 35  https://www.lazada.vn/products/laptop-hp-probo...   2.550.000 ₫
# 36  https://www.lazada.vn/products/lenovo-new-inte...   4.351.599 ₫
# 37  https://www.lazada.vn/products/laptop-hp-probo...  21.600.000 ₫
# 38  https://www.lazada.vn/products/laptop-hp-14-em...   8.890.000 ₫
# 39  https://www.lazada.vn/products/laptop-hp-pavil...  25.290.000 ₫
# 40  https://www.lazada.vn/products/tra-goplaptop-h...  26.000.000 ₫
#
#                           Sale_off   Total_sold Preview     Location
# 1                             None  3.0K Đã bán   (666)     Bắc Ninh
# 2                             None   312 Đã bán    (67)  Hồ Chí Minh
# 3                             None         None    None       Hà Nội
# 4   LazFlash Sale,kết thúc sau 12h    51 Đã bán     (5)    Hải Phòng
# 5   LazFlash Sale,kết thúc sau 12h   126 Đã bán    (29)       Hà Nội
# 6                             None    81 Đã bán    (28)       Hà Nội
# 7                             None    18 Đã bán     (6)       Hà Nội
# 8                             None    97 Đã bán    (23)    Hải Phòng
# 9                             None    11 Đã bán     (2)     Hưng Yên
# 10                            None    89 Đã bán    (36)  Hồ Chí Minh
# 11                            None    82 Đã bán    (41)       Hà Nội
# 12                            None    33 Đã bán    (18)      Nghệ An
# 13                            None    64 Đã bán    (28)      Nghệ An
# 14                            None    73 Đã bán    (31)      Nghệ An
# 15                            None    24 Đã bán    (11)  Hồ Chí Minh
# 16                            None  2.2K Đã bán   (789)  Hồ Chí Minh
# 17                            None   351 Đã bán   (108)  Hồ Chí Minh
# 18                            None   147 Đã bán     (3)     Bắc Ninh
# 19                            None     7 Đã bán    None  Hồ Chí Minh
# 20                            None    22 Đã bán    (10)  Hồ Chí Minh
# 21                            None    38 Đã bán    (12)  Hồ Chí Minh
# 22                            None    40 Đã bán     (7)     Hưng Yên
# 23                            None     9 Đã bán    None  Hồ Chí Minh
# 24                            None         None     (3)       Hà Nội
# 25                            None    48 Đã bán    None  Hồ Chí Minh
# 26                            None         None     (3)     Hưng Yên
# 27                            None    69 Đã bán    (22)  Hồ Chí Minh
# 28                            None    28 Đã bán    (15)       Hà Nội
# 29                            None     6 Đã bán    None  Hồ Chí Minh
# 30                            None   117 Đã bán    (33)    Hải Phòng
# 31  LazFlash Sale,kết thúc sau 12h    50 Đã bán     (4)       Hà Nội
# 32                            None    91 Đã bán    (49)  Hồ Chí Minh
# 33                            None    38 Đã bán    None  Hồ Chí Minh
# 34                            None   294 Đã bán   (118)  Hồ Chí Minh
# 35                            None    33 Đã bán     (9)       Hà Nội
# 36                            None    25 Đã bán     (5)    Hải Phòng
# 37                            None         None     (1)  Hồ Chí Minh
# 38                            None         None    None  Hồ Chí Minh
# 39                            None     5 Đã bán    None  Hồ Chí Minh
# 40                            None     8 Đã bán    None  Hồ Chí Minh

# %%
#Get the link and access each product to get more features
def get_Data_OneProduct_Link(link):
    driver.get(link)                            #Get link
    sleep(random.uniform(3, 5))                 #Random sleep to mimic human behavior and avoid getting blocked
    
    Price_original = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".notranslate.pdp-price.pdp-price_type_deleted.pdp-price_color_lightgray.pdp-price_size_xs")]
    Ship_price = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".delivery-option-item.delivery-option-item_type_standard .delivery-option-item__body .delivery-option-item__shipping-fee.no-subtitle")]
    Return = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".delivery-option-item.delivery-option-item_type_returnPolicy30 .delivery-option-item__body .delivery-option-item__info .delivery-option-item__title")]

    # Sale_rating & Ship_on_time & Chat_respone
    percentage = [elem.text for elem in driver.find_elements(By.CSS_SELECTOR, ".seller-info-value ")]
    Sale_rating = percentage[0] if len(percentage) > 0 else None
    Ship_on_time = percentage[1] if len(percentage) > 1 else None
    Chat_response = percentage[2] if len(percentage) > 2 else None


    #Cuộn trang từ từ để tải phần đánh giá sao
    while True:
        driver.execute_script("window.scrollBy(0, 400);")
        sleep(1)  #Đợi một chút để nội dung tải
        try:
            stars = driver.find_elements(By.CSS_SELECTOR, ".detail .percent")
            if len(stars) >= 5:
                break
        except NoSuchElementException:
            continue
    
    One_star, Two_star, Three_star, Four_star, Five_star = [], [], [], [], []
    stars = [elem.text for elem in stars]

    One_star.append(stars[4] if len(stars) > 4 else 'N/A')
    Two_star.append(stars[3] if len(stars) > 3 else 'N/A')
    Three_star.append(stars[2] if len(stars) > 2 else 'N/A')
    Four_star.append(stars[1] if len(stars) > 1 else 'N/A')
    Five_star.append(stars[0] if len(stars) > 0 else 'N/A')


    #Create a dictionary with the lists
    One_Product = {
        "Price_original": Price_original[0] if Price_original else None,
        "Ship_price": Ship_price[0] if Ship_price else None,
        "Return": Return[0] if Return else None,
        "Sale_rating": Sale_rating,
        "Ship_on_time": Ship_on_time,
        "Chat_response": Chat_response,
        "One_star": One_star,
        "Two_star": Two_star,
        "Three_star": Three_star,
        "Four_star": Four_star,
        "Five_star": Five_star
    }
    
    return One_Product

# %%
#Initialize dictionary to store details for all products
Products = {
    "Price_original": [],
    "Ship_price": [],
    "Return": [],
    "Sale_rating": [],
    "Ship_on_time": [],
    "Chat_response": [],
    "One_star": [],
    "Two_star": [],
    "Three_star": [],
    "Four_star": [],
    "Five_star": []
}

#Create a progress bar to track the crawl process
for link in tqdm(df_Laptop.Link, desc="Crawling link product"):
    LinkProduct = get_Data_OneProduct_Link(link)
    for key in detail_products.keys():
        Products[key].append(LinkProduct[key])
# Out:
# Crawling link product:   0%|          | 0/40 [00:00<?, ?it/s]
